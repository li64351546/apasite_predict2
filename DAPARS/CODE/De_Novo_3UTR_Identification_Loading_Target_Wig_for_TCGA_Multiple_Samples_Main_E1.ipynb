# %%
import numpy as np
import os
import sys
import datetime

import scipy as sp
import scipy.stats

from bisect import bisect
from statsmodels.stats.multitest import multipletests

import math

# %%
def parse_cfgfile(cfg_file):
    '''Parse configure file
    '''
    Group1_Tophat_aligned_file=''
    Group2_Tophat_aligned_file=''
    output_directory=''
    Annotated_3UTR_file=''
    Output_result_file=''
    Num_least_in_group1_local=''
    Num_least_in_group2_local=''
    Coverage_cutoff_local = ''
    FDR_cutoff_local = ''
    Fold_change_cutoff_local = ''
    PDUI_cutoff_local = ''
    
    for line in open(cfg_file,'r'):
        if line[0] == '\n' or line[0] == '#':
            comments = line;
        else:
            line = line.rstrip();
            command = line.split('=');
            if command[0] == 'Group1_Tophat_aligned_Wig':
                Group1_Tophat_aligned_file = command[1].split(',');
            if command[0] == 'Group2_Tophat_aligned_Wig':
                Group2_Tophat_aligned_file = command[1].split(',');
            if command[0] == 'Output_directory':
                output_directory = command[1]
                if output_directory[-1] != '/':
                    output_directory += '/'
            if command[0] == 'Annotated_3UTR':
                Annotated_3UTR_file = command[1]
            if command[0] == 'Output_result_file':
                Output_result_file = command[1]
            
            ##Parameters
            if command[0] == 'Num_least_in_group1':
                Num_least_in_group1_local = command[1]
            if command[0] == 'Num_least_in_group2':
                Num_least_in_group2_local = command[1]
            if command[0] == 'Coverage_cutoff':
                Coverage_cutoff_local = command[1]
            if command[0] == 'FDR_cutoff':
                FDR_cutoff_local = command[1]
            if command[0] == 'Fold_change_cutoff':
                Fold_change_cutoff_local = command[1]
            if command[0] == 'PDUI_cutoff':
                PDUI_cutoff_local = command[1]
            
    
    if Group1_Tophat_aligned_file=='':
        print("No Tophat aligned BAM file for group 1!", file=sys.stderr)
        exit(1)
    if Group2_Tophat_aligned_file=='':
        print("No Tophat aligned BAM file for group 2!", file=sys.stderr)
        exit(1)
    if output_directory=='':
        print("No output directory!", file=sys.stderr)
        exit(1)
    if Annotated_3UTR_file=='':
        print("No annotated 3' UTR file!", file=sys.stderr)
        exit(1)
    if Output_result_file=='':
        print("No result file name!", file=sys.stderr)
        exit(1)
    return Group1_Tophat_aligned_file,Group2_Tophat_aligned_file,output_directory,Annotated_3UTR_file,Output_result_file,Num_least_in_group1_local,Num_least_in_group2_local,Coverage_cutoff_local,FDR_cutoff_local,Fold_change_cutoff_local,PDUI_cutoff_local

# %%
Group1_Tophat_aligned_file,Group2_Tophat_aligned_file,output_directory,Annotated_3UTR_file,Output_result_file,Num_least_in_group1_local,Num_least_in_group2_local,Coverage_cutoff_local,FDR_cutoff_local,Fold_change_cutoff_local,PDUI_cutoff_local = parse_cfgfile('/home/li/桌面/PROJECT6/apasite_predict2/DAPARS/DATA/DaPars_test_data_configure.txt')

# %%
num_group_1 = len(Group1_Tophat_aligned_file)
All_Sample_files = Group1_Tophat_aligned_file[:]
All_Sample_files.extend(Group2_Tophat_aligned_file)

# %%
def Load_Target_Wig_files(All_Wig_files, UTR_Annotation_file):
    UTR_events_dict = {}
    All_Samples_Total_depth = []
    for line in open(UTR_Annotation_file,'r'):
        fields = line.strip('\n').split('\t')
        curr_chr = fields[0]
        region_start = int(float(fields[1]))
        region_end   = int(float(fields[2]))
        curr_strand  = fields[-1]
        UTR_pos = "%s:%s-%s" % (curr_chr, region_start, region_end)
        end_shift = int(round(abs(int(region_start) - int(region_end)) * 0.2))
        if curr_strand == '+':
            region_end = str(int(region_end) - end_shift)
        else:
            region_start = str(int(region_start) + end_shift)
        region_start = int(region_start) + 1
        region_end   = int(region_end) - 1
        if region_start + 50 < region_end:
            UTR_events_dict[fields[3]] = [fields[0],region_start,region_end,fields[-1],UTR_pos]

    ##Load coverage for all samples
    All_samples_extracted_3UTR_coverage_dict = {}
    for curr_wig_file in All_Wig_files:
        curr_sample_All_chroms_coverage_dict = {}
        num_line = 0
        cur_sample_total_depth = 0
        for line in open(curr_wig_file,'r'):
            if '#' not in line and line[0:3] == 'chr':
                fields = line.strip('\n').split('\t')
                chrom_name = fields[0]
                region_start = int(float(fields[1]))
                region_end = int(float(fields[2]))
                cur_sample_total_depth += int(float(fields[-1])) * (region_end - region_start)
                if chrom_name not in curr_sample_All_chroms_coverage_dict:
                    curr_sample_All_chroms_coverage_dict[chrom_name] = [[0],[0]]
                if region_start > curr_sample_All_chroms_coverage_dict[chrom_name][0][-1]:
                    curr_sample_All_chroms_coverage_dict[chrom_name][0].append(region_start)
                    curr_sample_All_chroms_coverage_dict[chrom_name][1].append(0)
                curr_sample_All_chroms_coverage_dict[chrom_name][0].append(region_end)
                curr_sample_All_chroms_coverage_dict[chrom_name][1].append(int(float(fields[-1])))
            num_line += 1
        curr_sample_All_chroms_coverage_dict[chrom_name][1].append(0)
        All_Samples_Total_depth.append(cur_sample_total_depth)
        for curr_3UTR_event_id in UTR_events_dict:
            curr_3UTR_structure = UTR_events_dict[curr_3UTR_event_id]
            curr_chr = curr_3UTR_structure[0]
            if curr_chr in curr_sample_All_chroms_coverage_dict:
                curr_chr_coverage = curr_sample_All_chroms_coverage_dict[curr_chr]
                region_start = curr_3UTR_structure[1]
                region_end = curr_3UTR_structure[2]
                left_region_index = bisect(curr_chr_coverage[0],region_start)
                right_region_index = bisect(curr_chr_coverage[0],region_end)

                extracted_coverage = curr_chr_coverage[1][left_region_index:right_region_index+1]
                extracted_3UTR_region = curr_chr_coverage[0][left_region_index:right_region_index]
                extracted_3UTR_region.insert(0,region_start)
                extracted_3UTR_region.append(region_end)
                if curr_3UTR_event_id not in All_samples_extracted_3UTR_coverage_dict:
                    All_samples_extracted_3UTR_coverage_dict[curr_3UTR_event_id] = []
                All_samples_extracted_3UTR_coverage_dict[curr_3UTR_event_id].append([extracted_coverage,extracted_3UTR_region])
    return All_samples_extracted_3UTR_coverage_dict,np.array(All_Samples_Total_depth),UTR_events_dict

# %%
#Load_Target_Wig_files
All_samples_Target_3UTR_coverages, All_samples_sequencing_depths, UTR_events_dict = Load_Target_Wig_files(All_Sample_files, Annotated_3UTR_file)

# %%
#All_samples_Target_3UTR_coverages
len(All_samples_Target_3UTR_coverages)
# Out:
# 1043

# %%
type(All_samples_Target_3UTR_coverages)
# Out:
# dict

# %%
for i in All_samples_Target_3UTR_coverages:
    print(i)
# Out:
# NM_001468|GAGE1|chrX|+
# NM_001012968|SPIN4|chrX|-
# NM_003828|MTMR1|chrX|+
# NM_032967|PCDH11X|chrX|+
# NM_003173|SUV39H1|chrX|+
# NM_003179|SYP|chrX|-
# NM_001081550|THOC2|chrX|-
# NM_014008|CCDC22|chrX|+
# NM_014009|FOXP3|chrX|-
# NR_029379|LOC100132163|chrX|+
# NM_001256188|SNX12|chrX|-
# NM_004312|ARR3|chrX|+
# NR_024062|UBE2DNL|chrX|+
# NM_198881|TBC1D8B|chrX|+
# NM_001105243|PCDH19|chrX|-
# NM_021049|MAGEA5|chrX|-
# NM_005193|CDX4|chrX|+
# NM_033380|COL4A5|chrX|+
# NM_001168361|PCDH11X|chrX|+
# NM_016303|WBP5|chrX|+
# NR_029513|MIR98|chrX|-
# NM_001170570|CXorf56|chrX|-
# NM_001145951|TIMM8A|chrX|-
# NM_020922|WNK3|chrX|-
# NR_038988|LOC100287765|chrX|+
# NM_173493|PASD1|chrX|+
# NM_173495|PTCHD1|chrX|+
# NM_173494|CXorf41|chrX|+
# NM_001017438|CT45A6|chrX|-
# NM_000425|L1CAM|chrX|-
# NM_006743|RBM3|chrX|+
# NR_029708|MIR188|chrX|+
# NR_030233|MIR506|chrX|-
# NR_030230|MIR505|chrX|-
# NR_030236|MIR509-1|chrX|-
# NR_030237|MIR510|chrX|-
# NR_030234|MIR507|chrX|-
# NR_030235|MIR508|chrX|-
# NR_030238|MIR514A1|chrX|-
# NR_030239|MIR514A2|chrX|-
# NM_006520|DYNLT3|chrX|-
# NM_006521|TFE3|chrX|-
# NM_182681|AMELX|chrX|+
# NM_001178099|ZNF182|chrX|-
# NM_024863|TCEAL4|chrX|+
# NM_175569|XG|chrX|+
# NM_001195272|LOC100129520|chrX|+
# NM_172377|CTAG2|chrX|-
# NM_004979|KCND1|chrX|-
# NM_005089|ZRSR2|chrX|+
# NM_032882|PNMA6A|chrX|-
# NM_006044|HDAC6|chrX|+
# NM_001166278|DLG3|chrX|+
# NM_001172285|GLRA4|chrX|-
# NR_036173|MIR514B|chrX|-
# NR_027291|NAP1L6|chrX|-
# NM_006875|PIM2|chrX|-
# NM_004586|RPS6KA3|chrX|-
# NM_001001888|VCX3B|chrX|+
# NM_007052|NOX1|chrX|-
# NM_022144|TNMD|chrX|+
# NM_022148|CRLF2|chrX|-
# NM_017677|MTMR8|chrX|-
# NM_001135995|ATXN3L|chrX|-
# NM_021048|MAGEA10|chrX|-
# NM_018159|NUDT11|chrX|-
# NM_001145346|RBMXL3|chrX|+
# NM_001190255|ZNF630|chrX|-
# NM_206923|YY2|chrX|+
# NM_016267|VGLL1|chrX|+
# NM_007213|PRAF2|chrX|-
# NM_003918|GYG2|chrX|+
# NM_003916|AP1S2|chrX|-
# NM_014499|P2RY10|chrX|+
# NM_001139500|FGF13|chrX|-
# NM_001256743|GRIA3|chrX|+
# NR_037183|SPANXA2-OT1|chrX|+
# NM_021123|GAGE7|chrX|+
# NM_001102576|CSAG1|chrX|+
# NM_001166422|HDAC8|chrX|-
# NM_001166420|HDAC8|chrX|-
# NR_003710|SNORA11C|chrX|+
# NM_002444|MSN|chrX|+
# NR_033460|PAGE3|chrX|-
# NM_000074|CD40LG|chrX|+
# NM_004463|FGD1|chrX|-
# NM_001493|GDI1|chrX|+
# NM_000330|RS1|chrX|-
# NR_029423|MAP2K4P1|chrX|-
# NR_031685|MIR1277|chrX|+
# NR_029427|WDR13|chrX|+
# NM_024082|PRRG3|chrX|+
# NM_001171877|MCF2|chrX|-
# NM_005635|SSX1|chrX|+
# NM_001205103|LOC100509575|chrX|+
# NM_194324|TMSB15B|chrX|+
# NM_001184771|CPXCR1|chrX|+
# NM_001013736|FAM47C|chrX|+
# NM_032803|SLC7A3|chrX|-
# NM_016562|TLR7|chrX|+
# NM_018466|ALG13|chrX|+
# NM_004057|S100G|chrX|+
# NM_001031834|RAB40AL|chrX|+
# NM_005756|GPR64|chrX|-
# NM_001242618|NXT2|chrX|+
# NM_001242614|CD99L2|chrX|-
# NM_032227|TMEM164|chrX|+
# NR_002993|SNORA35|chrX|+
# NM_001114123|ELK1|chrX|-
# NM_000240|MAOA|chrX|+
# NM_012282|KCNE1L|chrX|-
# NM_012286|MORF4L2|chrX|-
# NM_001654|ARAF|chrX|+
# NM_001146257|ZDHHC15|chrX|-
# NM_144967|ARHGAP36|chrX|+
# NM_144969|ZDHHC15|chrX|-
# NM_144968|RIBC1|chrX|+
# NM_021992|TMSB15A|chrX|-
# NM_173358|SSX7|chrX|-
# NM_001130860|HEPH|chrX|+
# NM_018360|TXLNG|chrX|+
# NM_001415|EIF2S3|chrX|+
# NM_001412|EIF1AX|chrX|-
# NR_039980|LOC286437|chrX|-
# NM_138289|ACTRT1|chrX|-
# NM_007150|ZNF185|chrX|+
# NM_007156|ZXDA|chrX|-
# NM_007157|ZXDB|chrX|+
# NR_034031|LOC389906|chrX|-
# NM_001017980|VMA21|chrX|+
# NM_001004051|GPRASP2|chrX|+
# NM_014380|NGFRAP1|chrX|+
# NM_001142389|PNPLA4|chrX|-
# NM_001142386|PDK3|chrX|+
# NM_014927|CNKSR2|chrX|+
# NM_004344|CETN2|chrX|-
# NM_001033583|ACOT9|chrX|-
# NM_001136158|OTUD5|chrX|-
# NM_001136157|OTUD5|chrX|-
# NM_001243197|IQSEC2|chrX|-
# NM_001145718|CT47B1|chrX|-
# NM_016656|RRAGB|chrX|+
# NM_144658|DOCK11|chrX|+
# NM_173523|MAGEB6|chrX|+
# NM_002565|P2RY4|chrX|-
# NR_029946|MIR424|chrX|-
# NM_005032|PLS3|chrX|+
# NM_153834|GPR112|chrX|+
# NR_026742|LOC158572|chrX|-
# NM_020721|KIAA1210|chrX|-
# NM_001128835|TRAPPC2|chrX|-
# NM_080390|TCEAL2|chrX|+
# NM_001847|COL4A6|chrX|-
# NM_052957|ACRC|chrX|+
# NM_004840|ARHGEF6|chrX|-
# NM_000169|GLA|chrX|-
# NM_001122716|CXorf64|chrX|+
# NM_001163335|SYTL5|chrX|+
# NM_001159560|BEX5|chrX|-
# NM_001097642|GJB1|chrX|+
# NM_006201|CDK16|chrX|+
# NM_013271|PCSK1N|chrX|-
# NM_001013845|CXorf40B|chrX|-
# NR_033237|FAM3A|chrX|-
# NM_000640|IL13RA2|chrX|-
# NM_001163279|ODZ1|chrX|-
# NM_022076|DUSP21|chrX|+
# NR_023358|SCARNA9L|chrX|-
# NM_019117|KLHL4|chrX|+
# NM_033085|FATE1|chrX|+
# NM_024122|APOO|chrX|-
# NM_006013|RPL10|chrX|+
# NM_006014|LAGE3|chrX|-
# NM_003069|SMARCA1|chrX|-
# NM_001193281|MID1|chrX|-
# NR_024359|LINC00086|chrX|+
# NM_001184831|VSIG4|chrX|-
# NM_003336|UBE2A|chrX|+
# NM_007003|PAGE4|chrX|+
# NM_133179|XAGE3|chrX|-
# NM_018969|GPR173|chrX|+
# NR_002784|SMEK3P|chrX|-
# NM_206915|NGFRAP1|chrX|+
# NM_206917|NGFRAP1|chrX|+
# NM_000475|NR0B1|chrX|-
# NM_000292|PHKA2|chrX|-
# NM_000291|PGK1|chrX|+
# NM_006733|CENPI|chrX|+
# NR_030241|MIR532|chrX|+
# NR_030240|MIR514A3|chrX|-
# NM_001099856|IKBKG|chrX|+
# NM_014496|RPS6KA6|chrX|-
# NR_033924|CXXC1P1|chrX|+
# NM_203408|FAM47A|chrX|-
# NM_019886|CHST7|chrX|+
# NM_022368|PJA1|chrX|-
# NM_018558|GABRQ|chrX|+
# NM_170750|PSMD10|chrX|-
# NR_029949|MIR18B|chrX|-
# NM_001174068|SYTL4|chrX|-
# NM_017938|FAM70A|chrX|-
# NM_152787|TAB3|chrX|-
# NM_001164415|HSFX2|chrX|+
# NM_001039705|TRO|chrX|+
# NM_153252|BRWD3|chrX|-
# NM_014599|MAGED2|chrX|+
# NM_001177479|HDX|chrX|-
# NM_001177475|MOSPD2|chrX|+
# NM_004065|CDR1|chrX|-
# NR_026975|LOC286467|chrX|-
# NM_001127197|ELF4|chrX|-
# NM_001127199|GAGE12D|chrX|+
# NR_028119|LOC100133957|chrX|+
# NM_006359|SLC9A6|chrX|+
# NM_001134321|FAM127B|chrX|-
# NM_001242640|BRCC3|chrX|+
# NM_080873|ASB11|chrX|-
# NM_080879|RAB40A|chrX|-
# NM_001006639|TCEAL1|chrX|+
# NM_001560|IL13RA1|chrX|+
# NM_001569|IRAK1|chrX|-
# NM_000216|KAL1|chrX|-
# NR_038968|LOC286442|chrX|-
# NM_001142503|STARD8|chrX|+
# NM_012278|ITGB1BP2|chrX|+
# NM_012274|CXorf27|chrX|+
# NM_004187|KDM5C|chrX|-
# NM_004182|UXT|chrX|-
# NR_037414|MIR23C|chrX|-
# NM_178175|LHFPL1|chrX|-
# NM_021637|TMEM35|chrX|+
# NM_005140|CNGA2|chrX|+
# NM_000533|PLP1|chrX|+
# NM_000531|OTC|chrX|+
# NM_000397|CYBB|chrX|+
# NM_000390|CHM|chrX|-
# NM_138702|MAGEC3|chrX|+
# NR_034005|FLJ46446|chrX|+
# NR_030581|MIR891A|chrX|-
# NR_030584|MIR892A|chrX|-
# NR_030586|MIR509-2|chrX|-
# NR_030587|MIR450B|chrX|-
# NR_030589|MIR890|chrX|-
# NR_028407|ARMCX4|chrX|+
# NM_001171689|AMMECR1|chrX|-
# NM_001184727|GPRASP1|chrX|+
# NM_016608|ARMCX1|chrX|+
# NM_001168467|MAP7D2|chrX|-
# NM_153333|TCEAL8|chrX|-
# NM_003399|XPNPEP2|chrX|+
# NM_001098843|CXorf30|chrX|+
# NM_174869|IDH3G|chrX|-
# NM_004606|TAF1|chrX|+
# NM_006603|STAG2|chrX|+
# NM_023934|FUNDC2|chrX|+
# NM_001099921|MAGEB16|chrX|+
# NM_001098412|GAGE13|chrX|+
# NM_001170761|SRPK3|chrX|+
# NR_024493|LINC00087|chrX|-
# NR_024499|FMR1-AS1|chrX|-
# NM_020717|SHROOM4|chrX|-
# NM_001145933|TKTL1|chrX|+
# NR_002969|SNORA36A|chrX|+
# NM_001013628|DCAF12L2|chrX|-
# NM_001013627|NHSL2|chrX|+
# NM_003372|VBP1|chrX|+
# NM_014728|FRMPD4|chrX|+
# NM_001171020|MUM1L1|chrX|+
# NM_181532|ERAS|chrX|+
# NM_002764|PRPS1|chrX|+
# NM_002765|PRPS2|chrX|+
# NM_001448|GPC4|chrX|-
# NM_032946|NXF5|chrX|-
# NM_003159|CDKL5|chrX|+
# NM_001032289|SLC35A2|chrX|-
# NM_001171184|DRP2|chrX|+
# NM_001171186|FAM9A|chrX|-
# NR_026551|CA5BP1|chrX|+
# NM_152226|PPEF1|chrX|+
# NR_045864|ARMCX4|chrX|+
# NR_045863|ARMCX4|chrX|+
# NM_207672|GRIPAP1|chrX|-
# NM_133265|AMOT|chrX|-
# NM_002049|GATA1|chrX|+
# NM_001145408|NONO|chrX|+
# NR_036256|MIR4330|chrX|+
# NR_036257|MIR500B|chrX|+
# NR_036255|MIR4329|chrX|-
# NM_001078171|FAM127A|chrX|+
# NM_001078172|FAM127B|chrX|-
# NM_001078173|FAM127C|chrX|-
# NM_152424|FAM123B|chrX|-
# NR_027444|LOC100133957|chrX|+
# NM_013452|VCX|chrX|+
# NM_013453|SPANXA1|chrX|+
# NM_001006614|WBP5|chrX|+
# NM_015129|SEPT6|chrX|-
# NM_012471|TRPC5|chrX|-
# NM_001173486|PRRG1|chrX|+
# NM_001173480|ARHGEF9|chrX|-
# NM_198456|FAM120C|chrX|-
# NM_198450|APOOL|chrX|+
# NM_198451|FOXR2|chrX|+
# NM_001325|CSTF2|chrX|+
# NM_004135|IDH3G|chrX|-
# NM_080612|GAB3|chrX|-
# NM_001110556|FLNA|chrX|-
# NM_004794|RAB33A|chrX|+
# NM_019597|HNRNPH2|chrX|+
# NM_052926|PNMA5|chrX|-
# NM_001356|DDX3X|chrX|+
# NM_174901|FAM9C|chrX|-
# NM_004729|ZBED1|chrX|-
# NM_000402|G6PD|chrX|-
# NR_026694|ZCCHC18|chrX|+
# NM_057162|KLHL4|chrX|+
# NR_033974|DKFZp686D0853|chrX|+
# NR_027250|SSX8|chrX|+
# NM_021183|RAP2C|chrX|-
# NM_018990|SASH3|chrX|+
# NM_171998|RAB39B|chrX|-
# NM_001195214|YIPF6|chrX|+
# NM_016383|LUZP4|chrX|+
# NM_032512|PDZD4|chrX|-
# NR_030399|MIR542|chrX|-
# NM_001171109|FAM133A|chrX|+
# NM_001127200|GAGE2E|chrX|+
# NR_029484|MIRLET7F2|chrX|-
# NM_024539|RNF128|chrX|+
# NM_001004308|ZCCHC16|chrX|+
# NM_182506|MAGEB10|chrX|+
# NM_058163|TSR2|chrX|+
# NM_015686|FAM155B|chrX|+
# NM_000052|ATP7A|chrX|+
# NM_013364|PNMA3|chrX|+
# NR_030629|MIR509-3|chrX|-
# NM_002362|MAGEA4|chrX|+
# NM_002364|MAGEB2|chrX|+
# NM_002365|MAGEB3|chrX|+
# NM_001031855|LONRF3|chrX|+
# NM_007075|WDR45|chrX|-
# NM_006306|SMC1A|chrX|-
# NM_006307|SRPX|chrX|-
# NM_001185076|FMR1|chrX|+
# NR_024440|LOC729609|chrX|-
# NM_001080790|MAGEA9B|chrX|-
# NR_031748|MIR2114|chrX|+
# NM_001178032|ZC4H2|chrX|-
# NM_021109|TMSB4X|chrX|+
# NM_001142797|CXCR3|chrX|-
# NM_012227|GTPBP6|chrX|-
# NM_006915|RP2|chrX|+
# NM_004208|AIFM1|chrX|-
# NM_001159703|FHL1|chrX|+
# NM_030763|HMGN5|chrX|-
# NM_139019|SPANXF1|chrX|+
# NM_198057|TSC22D3|chrX|-
# NM_018301|RBM41|chrX|-
# NM_004992|MECP2|chrX|-
# NM_001167989|PQBP1|chrX|+
# NM_138737|HEPH|chrX|+
# NM_001007524|F8A3|chrX|+
# NM_001011719|ARSH|chrX|+
# NM_022661|SPANXC|chrX|-
# NM_024921|POF1B|chrX|-
# NM_001105576|SOWAHD|chrX|+
# NM_001110792|MECP2|chrX|-
# NM_014522|PCDH11X|chrX|+
# NM_001257403|VSIG4|chrX|-
# NM_005636|SSX4|chrX|+
# NM_005634|SOX3|chrX|-
# NM_032591|SLC9A7|chrX|-
# NM_138703|MAGEE2|chrX|-
# NM_015698|GPKOW|chrX|-
# NM_015691|WWC3|chrX|+
# NM_212559|XKRX|chrX|-
# NM_012084|GLUD2|chrX|+
# NM_001004486|OR13H1|chrX|+
# NR_003007|SCARNA23|chrX|+
# NM_001013579|AWAT1|chrX|+
# NM_001009613|SPANXN4|chrX|+
# NM_001009615|SPANXN2|chrX|-
# NM_001009614|SPANXN1|chrX|+
# NM_001009616|SPANXN5|chrX|-
# NM_000266|NDP|chrX|-
# NM_001077188|HS6ST2|chrX|-
# NM_031273|TEX13B|chrX|-
# NM_031274|TEX13A|chrX|-
# NM_031276|TEX11|chrX|-
# NM_001170961|IGSF1|chrX|-
# NR_030737|TTC3P1|chrX|-
# NM_017711|GDPD2|chrX|+
# NM_001039840|CHIC1|chrX|+
# NM_001475|GAGE5|chrX|+
# NM_001476|GAGE6|chrX|+
# NM_001472|GAGE2C|chrX|+
# NM_007137|ZNF81|chrX|+
# NM_007130|ZNF41|chrX|-
# NM_007131|ZNF75D|chrX|-
# NM_001012979|TCEAL5|chrX|-
# NM_001012977|PABPC1L2A|chrX|-
# NM_001128127|GK|chrX|+
# NM_001010888|ZC3H12B|chrX|+
# NM_001098411|GAGE2B|chrX|+
# NM_001098413|GAGE10|chrX|+
# NM_001256197|ARAF|chrX|+
# NM_001184797|TMLHE|chrX|-
# NM_152274|FAM58A|chrX|-
# NM_152278|TCEAL7|chrX|+
# NM_020871|LRCH2|chrX|-
# NM_205849|FAM9B|chrX|-
# NM_002547|OPHN1|chrX|-
# NM_177439|FTSJ1|chrX|+
# NM_004651|USP11|chrX|+
# NM_015975|TAF9B|chrX|-
# NR_031581|MIR764|chrX|+
# NM_007309|DIAPH2|chrX|+
# NM_130467|PAGE5|chrX|+
# NM_020932|MAGEE1|chrX|+
# NR_038998|LOC100506757|chrX|+
# NM_001042498|SLC35A2|chrX|-
# NM_175711|SSX3|chrX|-
# NM_032498|RHOXF2|chrX|+
# NM_002668|PLP2|chrX|+
# NM_001363|DKC1|chrX|+
# NM_001587|OCRL|chrX|+
# NR_030224|MIR500A|chrX|+
# NR_030225|MIR501|chrX|+
# NR_030227|MIR450A2|chrX|-
# NR_030226|MIR502|chrX|+
# NR_030229|MIR504|chrX|-
# NR_030228|MIR503|chrX|-
# NM_182699|DDX53|chrX|+
# NR_046101|CXorf31|chrX|-
# NM_145799|SEPT6|chrX|-
# NM_024859|MAGIX|chrX|+
# NM_001039590|USP9X|chrX|+
# NM_153448|ESX1|chrX|-
# NR_033941|LOC100129515|chrX|-
# NM_001256447|BCAP31|chrX|-
# NM_001289|CLIC2|chrX|-
# NR_015378|LOC401588|chrX|+
# NM_001163257|PLXNB3|chrX|+
# NM_022052|NXF3|chrX|-
# NM_022053|NXF2|chrX|+
# NM_001173517|MAP7D3|chrX|-
# NM_016378|VCX2|chrX|-
# NM_016379|VCX3A|chrX|-
# NR_029521|MIR105-1|chrX|-
# NM_000061|BTK|chrX|-
# NR_027419|AVPR2|chrX|+
# NM_002351|SH2D1A|chrX|+
# NM_014289|CAPN6|chrX|-
# NM_001173456|PDHA1|chrX|+
# NM_001177465|MAMLD1|chrX|+
# NM_004595|SMS|chrX|+
# NM_032121|MAGT1|chrX|-
# NM_017666|ZNF280C|chrX|-
# NM_017669|ERCC6L|chrX|-
# NR_002226|INGX|chrX|-
# NM_178813|AKAP14|chrX|+
# NM_173794|FUNDC1|chrX|-
# NM_173798|ZCCHC12|chrX|+
# NM_145664|SPANXB2|chrX|+
# NM_145662|SPANXA2|chrX|-
# NM_032417|SPANXD|chrX|-
# NM_012151|F8A1|chrX|+
# NM_001504|CXCR3|chrX|-
# NM_007220|CA5B|chrX|+
# NM_001032726|RAB41|chrX|+
# NM_012216|MID2|chrX|+
# NM_033215|PPP1R3F|chrX|+
# NM_004085|TIMM8A|chrX|-
# NM_001195081|LOC100288814|chrX|+
# NM_005834|TIMM17B|chrX|-
# NM_003785|PAGE1|chrX|-
# NM_015507|EGFL6|chrX|+
# NR_029962|MIR450A1|chrX|-
# NM_004493|HSD17B10|chrX|-
# NR_028366|SSX6|chrX|+
# NM_015884|MBTPS2|chrX|+
# NR_039991|LOC100507404|chrX|+
# NM_001017930|DCAF8L1|chrX|-
# NR_024608|LOC442459|chrX|-
# NR_024607|MGC16121|chrX|-
# NM_001184742|ZBTB33|chrX|+
# NM_178470|DCAF12L1|chrX|-
# NM_178471|GPR119|chrX|-
# NM_018476|BEX1|chrX|-
# NM_005660|SLC35A2|chrX|-
# NR_028379|FTX|chrX|-
# NM_004043|ASMT|chrX|+
# NM_004042|ARSF|chrX|+
# NM_006375|ENOX2|chrX|-
# NM_001122606|LAMP2|chrX|-
# NR_031578|MIR1298|chrX|+
# NM_021796|PLAC1|chrX|-
# NM_001136273|ZFP92|chrX|+
# NM_005462|MAGEC1|chrX|+
# NM_001144064|CXorf51A|chrX|+
# NR_002984|SNORA56|chrX|+
# NM_139282|RHOXF1|chrX|-
# NM_139289|AKAP4|chrX|-
# NR_029852|MIR363|chrX|-
# NM_001080848|CSAG2|chrX|+
# NM_025184|EFHC2|chrX|-
# NM_001017417|CT45A1|chrX|+
# NM_001171136|ZBED1|chrX|-
# NM_173695|CXorf59|chrX|+
# NM_173694|ATP11C|chrX|-
# NM_173699|MAGEB18|chrX|+
# NM_078628|MSL3|chrX|+
# NM_019003|SPIN2A|chrX|-
# NM_178129|P2RY8|chrX|-
# NR_038461|LOC100128420|chrX|+
# NM_018977|NLGN3|chrX|+
# NM_001031745|RIBC1|chrX|+
# NM_003868|FGF16|chrX|+
# NM_001079900|SPACA5B|chrX|+
# NM_152761|CXorf58|chrX|+
# NM_001142395|PRRG1|chrX|+
# NM_001142392|SLC10A3|chrX|-
# NM_001142391|SLC10A3|chrX|-
# NM_000206|IL2RG|chrX|-
# NM_205833|IGSF1|chrX|-
# NM_130775|XAGE5|chrX|+
# NM_130777|XAGE2|chrX|+
# NM_001146702|KDM5C|chrX|-
# NM_006667|PGRMC1|chrX|+
# NM_006089|SCML2|chrX|-
# NM_014235|UBL4A|chrX|-
# NM_001143983|CHRDL1|chrX|-
# NM_001170704|MBNL3|chrX|-
# NM_001195576|LOC100329135|chrX|+
# NM_017856|GEMIN8|chrX|-
# NM_175723|SSX5|chrX|-
# NM_145119|PJA1|chrX|-
# NM_001144886|CITED1|chrX|-
# NM_001163322|CCDC120|chrX|+
# NM_001163323|CCDC120|chrX|+
# NM_152692|C1GALT1C1|chrX|-
# NM_152694|ZCCHC5|chrX|-
# NM_152695|ZNF449|chrX|+
# NR_028597|SRD5A1P1|chrX|+
# NM_001034853|RPGR|chrX|-
# NM_001136533|DCAF8L2|chrX|+
# NM_031407|HUWE1|chrX|-
# NM_138270|ATRX|chrX|-
# NM_000377|WAS|chrX|+
# NM_032926|TCEAL3|chrX|+
# NM_001037968|ALAS2|chrX|-
# NM_018094|GSPT2|chrX|+
# NM_006729|DIAPH2|chrX|+
# NM_006579|EBP|chrX|+
# NM_001011657|ZMAT1|chrX|-
# NM_003611|OFD1|chrX|+
# NM_021083|XK|chrX|+
# NR_024501|FMR1-AS1|chrX|-
# NM_153183|NUDT10|chrX|+
# NM_145177|DHRSX|chrX|-
# NM_001029891|PGAM4|chrX|-
# NM_012317|LDOC1|chrX|-
# NM_012310|KIF4A|chrX|+
# NM_001129898|ZNF673|chrX|+
# NM_005044|PRKX|chrX|-
# NM_015922|NSDHL|chrX|+
# NM_001164416|H2BFM|chrX|+
# NM_024689|CXorf36|chrX|-
# NM_001139467|TBL1X|chrX|+
# NM_001170781|FAM122C|chrX|+
# NM_001170782|FAM122C|chrX|+
# NM_001170783|FAM122C|chrX|+
# NM_004541|NDUFA1|chrX|+
# NM_080632|UPF3B|chrX|-
# NM_000898|MAOB|chrX|-
# NR_002216|NXF4|chrX|+
# NM_003270|TSPAN6|chrX|-
# NM_018196|TMLHE|chrX|-
# NM_005361|MAGEA2|chrX|+
# NM_005362|MAGEA3|chrX|-
# NM_005365|MAGEA9|chrX|+
# NM_005367|MAGEA12|chrX|-
# NM_005366|MAGEA11|chrX|+
# NM_004709|CXorf1|chrX|+
# NM_001080489|GLOD5|chrX|+
# NM_001080485|ZNF275|chrX|+
# NM_014467|SRPX2|chrX|+
# NM_001101357|CCDC160|chrX|+
# NM_001170628|AFF2|chrX|+
# NM_001199972|RPL36A|chrX|+
# NM_001166462|MPP1|chrX|-
# NM_138960|TGIF2LX|chrX|+
# NR_029955|MIR448|chrX|+
# NR_029950|MIR20B|chrX|-
# NM_001183|ATP6AP1|chrX|+
# NR_002584|SNORA69|chrX|-
# NM_001171163|ZMYM3|chrX|-
# NM_001171162|ZMYM3|chrX|-
# NM_152869|RGN|chrX|+
# NM_001031705|CXorf48|chrX|-
# NR_024582|JPX|chrX|+
# NM_001145139|CXorf49B|chrX|+
# NM_207339|PAGE2|chrX|+
# NM_000033|ABCD1|chrX|+
# NM_016521|TFDP3|chrX|-
# NM_013347|RPA4|chrX|+
# NM_001171706|RIPPLY1|chrX|-
# NM_001080975|REPS2|chrX|+
# NM_004019|DMD|chrX|-
# NM_001032384|PQBP1|chrX|+
# NM_001163438|CXorf69|chrX|+
# NM_203303|ZCCHC13|chrX|+
# NM_001168300|KLHL13|chrX|-
# NM_175859|CTPS2|chrX|-
# NR_002735|SNORD61|chrX|-
# NR_033670|ARMCX6|chrX|-
# NR_045260|LOC100133123|chrX|+
# NM_001551|IGBP1|chrX|+
# NM_007250|KLF8|chrX|+
# NM_003951|SLC25A14|chrX|+
# NR_038978|LOC340544|chrX|+
# NM_006123|IDS|chrX|-
# NM_006125|ARHGAP6|chrX|-
# NM_001167|XIAP|chrX|+
# NR_030413|MIR766|chrX|-
# NM_004192|ASMTL|chrX|-
# NM_006978|RNF113A|chrX|-
# NM_004229|MED14|chrX|-
# NM_004224|GPR50|chrX|+
# NM_025159|CXorf21|chrX|-
# NM_001024452|GLRA4|chrX|-
# NM_001024455|RGAG4|chrX|-
# NM_001204526|SSR4|chrX|+
# NM_016024|RBMX2|chrX|+
# NM_031907|USP26|chrX|-
# NM_004429|EFNB1|chrX|+
# NM_001166700|FAM104B|chrX|-
# NM_024597|MAP7D3|chrX|-
# NM_001163280|HTATSF1|chrX|+
# NR_030593|MIR892B|chrX|-
# NR_030592|MIR888|chrX|-
# NR_030590|MIR891B|chrX|-
# NM_001097594|XAGE1B|chrX|+
# NM_001097596|XAGE1B|chrX|-
# NM_001097598|XAGE1C|chrX|+
# NM_177456|MAGEC3|chrX|+
# NR_033742|FRMD8P1|chrX|-
# NR_037842|LINC00102|chrX|-
# NM_016937|POLA1|chrX|+
# NM_006639|CYSLTR1|chrX|-
# NR_029635|MIR221|chrX|-
# NR_029636|MIR222|chrX|-
# NR_029637|MIR223|chrX|+
# NM_024657|MORC4|chrX|-
# NR_027783|SAT1|chrX|+
# NM_001137554|MCTS1|chrX|+
# NR_027121|SHROOM4|chrX|-
# NM_001170757|FAM122B|chrX|-
# NM_001170756|FAM122B|chrX|-
# NM_001139515|DACH2|chrX|+
# NM_020769|RGAG1|chrX|+
# NM_001145073|USP27X|chrX|+
# NR_002953|SNORA11|chrX|+
# NM_017863|CXorf48|chrX|-
# NM_001195522|LOC347411|chrX|+
# NM_000828|GRIA3|chrX|+
# NM_001193270|MSL3|chrX|+
# NM_001193277|MID1|chrX|-
# NM_001127899|CLCN5|chrX|+
# NM_181313|TAZ|chrX|+
# NM_001170944|PNMA6C|chrX|+
# NM_006406|PRDX4|chrX|+
# NM_019056|NDUFB11|chrX|-
# NR_003238|H2BFXP|chrX|+
# NM_000328|RPGR|chrX|-
# NM_021998|ZNF711|chrX|+
# NM_003147|SSX2|chrX|+
# NM_002893|RBBP7|chrX|-
# NM_176819|CXorf36|chrX|-
# NM_001152|SLC25A5|chrX|+
# NM_020061|OPN1LW|chrX|+
# NR_026545|APOO|chrX|-
# NM_001142805|SLC6A8|chrX|+
# NM_030624|KLHL15|chrX|-
# NM_001145414|CHM|chrX|-
# NM_001162936|CXorf68|chrX|-
# NR_031563|MIR1264|chrX|+
# NR_031567|MIR1468|chrX|-
# NM_002910|RENBP|chrX|-
# NM_153280|UBA1|chrX|+
# NM_001123384|BCOR|chrX|-
# NM_013444|UBQLN2|chrX|+
# NM_004538|NAP1L3|chrX|-
# NM_016153|HSFX1|chrX|+
# NM_016157|TRO|chrX|+
# NM_016484|PDZD11|chrX|-
# NM_017681|NUP62CL|chrX|-
# NM_002641|PIGA|chrX|-
# NM_174912|FAAH2|chrX|+
# NM_001178086|ZFX|chrX|+
# NM_001170650|LAS1L|chrX|-
# NM_021963|NAP1L2|chrX|-
# NM_001166418|HDAC8|chrX|-
# NM_178153|DCX|chrX|-
# NM_001010862|SPIN3|chrX|-
# NM_013239|PPP2R3B|chrX|-
# NM_003491|NAA10|chrX|-
# NM_003492|TMEM187|chrX|+
# NM_020137|GRIPAP1|chrX|-
# NM_005765|ATP6AP2|chrX|+
# NR_029909|MIR384|chrX|-
# NM_004961|GABRE|chrX|-
# NM_001017436|CT45A4|chrX|+
# NM_001127212|GAGE2A|chrX|+
# NR_015353|LOC92249|chrX|-
# NM_020384|CLDN2|chrX|+
# NM_001711|BGN|chrX|+
# NM_000047|ARSE|chrX|-
# NM_000044|AR|chrX|+
# NM_001013742|DGKK|chrX|-
# NM_021140|KDM6A|chrX|+
# NM_003022|SH3BGRL|chrX|+
# NM_004020|DMD|chrX|-
# NM_001184874|GPRASP2|chrX|+
# NM_020994|CTAG2|chrX|-
# NM_005334|HCFC1|chrX|-
# NM_005333|HCCS|chrX|+
# NM_001522|GUCY2F|chrX|-
# NM_001193280|MID1|chrX|-
# NR_031732|MIR1911|chrX|+
# NR_031733|MIR1912|chrX|+
# NM_152632|CXorf22|chrX|+
# NM_152634|TCEANC|chrX|+
# NM_080720|H2AFB3|chrX|+
# NM_003413|ZIC3|chrX|+
# NR_038405|LOC100129662|chrX|+
# NM_003886|AKAP4|chrX|-
# NR_028345|RP1-177G6.2|chrX|+
# NR_028344|RP1-177G6.2|chrX|+
# NM_000686|AGTR2|chrX|+
# NM_001012989|UBE2NL|chrX|+
# NM_001145149|VAMP7|chrX|+
# NM_001184767|BEND2|chrX|-
# NM_001184768|ARMCX6|chrX|-
# NM_001195328|RAB9A|chrX|+
# NM_001005613|EDA|chrX|+
# NM_003604|IRS4|chrX|-
# NM_001098800|MAGED4|chrX|+
# NR_026935|LOC158696|chrX|-
# NM_054021|GPR101|chrX|-
# NM_198279|CXorf23|chrX|-
# NM_198270|NHS|chrX|+
# NM_022567|NYX|chrX|+
# NM_001130997|FAM58A|chrX|-
# NM_005448|BMP15|chrX|+
# NM_080832|PABPC5|chrX|+
# NM_001144003|SLITRK2|chrX|+
# NM_001144004|SLITRK2|chrX|+
# NM_001009609|SPANXN3|chrX|-
# NM_000252|MTM1|chrX|+
# NM_006150|PRICKLE3|chrX|-
# NM_019556|MOSPD1|chrX|-
# NM_001395|DUSP9|chrX|+
# NM_001399|EDA|chrX|+
# NM_001649|SHROOM2|chrX|+
# NM_144970|CXorf38|chrX|-
# NM_000117|EMD|chrX|+
# NM_001001994|GPM6B|chrX|-
# NM_001001995|GPM6B|chrX|-
# NM_001080139|CT47A8|chrX|-
# NM_001080137|CT47A10|chrX|-
# NM_152582|CT45A2|chrX|+
# NM_153270|KLHL34|chrX|-
# NM_005183|CACNA1F|chrX|-
# NR_028443|SLC25A5-AS1|chrX|-
# NM_001017991|H2AFB2|chrX|+
# NM_001098408|GAGE12C|chrX|+
# NM_001098409|GAGE12G|chrX|+
# NM_001098406|GAGE12J|chrX|+
# NM_001098407|GAGE2D|chrX|+
# NM_014061|MAGEH1|chrX|+
# NM_021804|ACE2|chrX|-
# NM_205856|SPACA5|chrX|+
# NM_021029|RPL36A|chrX|+
# NM_001042506|PABPC1L2B|chrX|+
# NM_003688|CASK|chrX|-
# NR_033717|SCML2|chrX|-
# NM_177404|MAGEB1|chrX|+
# NM_001178135|HDHD1|chrX|-
# NM_001830|CLCN4|chrX|+
# NM_001012288|CRLF2|chrX|-
# NM_015419|MXRA5|chrX|-
# NM_001146151|AVPR2|chrX|+
# NM_000194|HPRT1|chrX|+
# NR_030785|MIR374A|chrX|-
# NM_001039582|PNCK|chrX|-
# NM_000351|STS|chrX|+
# NM_000354|SERPINA7|chrX|-
# NM_001166448|HDAC8|chrX|-
# NM_001048181|OPN1MW2|chrX|+
# NM_013995|LAMP2|chrX|-
# NM_001002254|AWAT2|chrX|-
# NR_026595|LINC00246A|chrX|-
# NR_015367|LOC550643|chrX|+
# NM_001163265|PCYT1B|chrX|-
# NM_001163264|PCYT1B|chrX|-
# NM_201286|USP51|chrX|-
# NM_182541|TMEM31|chrX|+
# NM_182540|DDX26B|chrX|+
# NM_033670|CCNB3|chrX|+
# NM_001097579|GPR34|chrX|+
# NM_001727|BRS3|chrX|+
# NM_001721|BMX|chrX|+
# NM_017413|APLN|chrX|-
# NM_017416|IL1RAPL2|chrX|+
# NR_027402|LINC00204B|chrX|+
# NM_001142527|BHLHB9|chrX|+
# NM_016120|RLIM|chrX|-
# NM_001242922|CT47A12|chrX|-
# NM_003254|TIMP1|chrX|+
# NM_032796|SYAP1|chrX|+
# NM_005342|HMGB3|chrX|+
# NM_000444|PHEX|chrX|+
# NM_016249|MAGEC2|chrX|-
# NR_030397|MIR660|chrX|+
# NM_007231|SLC6A14|chrX|+
# NM_006517|SLC16A2|chrX|+
# NR_030398|MIR421|chrX|-
# NR_030258|MIR545|chrX|-
# NM_014481|APEX2|chrX|+
# NM_152630|FAM46D|chrX|+
# NM_152631|FAM47B|chrX|+
# NM_152633|FANCB|chrX|-
# NM_001256760|HTR2C|chrX|+
# NM_203474|PORCN|chrX|+
# NM_198511|LANCL3|chrX|+
# NM_198510|ITIH6|chrX|-
# NM_001190708|MTRNR2L10|chrX|-
# NM_001166401|MAGEA8|chrX|+
# NR_029973|MIR452|chrX|-
# NR_024616|INE1|chrX|+
# NM_020665|TMEM27|chrX|-
# NM_207318|FAM199X|chrX|+
# NM_001184750|SLITRK4|chrX|-
# NM_138636|TLR8|chrX|+
# NM_016954|TBX22|chrX|+
# NM_001000|RPL39|chrX|-
# NM_004699|FAM50A|chrX|+
# NM_173470|MMGT1|chrX|-
# NM_021785|RAI2|chrX|-
# NM_021783|EDA2R|chrX|-
# NM_001172732|RAI2|chrX|-
# NR_002718|TDGF1P3|chrX|+
# NM_017514|PLXNA3|chrX|+
# NM_017518|HAUS7|chrX|-
# NM_001168649|CNKSR2|chrX|+
# NM_001080425|BEX4|chrX|+
# NM_001098791|MID1IP1|chrX|+
# NM_001099680|MAGIX|chrX|+
# NM_001099686|NXF2B|chrX|-
# NM_001099685|RHOXF2B|chrX|+
# NM_001099684|FAM156B|chrX|+
# NM_006950|SYN1|chrX|-
# NM_001636|SLC25A6|chrX|-
# NM_001080851|DMRTC1B|chrX|+
# NM_181332|NLGN4X|chrX|-
# NM_001184966|WDR44|chrX|+
# NM_152578|FMR1NB|chrX|+
# NM_152577|ZNF645|chrX|+
# NM_017752|TBC1D8B|chrX|+
# NM_003446|ZNF157|chrX|+
# NM_139058|ARX|chrX|-
# NM_012069|ATP1B4|chrX|+
# NM_001174092|TMEM185A|chrX|-
# NM_001128167|PAK3|chrX|+
# NR_028477|RBMX|chrX|-
# NM_001256155|ARMCX4|chrX|+
# NM_001006683|SPIN2B|chrX|-
# NM_198512|DGAT2L6|chrX|+
# NM_001135565|HDHD1|chrX|-
# NR_024033|IL9R|chrX|+
# NM_207422|FLJ44635|chrX|+
# NM_133499|SYN1|chrX|-
# NM_016500|CXorf26|chrX|+
# NM_001204468|RBM10|chrX|+
# NR_045617|SMPX|chrX|-
# NM_001168474|TAF7L|chrX|-
# NM_021014|SSX3|chrX|-
# NR_002309|RPS26P11|chrX|+
# NR_002308|UQCRBP1|chrX|-
# NM_002367|MAGEB4|chrX|+
# NR_029509|MIR92A2|chrX|-
# NM_001146291|ZNF674|chrX|-
# NM_004615|TSPAN7|chrX|+
# NM_001006682|SPIN2B|chrX|-
# NM_001143978|ZCCHC18|chrX|+
# NM_001170779|FAM122C|chrX|+
# NM_001184898|PHF8|chrX|-
# NM_001184897|PHF8|chrX|-
# NM_001184896|PHF8|chrX|-
# NM_001190417|ZNF674|chrX|-
# NM_017848|FAM120C|chrX|-
# NM_001866|COX7B|chrX|+
# NM_001164803|RBMX|chrX|-
# NM_000808|GABRA3|chrX|-
# NM_014735|PHF16|chrX|+
# NM_001327|CTAG1B|chrX|-
# NM_012196|GAGE8|chrX|+
# NM_001080146|CT47A1|chrX|-
# NM_001080142|CT47A5|chrX|-
# NM_001080140|CT47A7|chrX|-
# NR_030774|UPRT|chrX|+
# NM_181673|OGT|chrX|+
# NR_039925|MIR4768|chrX|+
# NR_039924|MIR4767|chrX|+
# NR_039926|MIR4769|chrX|+
# NR_003255|TSIX|chrX|+
# NM_153488|MAGEA2B|chrX|+
# NM_000307|POU3F4|chrX|+
# NM_006223|PIN4|chrX|+
# NM_001015877|PHF6|chrX|+
# NM_001172436|PHKA1|chrX|-
# NR_033212|CXorf65|chrX|-
# NM_145802|SEPT6|chrX|-
# NM_001006937|TCEAL4|chrX|+
# NM_001006938|TCEAL6|chrX|-
# NR_027761|LOC100132831|chrX|-
# NM_032553|GPR174|chrX|+
# NM_001018024|MTCP1NB|chrX|-
# NM_001018025|MTCP1|chrX|-
# NM_016370|RAB9B|chrX|-
# NR_029522|MIR105-2|chrX|-
# NR_029523|MIR106A|chrX|-
# NR_034116|LOC100129407|chrX|+
# NR_037494|MIR676|chrX|+
# NR_027456|LOC100272228|chrX|+
# NR_027455|LOC100131434|chrX|-
# NM_013427|ARHGAP6|chrX|-
# NM_153346|BEND2|chrX|-
# NM_001162491|ARL13A|chrX|+
# NM_001162490|ARL13A|chrX|+
# NM_198465|NRK|chrX|+
# NM_145305|SLC25A43|chrX|+
# NM_001184819|GNL3L|chrX|+
# NM_001168531|ASB9|chrX|-
# NM_001042453|MST4|chrX|+
# NM_001168399|BEX2|chrX|-
# NR_002191|PPP1R2P9|chrX|-
# NM_032458|PHF6|chrX|+
# NR_001559|VENTXP1|chrX|+
# NM_002625|PFKFB1|chrX|-
# NM_002621|CFP|chrX|-
# NM_005938|FOXO4|chrX|+
# NM_052936|ATG4A|chrX|+
# NM_018015|CXorf57|chrX|+
# NR_028089|NXF5|chrX|-
# NM_001164619|GPC3|chrX|-
# NM_005300|GPR34|chrX|+
# NM_021949|ATP2B3|chrX|+
# NM_021946|BCORL1|chrX|+
# NM_002294|LAMP2|chrX|-
# NR_030380|MIR651|chrX|+
# NR_029491|MIR19B2|chrX|-
# NM_001111125|IQSEC2|chrX|-
# NM_024528|NKAP|chrX|-
# NM_207320|OTUD6A|chrX|+
# NM_032335|PHF6|chrX|+
# NM_001168482|ARMCX5|chrX|+
# NM_001079872|CUL4B|chrX|-
# NR_030631|MIR934|chrX|+
# NM_001166221|UTP14A|chrX|+
# NM_001009933|DNASE1L1|chrX|-
# NM_194277|FRMD7|chrX|-
# NM_001032396|PJA1|chrX|-
# NM_022117|TSPYL2|chrX|+
# NM_175868|MAGEA6|chrX|+
# NR_003539|LOC643486|chrX|-
# NM_001136233|FAM48B2|chrX|-
# NM_001136234|FAM48B1|chrX|+
# NM_031892|SH3KBP1|chrX|-
# NM_031894|FTHL17|chrX|-
# NM_005314|GRPR|chrX|+
# NM_001008537|KIAA2022|chrX|-
# NM_001008535|AKAP14|chrX|+
# NR_004379|SNORD96B|chrX|-
# NM_007268|VSIG4|chrX|-
# NM_017544|NKRF|chrX|-
# NR_000011|SNORA70|chrX|+
# NR_031757|MIR718|chrX|-
# NR_030409|MIR767|chrX|-
# NM_001166699|FAM104B|chrX|-
# NM_177948|ARMCX3|chrX|+
# NM_018666|SAGE1|chrX|+
# NM_014782|ARMCX2|chrX|-
# NM_021118|CYLC1|chrX|+
# NM_001002916|H2BFWT|chrX|-
# NM_001242319|PNMA6D|chrX|+
# NM_080701|TREX2|chrX|-
# NM_001171080|RBM41|chrX|-
# NM_016032|ZDHHC9|chrX|-
# NR_039774|MIR3978|chrX|+
# NM_033518|SLC38A5|chrX|-
# NR_038428|CXorf28|chrX|+
# NM_005296|LPAR4|chrX|+
# NM_005120|MED12|chrX|+
# NM_004458|ACSL4|chrX|-
# NM_000513|OPN1MW|chrX|+
# NM_004988|MAGEA1|chrX|-
# NM_001007551|CT45A5|chrX|-
# NM_001017978|CXorf61|chrX|-
# NM_024917|TRMT2B|chrX|-
# NM_001166550|IDS|chrX|-
# NM_003662|PIR|chrX|-
# NM_002536|TBC1D25|chrX|+
# NR_037859|PIR-FIGF|chrX|-
# NM_001037535|SCML1|chrX|+
# NR_033772|CENPVL1|chrX|+
# NM_001013403|CXorf66|chrX|-
# NM_001012755|SLC25A53|chrX|-
# NM_001171909|CXorf40A|chrX|+
# NM_001171908|CXorf40A|chrX|+
# NM_014271|IL1RAPL1|chrX|+
# NR_027139|SPIN3|chrX|-
# NR_027131|NKAPP1|chrX|-
# NM_001170747|PIN4|chrX|+
# NM_080817|GPR82|chrX|+
# NM_005391|PDK3|chrX|+
# NM_001015038|PAGE2B|chrX|+
# NM_001007|RPS4X|chrX|-
# NM_130388|ASB12|chrX|-
# NM_000273|GPR143|chrX|-
# NM_001171581|ITM2A|chrX|-
# NM_006986|MAGED1|chrX|+
# NM_001669|ARSD|chrX|-
# NM_004299|ABCB7|chrX|-
# NM_001666|ARHGAP4|chrX|-
# NM_000133|F9|chrX|+
# NM_000132|F8|chrX|-
# NR_030727|TLR8-AS1|chrX|-
# NM_001171942|GLRA2|chrX|+
# NM_182607|VSIG1|chrX|+
# NM_031442|TMEM47|chrX|-
# NR_033124|ALG13|chrX|+

# %%
#All_samples_sequencing_depths
All_samples_sequencing_depths
# Out:
# array([475249457, 453111546])

# %%
#UTR_events_dict
len(UTR_events_dict)
# Out:
# 24983

# %%
type(UTR_events_dict)
# Out:
# dict

# %%
for i in All_samples_Target_3UTR_coverages:
    print(i)
# Out:
# NM_001468|GAGE1|chrX|+
# NM_001012968|SPIN4|chrX|-
# NM_003828|MTMR1|chrX|+
# NM_032967|PCDH11X|chrX|+
# NM_003173|SUV39H1|chrX|+
# NM_003179|SYP|chrX|-
# NM_001081550|THOC2|chrX|-
# NM_014008|CCDC22|chrX|+
# NM_014009|FOXP3|chrX|-
# NR_029379|LOC100132163|chrX|+
# NM_001256188|SNX12|chrX|-
# NM_004312|ARR3|chrX|+
# NR_024062|UBE2DNL|chrX|+
# NM_198881|TBC1D8B|chrX|+
# NM_001105243|PCDH19|chrX|-
# NM_021049|MAGEA5|chrX|-
# NM_005193|CDX4|chrX|+
# NM_033380|COL4A5|chrX|+
# NM_001168361|PCDH11X|chrX|+
# NM_016303|WBP5|chrX|+
# NR_029513|MIR98|chrX|-
# NM_001170570|CXorf56|chrX|-
# NM_001145951|TIMM8A|chrX|-
# NM_020922|WNK3|chrX|-
# NR_038988|LOC100287765|chrX|+
# NM_173493|PASD1|chrX|+
# NM_173495|PTCHD1|chrX|+
# NM_173494|CXorf41|chrX|+
# NM_001017438|CT45A6|chrX|-
# NM_000425|L1CAM|chrX|-
# NM_006743|RBM3|chrX|+
# NR_029708|MIR188|chrX|+
# NR_030233|MIR506|chrX|-
# NR_030230|MIR505|chrX|-
# NR_030236|MIR509-1|chrX|-
# NR_030237|MIR510|chrX|-
# NR_030234|MIR507|chrX|-
# NR_030235|MIR508|chrX|-
# NR_030238|MIR514A1|chrX|-
# NR_030239|MIR514A2|chrX|-
# NM_006520|DYNLT3|chrX|-
# NM_006521|TFE3|chrX|-
# NM_182681|AMELX|chrX|+
# NM_001178099|ZNF182|chrX|-
# NM_024863|TCEAL4|chrX|+
# NM_175569|XG|chrX|+
# NM_001195272|LOC100129520|chrX|+
# NM_172377|CTAG2|chrX|-
# NM_004979|KCND1|chrX|-
# NM_005089|ZRSR2|chrX|+
# NM_032882|PNMA6A|chrX|-
# NM_006044|HDAC6|chrX|+
# NM_001166278|DLG3|chrX|+
# NM_001172285|GLRA4|chrX|-
# NR_036173|MIR514B|chrX|-
# NR_027291|NAP1L6|chrX|-
# NM_006875|PIM2|chrX|-
# NM_004586|RPS6KA3|chrX|-
# NM_001001888|VCX3B|chrX|+
# NM_007052|NOX1|chrX|-
# NM_022144|TNMD|chrX|+
# NM_022148|CRLF2|chrX|-
# NM_017677|MTMR8|chrX|-
# NM_001135995|ATXN3L|chrX|-
# NM_021048|MAGEA10|chrX|-
# NM_018159|NUDT11|chrX|-
# NM_001145346|RBMXL3|chrX|+
# NM_001190255|ZNF630|chrX|-
# NM_206923|YY2|chrX|+
# NM_016267|VGLL1|chrX|+
# NM_007213|PRAF2|chrX|-
# NM_003918|GYG2|chrX|+
# NM_003916|AP1S2|chrX|-
# NM_014499|P2RY10|chrX|+
# NM_001139500|FGF13|chrX|-
# NM_001256743|GRIA3|chrX|+
# NR_037183|SPANXA2-OT1|chrX|+
# NM_021123|GAGE7|chrX|+
# NM_001102576|CSAG1|chrX|+
# NM_001166422|HDAC8|chrX|-
# NM_001166420|HDAC8|chrX|-
# NR_003710|SNORA11C|chrX|+
# NM_002444|MSN|chrX|+
# NR_033460|PAGE3|chrX|-
# NM_000074|CD40LG|chrX|+
# NM_004463|FGD1|chrX|-
# NM_001493|GDI1|chrX|+
# NM_000330|RS1|chrX|-
# NR_029423|MAP2K4P1|chrX|-
# NR_031685|MIR1277|chrX|+
# NR_029427|WDR13|chrX|+
# NM_024082|PRRG3|chrX|+
# NM_001171877|MCF2|chrX|-
# NM_005635|SSX1|chrX|+
# NM_001205103|LOC100509575|chrX|+
# NM_194324|TMSB15B|chrX|+
# NM_001184771|CPXCR1|chrX|+
# NM_001013736|FAM47C|chrX|+
# NM_032803|SLC7A3|chrX|-
# NM_016562|TLR7|chrX|+
# NM_018466|ALG13|chrX|+
# NM_004057|S100G|chrX|+
# NM_001031834|RAB40AL|chrX|+
# NM_005756|GPR64|chrX|-
# NM_001242618|NXT2|chrX|+
# NM_001242614|CD99L2|chrX|-
# NM_032227|TMEM164|chrX|+
# NR_002993|SNORA35|chrX|+
# NM_001114123|ELK1|chrX|-
# NM_000240|MAOA|chrX|+
# NM_012282|KCNE1L|chrX|-
# NM_012286|MORF4L2|chrX|-
# NM_001654|ARAF|chrX|+
# NM_001146257|ZDHHC15|chrX|-
# NM_144967|ARHGAP36|chrX|+
# NM_144969|ZDHHC15|chrX|-
# NM_144968|RIBC1|chrX|+
# NM_021992|TMSB15A|chrX|-
# NM_173358|SSX7|chrX|-
# NM_001130860|HEPH|chrX|+
# NM_018360|TXLNG|chrX|+
# NM_001415|EIF2S3|chrX|+
# NM_001412|EIF1AX|chrX|-
# NR_039980|LOC286437|chrX|-
# NM_138289|ACTRT1|chrX|-
# NM_007150|ZNF185|chrX|+
# NM_007156|ZXDA|chrX|-
# NM_007157|ZXDB|chrX|+
# NR_034031|LOC389906|chrX|-
# NM_001017980|VMA21|chrX|+
# NM_001004051|GPRASP2|chrX|+
# NM_014380|NGFRAP1|chrX|+
# NM_001142389|PNPLA4|chrX|-
# NM_001142386|PDK3|chrX|+
# NM_014927|CNKSR2|chrX|+
# NM_004344|CETN2|chrX|-
# NM_001033583|ACOT9|chrX|-
# NM_001136158|OTUD5|chrX|-
# NM_001136157|OTUD5|chrX|-
# NM_001243197|IQSEC2|chrX|-
# NM_001145718|CT47B1|chrX|-
# NM_016656|RRAGB|chrX|+
# NM_144658|DOCK11|chrX|+
# NM_173523|MAGEB6|chrX|+
# NM_002565|P2RY4|chrX|-
# NR_029946|MIR424|chrX|-
# NM_005032|PLS3|chrX|+
# NM_153834|GPR112|chrX|+
# NR_026742|LOC158572|chrX|-
# NM_020721|KIAA1210|chrX|-
# NM_001128835|TRAPPC2|chrX|-
# NM_080390|TCEAL2|chrX|+
# NM_001847|COL4A6|chrX|-
# NM_052957|ACRC|chrX|+
# NM_004840|ARHGEF6|chrX|-
# NM_000169|GLA|chrX|-
# NM_001122716|CXorf64|chrX|+
# NM_001163335|SYTL5|chrX|+
# NM_001159560|BEX5|chrX|-
# NM_001097642|GJB1|chrX|+
# NM_006201|CDK16|chrX|+
# NM_013271|PCSK1N|chrX|-
# NM_001013845|CXorf40B|chrX|-
# NR_033237|FAM3A|chrX|-
# NM_000640|IL13RA2|chrX|-
# NM_001163279|ODZ1|chrX|-
# NM_022076|DUSP21|chrX|+
# NR_023358|SCARNA9L|chrX|-
# NM_019117|KLHL4|chrX|+
# NM_033085|FATE1|chrX|+
# NM_024122|APOO|chrX|-
# NM_006013|RPL10|chrX|+
# NM_006014|LAGE3|chrX|-
# NM_003069|SMARCA1|chrX|-
# NM_001193281|MID1|chrX|-
# NR_024359|LINC00086|chrX|+
# NM_001184831|VSIG4|chrX|-
# NM_003336|UBE2A|chrX|+
# NM_007003|PAGE4|chrX|+
# NM_133179|XAGE3|chrX|-
# NM_018969|GPR173|chrX|+
# NR_002784|SMEK3P|chrX|-
# NM_206915|NGFRAP1|chrX|+
# NM_206917|NGFRAP1|chrX|+
# NM_000475|NR0B1|chrX|-
# NM_000292|PHKA2|chrX|-
# NM_000291|PGK1|chrX|+
# NM_006733|CENPI|chrX|+
# NR_030241|MIR532|chrX|+
# NR_030240|MIR514A3|chrX|-
# NM_001099856|IKBKG|chrX|+
# NM_014496|RPS6KA6|chrX|-
# NR_033924|CXXC1P1|chrX|+
# NM_203408|FAM47A|chrX|-
# NM_019886|CHST7|chrX|+
# NM_022368|PJA1|chrX|-
# NM_018558|GABRQ|chrX|+
# NM_170750|PSMD10|chrX|-
# NR_029949|MIR18B|chrX|-
# NM_001174068|SYTL4|chrX|-
# NM_017938|FAM70A|chrX|-
# NM_152787|TAB3|chrX|-
# NM_001164415|HSFX2|chrX|+
# NM_001039705|TRO|chrX|+
# NM_153252|BRWD3|chrX|-
# NM_014599|MAGED2|chrX|+
# NM_001177479|HDX|chrX|-
# NM_001177475|MOSPD2|chrX|+
# NM_004065|CDR1|chrX|-
# NR_026975|LOC286467|chrX|-
# NM_001127197|ELF4|chrX|-
# NM_001127199|GAGE12D|chrX|+
# NR_028119|LOC100133957|chrX|+
# NM_006359|SLC9A6|chrX|+
# NM_001134321|FAM127B|chrX|-
# NM_001242640|BRCC3|chrX|+
# NM_080873|ASB11|chrX|-
# NM_080879|RAB40A|chrX|-
# NM_001006639|TCEAL1|chrX|+
# NM_001560|IL13RA1|chrX|+
# NM_001569|IRAK1|chrX|-
# NM_000216|KAL1|chrX|-
# NR_038968|LOC286442|chrX|-
# NM_001142503|STARD8|chrX|+
# NM_012278|ITGB1BP2|chrX|+
# NM_012274|CXorf27|chrX|+
# NM_004187|KDM5C|chrX|-
# NM_004182|UXT|chrX|-
# NR_037414|MIR23C|chrX|-
# NM_178175|LHFPL1|chrX|-
# NM_021637|TMEM35|chrX|+
# NM_005140|CNGA2|chrX|+
# NM_000533|PLP1|chrX|+
# NM_000531|OTC|chrX|+
# NM_000397|CYBB|chrX|+
# NM_000390|CHM|chrX|-
# NM_138702|MAGEC3|chrX|+
# NR_034005|FLJ46446|chrX|+
# NR_030581|MIR891A|chrX|-
# NR_030584|MIR892A|chrX|-
# NR_030586|MIR509-2|chrX|-
# NR_030587|MIR450B|chrX|-
# NR_030589|MIR890|chrX|-
# NR_028407|ARMCX4|chrX|+
# NM_001171689|AMMECR1|chrX|-
# NM_001184727|GPRASP1|chrX|+
# NM_016608|ARMCX1|chrX|+
# NM_001168467|MAP7D2|chrX|-
# NM_153333|TCEAL8|chrX|-
# NM_003399|XPNPEP2|chrX|+
# NM_001098843|CXorf30|chrX|+
# NM_174869|IDH3G|chrX|-
# NM_004606|TAF1|chrX|+
# NM_006603|STAG2|chrX|+
# NM_023934|FUNDC2|chrX|+
# NM_001099921|MAGEB16|chrX|+
# NM_001098412|GAGE13|chrX|+
# NM_001170761|SRPK3|chrX|+
# NR_024493|LINC00087|chrX|-
# NR_024499|FMR1-AS1|chrX|-
# NM_020717|SHROOM4|chrX|-
# NM_001145933|TKTL1|chrX|+
# NR_002969|SNORA36A|chrX|+
# NM_001013628|DCAF12L2|chrX|-
# NM_001013627|NHSL2|chrX|+
# NM_003372|VBP1|chrX|+
# NM_014728|FRMPD4|chrX|+
# NM_001171020|MUM1L1|chrX|+
# NM_181532|ERAS|chrX|+
# NM_002764|PRPS1|chrX|+
# NM_002765|PRPS2|chrX|+
# NM_001448|GPC4|chrX|-
# NM_032946|NXF5|chrX|-
# NM_003159|CDKL5|chrX|+
# NM_001032289|SLC35A2|chrX|-
# NM_001171184|DRP2|chrX|+
# NM_001171186|FAM9A|chrX|-
# NR_026551|CA5BP1|chrX|+
# NM_152226|PPEF1|chrX|+
# NR_045864|ARMCX4|chrX|+
# NR_045863|ARMCX4|chrX|+
# NM_207672|GRIPAP1|chrX|-
# NM_133265|AMOT|chrX|-
# NM_002049|GATA1|chrX|+
# NM_001145408|NONO|chrX|+
# NR_036256|MIR4330|chrX|+
# NR_036257|MIR500B|chrX|+
# NR_036255|MIR4329|chrX|-
# NM_001078171|FAM127A|chrX|+
# NM_001078172|FAM127B|chrX|-
# NM_001078173|FAM127C|chrX|-
# NM_152424|FAM123B|chrX|-
# NR_027444|LOC100133957|chrX|+
# NM_013452|VCX|chrX|+
# NM_013453|SPANXA1|chrX|+
# NM_001006614|WBP5|chrX|+
# NM_015129|SEPT6|chrX|-
# NM_012471|TRPC5|chrX|-
# NM_001173486|PRRG1|chrX|+
# NM_001173480|ARHGEF9|chrX|-
# NM_198456|FAM120C|chrX|-
# NM_198450|APOOL|chrX|+
# NM_198451|FOXR2|chrX|+
# NM_001325|CSTF2|chrX|+
# NM_004135|IDH3G|chrX|-
# NM_080612|GAB3|chrX|-
# NM_001110556|FLNA|chrX|-
# NM_004794|RAB33A|chrX|+
# NM_019597|HNRNPH2|chrX|+
# NM_052926|PNMA5|chrX|-
# NM_001356|DDX3X|chrX|+
# NM_174901|FAM9C|chrX|-
# NM_004729|ZBED1|chrX|-
# NM_000402|G6PD|chrX|-
# NR_026694|ZCCHC18|chrX|+
# NM_057162|KLHL4|chrX|+
# NR_033974|DKFZp686D0853|chrX|+
# NR_027250|SSX8|chrX|+
# NM_021183|RAP2C|chrX|-
# NM_018990|SASH3|chrX|+
# NM_171998|RAB39B|chrX|-
# NM_001195214|YIPF6|chrX|+
# NM_016383|LUZP4|chrX|+
# NM_032512|PDZD4|chrX|-
# NR_030399|MIR542|chrX|-
# NM_001171109|FAM133A|chrX|+
# NM_001127200|GAGE2E|chrX|+
# NR_029484|MIRLET7F2|chrX|-
# NM_024539|RNF128|chrX|+
# NM_001004308|ZCCHC16|chrX|+
# NM_182506|MAGEB10|chrX|+
# NM_058163|TSR2|chrX|+
# NM_015686|FAM155B|chrX|+
# NM_000052|ATP7A|chrX|+
# NM_013364|PNMA3|chrX|+
# NR_030629|MIR509-3|chrX|-
# NM_002362|MAGEA4|chrX|+
# NM_002364|MAGEB2|chrX|+
# NM_002365|MAGEB3|chrX|+
# NM_001031855|LONRF3|chrX|+
# NM_007075|WDR45|chrX|-
# NM_006306|SMC1A|chrX|-
# NM_006307|SRPX|chrX|-
# NM_001185076|FMR1|chrX|+
# NR_024440|LOC729609|chrX|-
# NM_001080790|MAGEA9B|chrX|-
# NR_031748|MIR2114|chrX|+
# NM_001178032|ZC4H2|chrX|-
# NM_021109|TMSB4X|chrX|+
# NM_001142797|CXCR3|chrX|-
# NM_012227|GTPBP6|chrX|-
# NM_006915|RP2|chrX|+
# NM_004208|AIFM1|chrX|-
# NM_001159703|FHL1|chrX|+
# NM_030763|HMGN5|chrX|-
# NM_139019|SPANXF1|chrX|+
# NM_198057|TSC22D3|chrX|-
# NM_018301|RBM41|chrX|-
# NM_004992|MECP2|chrX|-
# NM_001167989|PQBP1|chrX|+
# NM_138737|HEPH|chrX|+
# NM_001007524|F8A3|chrX|+
# NM_001011719|ARSH|chrX|+
# NM_022661|SPANXC|chrX|-
# NM_024921|POF1B|chrX|-
# NM_001105576|SOWAHD|chrX|+
# NM_001110792|MECP2|chrX|-
# NM_014522|PCDH11X|chrX|+
# NM_001257403|VSIG4|chrX|-
# NM_005636|SSX4|chrX|+
# NM_005634|SOX3|chrX|-
# NM_032591|SLC9A7|chrX|-
# NM_138703|MAGEE2|chrX|-
# NM_015698|GPKOW|chrX|-
# NM_015691|WWC3|chrX|+
# NM_212559|XKRX|chrX|-
# NM_012084|GLUD2|chrX|+
# NM_001004486|OR13H1|chrX|+
# NR_003007|SCARNA23|chrX|+
# NM_001013579|AWAT1|chrX|+
# NM_001009613|SPANXN4|chrX|+
# NM_001009615|SPANXN2|chrX|-
# NM_001009614|SPANXN1|chrX|+
# NM_001009616|SPANXN5|chrX|-
# NM_000266|NDP|chrX|-
# NM_001077188|HS6ST2|chrX|-
# NM_031273|TEX13B|chrX|-
# NM_031274|TEX13A|chrX|-
# NM_031276|TEX11|chrX|-
# NM_001170961|IGSF1|chrX|-
# NR_030737|TTC3P1|chrX|-
# NM_017711|GDPD2|chrX|+
# NM_001039840|CHIC1|chrX|+
# NM_001475|GAGE5|chrX|+
# NM_001476|GAGE6|chrX|+
# NM_001472|GAGE2C|chrX|+
# NM_007137|ZNF81|chrX|+
# NM_007130|ZNF41|chrX|-
# NM_007131|ZNF75D|chrX|-
# NM_001012979|TCEAL5|chrX|-
# NM_001012977|PABPC1L2A|chrX|-
# NM_001128127|GK|chrX|+
# NM_001010888|ZC3H12B|chrX|+
# NM_001098411|GAGE2B|chrX|+
# NM_001098413|GAGE10|chrX|+
# NM_001256197|ARAF|chrX|+
# NM_001184797|TMLHE|chrX|-
# NM_152274|FAM58A|chrX|-
# NM_152278|TCEAL7|chrX|+
# NM_020871|LRCH2|chrX|-
# NM_205849|FAM9B|chrX|-
# NM_002547|OPHN1|chrX|-
# NM_177439|FTSJ1|chrX|+
# NM_004651|USP11|chrX|+
# NM_015975|TAF9B|chrX|-
# NR_031581|MIR764|chrX|+
# NM_007309|DIAPH2|chrX|+
# NM_130467|PAGE5|chrX|+
# NM_020932|MAGEE1|chrX|+
# NR_038998|LOC100506757|chrX|+
# NM_001042498|SLC35A2|chrX|-
# NM_175711|SSX3|chrX|-
# NM_032498|RHOXF2|chrX|+
# NM_002668|PLP2|chrX|+
# NM_001363|DKC1|chrX|+
# NM_001587|OCRL|chrX|+
# NR_030224|MIR500A|chrX|+
# NR_030225|MIR501|chrX|+
# NR_030227|MIR450A2|chrX|-
# NR_030226|MIR502|chrX|+
# NR_030229|MIR504|chrX|-
# NR_030228|MIR503|chrX|-
# NM_182699|DDX53|chrX|+
# NR_046101|CXorf31|chrX|-
# NM_145799|SEPT6|chrX|-
# NM_024859|MAGIX|chrX|+
# NM_001039590|USP9X|chrX|+
# NM_153448|ESX1|chrX|-
# NR_033941|LOC100129515|chrX|-
# NM_001256447|BCAP31|chrX|-
# NM_001289|CLIC2|chrX|-
# NR_015378|LOC401588|chrX|+
# NM_001163257|PLXNB3|chrX|+
# NM_022052|NXF3|chrX|-
# NM_022053|NXF2|chrX|+
# NM_001173517|MAP7D3|chrX|-
# NM_016378|VCX2|chrX|-
# NM_016379|VCX3A|chrX|-
# NR_029521|MIR105-1|chrX|-
# NM_000061|BTK|chrX|-
# NR_027419|AVPR2|chrX|+
# NM_002351|SH2D1A|chrX|+
# NM_014289|CAPN6|chrX|-
# NM_001173456|PDHA1|chrX|+
# NM_001177465|MAMLD1|chrX|+
# NM_004595|SMS|chrX|+
# NM_032121|MAGT1|chrX|-
# NM_017666|ZNF280C|chrX|-
# NM_017669|ERCC6L|chrX|-
# NR_002226|INGX|chrX|-
# NM_178813|AKAP14|chrX|+
# NM_173794|FUNDC1|chrX|-
# NM_173798|ZCCHC12|chrX|+
# NM_145664|SPANXB2|chrX|+
# NM_145662|SPANXA2|chrX|-
# NM_032417|SPANXD|chrX|-
# NM_012151|F8A1|chrX|+
# NM_001504|CXCR3|chrX|-
# NM_007220|CA5B|chrX|+
# NM_001032726|RAB41|chrX|+
# NM_012216|MID2|chrX|+
# NM_033215|PPP1R3F|chrX|+
# NM_004085|TIMM8A|chrX|-
# NM_001195081|LOC100288814|chrX|+
# NM_005834|TIMM17B|chrX|-
# NM_003785|PAGE1|chrX|-
# NM_015507|EGFL6|chrX|+
# NR_029962|MIR450A1|chrX|-
# NM_004493|HSD17B10|chrX|-
# NR_028366|SSX6|chrX|+
# NM_015884|MBTPS2|chrX|+
# NR_039991|LOC100507404|chrX|+
# NM_001017930|DCAF8L1|chrX|-
# NR_024608|LOC442459|chrX|-
# NR_024607|MGC16121|chrX|-
# NM_001184742|ZBTB33|chrX|+
# NM_178470|DCAF12L1|chrX|-
# NM_178471|GPR119|chrX|-
# NM_018476|BEX1|chrX|-
# NM_005660|SLC35A2|chrX|-
# NR_028379|FTX|chrX|-
# NM_004043|ASMT|chrX|+
# NM_004042|ARSF|chrX|+
# NM_006375|ENOX2|chrX|-
# NM_001122606|LAMP2|chrX|-
# NR_031578|MIR1298|chrX|+
# NM_021796|PLAC1|chrX|-
# NM_001136273|ZFP92|chrX|+
# NM_005462|MAGEC1|chrX|+
# NM_001144064|CXorf51A|chrX|+
# NR_002984|SNORA56|chrX|+
# NM_139282|RHOXF1|chrX|-
# NM_139289|AKAP4|chrX|-
# NR_029852|MIR363|chrX|-
# NM_001080848|CSAG2|chrX|+
# NM_025184|EFHC2|chrX|-
# NM_001017417|CT45A1|chrX|+
# NM_001171136|ZBED1|chrX|-
# NM_173695|CXorf59|chrX|+
# NM_173694|ATP11C|chrX|-
# NM_173699|MAGEB18|chrX|+
# NM_078628|MSL3|chrX|+
# NM_019003|SPIN2A|chrX|-
# NM_178129|P2RY8|chrX|-
# NR_038461|LOC100128420|chrX|+
# NM_018977|NLGN3|chrX|+
# NM_001031745|RIBC1|chrX|+
# NM_003868|FGF16|chrX|+
# NM_001079900|SPACA5B|chrX|+
# NM_152761|CXorf58|chrX|+
# NM_001142395|PRRG1|chrX|+
# NM_001142392|SLC10A3|chrX|-
# NM_001142391|SLC10A3|chrX|-
# NM_000206|IL2RG|chrX|-
# NM_205833|IGSF1|chrX|-
# NM_130775|XAGE5|chrX|+
# NM_130777|XAGE2|chrX|+
# NM_001146702|KDM5C|chrX|-
# NM_006667|PGRMC1|chrX|+
# NM_006089|SCML2|chrX|-
# NM_014235|UBL4A|chrX|-
# NM_001143983|CHRDL1|chrX|-
# NM_001170704|MBNL3|chrX|-
# NM_001195576|LOC100329135|chrX|+
# NM_017856|GEMIN8|chrX|-
# NM_175723|SSX5|chrX|-
# NM_145119|PJA1|chrX|-
# NM_001144886|CITED1|chrX|-
# NM_001163322|CCDC120|chrX|+
# NM_001163323|CCDC120|chrX|+
# NM_152692|C1GALT1C1|chrX|-
# NM_152694|ZCCHC5|chrX|-
# NM_152695|ZNF449|chrX|+
# NR_028597|SRD5A1P1|chrX|+
# NM_001034853|RPGR|chrX|-
# NM_001136533|DCAF8L2|chrX|+
# NM_031407|HUWE1|chrX|-
# NM_138270|ATRX|chrX|-
# NM_000377|WAS|chrX|+
# NM_032926|TCEAL3|chrX|+
# NM_001037968|ALAS2|chrX|-
# NM_018094|GSPT2|chrX|+
# NM_006729|DIAPH2|chrX|+
# NM_006579|EBP|chrX|+
# NM_001011657|ZMAT1|chrX|-
# NM_003611|OFD1|chrX|+
# NM_021083|XK|chrX|+
# NR_024501|FMR1-AS1|chrX|-
# NM_153183|NUDT10|chrX|+
# NM_145177|DHRSX|chrX|-
# NM_001029891|PGAM4|chrX|-
# NM_012317|LDOC1|chrX|-
# NM_012310|KIF4A|chrX|+
# NM_001129898|ZNF673|chrX|+
# NM_005044|PRKX|chrX|-
# NM_015922|NSDHL|chrX|+
# NM_001164416|H2BFM|chrX|+
# NM_024689|CXorf36|chrX|-
# NM_001139467|TBL1X|chrX|+
# NM_001170781|FAM122C|chrX|+
# NM_001170782|FAM122C|chrX|+
# NM_001170783|FAM122C|chrX|+
# NM_004541|NDUFA1|chrX|+
# NM_080632|UPF3B|chrX|-
# NM_000898|MAOB|chrX|-
# NR_002216|NXF4|chrX|+
# NM_003270|TSPAN6|chrX|-
# NM_018196|TMLHE|chrX|-
# NM_005361|MAGEA2|chrX|+
# NM_005362|MAGEA3|chrX|-
# NM_005365|MAGEA9|chrX|+
# NM_005367|MAGEA12|chrX|-
# NM_005366|MAGEA11|chrX|+
# NM_004709|CXorf1|chrX|+
# NM_001080489|GLOD5|chrX|+
# NM_001080485|ZNF275|chrX|+
# NM_014467|SRPX2|chrX|+
# NM_001101357|CCDC160|chrX|+
# NM_001170628|AFF2|chrX|+
# NM_001199972|RPL36A|chrX|+
# NM_001166462|MPP1|chrX|-
# NM_138960|TGIF2LX|chrX|+
# NR_029955|MIR448|chrX|+
# NR_029950|MIR20B|chrX|-
# NM_001183|ATP6AP1|chrX|+
# NR_002584|SNORA69|chrX|-
# NM_001171163|ZMYM3|chrX|-
# NM_001171162|ZMYM3|chrX|-
# NM_152869|RGN|chrX|+
# NM_001031705|CXorf48|chrX|-
# NR_024582|JPX|chrX|+
# NM_001145139|CXorf49B|chrX|+
# NM_207339|PAGE2|chrX|+
# NM_000033|ABCD1|chrX|+
# NM_016521|TFDP3|chrX|-
# NM_013347|RPA4|chrX|+
# NM_001171706|RIPPLY1|chrX|-
# NM_001080975|REPS2|chrX|+
# NM_004019|DMD|chrX|-
# NM_001032384|PQBP1|chrX|+
# NM_001163438|CXorf69|chrX|+
# NM_203303|ZCCHC13|chrX|+
# NM_001168300|KLHL13|chrX|-
# NM_175859|CTPS2|chrX|-
# NR_002735|SNORD61|chrX|-
# NR_033670|ARMCX6|chrX|-
# NR_045260|LOC100133123|chrX|+
# NM_001551|IGBP1|chrX|+
# NM_007250|KLF8|chrX|+
# NM_003951|SLC25A14|chrX|+
# NR_038978|LOC340544|chrX|+
# NM_006123|IDS|chrX|-
# NM_006125|ARHGAP6|chrX|-
# NM_001167|XIAP|chrX|+
# NR_030413|MIR766|chrX|-
# NM_004192|ASMTL|chrX|-
# NM_006978|RNF113A|chrX|-
# NM_004229|MED14|chrX|-
# NM_004224|GPR50|chrX|+
# NM_025159|CXorf21|chrX|-
# NM_001024452|GLRA4|chrX|-
# NM_001024455|RGAG4|chrX|-
# NM_001204526|SSR4|chrX|+
# NM_016024|RBMX2|chrX|+
# NM_031907|USP26|chrX|-
# NM_004429|EFNB1|chrX|+
# NM_001166700|FAM104B|chrX|-
# NM_024597|MAP7D3|chrX|-
# NM_001163280|HTATSF1|chrX|+
# NR_030593|MIR892B|chrX|-
# NR_030592|MIR888|chrX|-
# NR_030590|MIR891B|chrX|-
# NM_001097594|XAGE1B|chrX|+
# NM_001097596|XAGE1B|chrX|-
# NM_001097598|XAGE1C|chrX|+
# NM_177456|MAGEC3|chrX|+
# NR_033742|FRMD8P1|chrX|-
# NR_037842|LINC00102|chrX|-
# NM_016937|POLA1|chrX|+
# NM_006639|CYSLTR1|chrX|-
# NR_029635|MIR221|chrX|-
# NR_029636|MIR222|chrX|-
# NR_029637|MIR223|chrX|+
# NM_024657|MORC4|chrX|-
# NR_027783|SAT1|chrX|+
# NM_001137554|MCTS1|chrX|+
# NR_027121|SHROOM4|chrX|-
# NM_001170757|FAM122B|chrX|-
# NM_001170756|FAM122B|chrX|-
# NM_001139515|DACH2|chrX|+
# NM_020769|RGAG1|chrX|+
# NM_001145073|USP27X|chrX|+
# NR_002953|SNORA11|chrX|+
# NM_017863|CXorf48|chrX|-
# NM_001195522|LOC347411|chrX|+
# NM_000828|GRIA3|chrX|+
# NM_001193270|MSL3|chrX|+
# NM_001193277|MID1|chrX|-
# NM_001127899|CLCN5|chrX|+
# NM_181313|TAZ|chrX|+
# NM_001170944|PNMA6C|chrX|+
# NM_006406|PRDX4|chrX|+
# NM_019056|NDUFB11|chrX|-
# NR_003238|H2BFXP|chrX|+
# NM_000328|RPGR|chrX|-
# NM_021998|ZNF711|chrX|+
# NM_003147|SSX2|chrX|+
# NM_002893|RBBP7|chrX|-
# NM_176819|CXorf36|chrX|-
# NM_001152|SLC25A5|chrX|+
# NM_020061|OPN1LW|chrX|+
# NR_026545|APOO|chrX|-
# NM_001142805|SLC6A8|chrX|+
# NM_030624|KLHL15|chrX|-
# NM_001145414|CHM|chrX|-
# NM_001162936|CXorf68|chrX|-
# NR_031563|MIR1264|chrX|+
# NR_031567|MIR1468|chrX|-
# NM_002910|RENBP|chrX|-
# NM_153280|UBA1|chrX|+
# NM_001123384|BCOR|chrX|-
# NM_013444|UBQLN2|chrX|+
# NM_004538|NAP1L3|chrX|-
# NM_016153|HSFX1|chrX|+
# NM_016157|TRO|chrX|+
# NM_016484|PDZD11|chrX|-
# NM_017681|NUP62CL|chrX|-
# NM_002641|PIGA|chrX|-
# NM_174912|FAAH2|chrX|+
# NM_001178086|ZFX|chrX|+
# NM_001170650|LAS1L|chrX|-
# NM_021963|NAP1L2|chrX|-
# NM_001166418|HDAC8|chrX|-
# NM_178153|DCX|chrX|-
# NM_001010862|SPIN3|chrX|-
# NM_013239|PPP2R3B|chrX|-
# NM_003491|NAA10|chrX|-
# NM_003492|TMEM187|chrX|+
# NM_020137|GRIPAP1|chrX|-
# NM_005765|ATP6AP2|chrX|+
# NR_029909|MIR384|chrX|-
# NM_004961|GABRE|chrX|-
# NM_001017436|CT45A4|chrX|+
# NM_001127212|GAGE2A|chrX|+
# NR_015353|LOC92249|chrX|-
# NM_020384|CLDN2|chrX|+
# NM_001711|BGN|chrX|+
# NM_000047|ARSE|chrX|-
# NM_000044|AR|chrX|+
# NM_001013742|DGKK|chrX|-
# NM_021140|KDM6A|chrX|+
# NM_003022|SH3BGRL|chrX|+
# NM_004020|DMD|chrX|-
# NM_001184874|GPRASP2|chrX|+
# NM_020994|CTAG2|chrX|-
# NM_005334|HCFC1|chrX|-
# NM_005333|HCCS|chrX|+
# NM_001522|GUCY2F|chrX|-
# NM_001193280|MID1|chrX|-
# NR_031732|MIR1911|chrX|+
# NR_031733|MIR1912|chrX|+
# NM_152632|CXorf22|chrX|+
# NM_152634|TCEANC|chrX|+
# NM_080720|H2AFB3|chrX|+
# NM_003413|ZIC3|chrX|+
# NR_038405|LOC100129662|chrX|+
# NM_003886|AKAP4|chrX|-
# NR_028345|RP1-177G6.2|chrX|+
# NR_028344|RP1-177G6.2|chrX|+
# NM_000686|AGTR2|chrX|+
# NM_001012989|UBE2NL|chrX|+
# NM_001145149|VAMP7|chrX|+
# NM_001184767|BEND2|chrX|-
# NM_001184768|ARMCX6|chrX|-
# NM_001195328|RAB9A|chrX|+
# NM_001005613|EDA|chrX|+
# NM_003604|IRS4|chrX|-
# NM_001098800|MAGED4|chrX|+
# NR_026935|LOC158696|chrX|-
# NM_054021|GPR101|chrX|-
# NM_198279|CXorf23|chrX|-
# NM_198270|NHS|chrX|+
# NM_022567|NYX|chrX|+
# NM_001130997|FAM58A|chrX|-
# NM_005448|BMP15|chrX|+
# NM_080832|PABPC5|chrX|+
# NM_001144003|SLITRK2|chrX|+
# NM_001144004|SLITRK2|chrX|+
# NM_001009609|SPANXN3|chrX|-
# NM_000252|MTM1|chrX|+
# NM_006150|PRICKLE3|chrX|-
# NM_019556|MOSPD1|chrX|-
# NM_001395|DUSP9|chrX|+
# NM_001399|EDA|chrX|+
# NM_001649|SHROOM2|chrX|+
# NM_144970|CXorf38|chrX|-
# NM_000117|EMD|chrX|+
# NM_001001994|GPM6B|chrX|-
# NM_001001995|GPM6B|chrX|-
# NM_001080139|CT47A8|chrX|-
# NM_001080137|CT47A10|chrX|-
# NM_152582|CT45A2|chrX|+
# NM_153270|KLHL34|chrX|-
# NM_005183|CACNA1F|chrX|-
# NR_028443|SLC25A5-AS1|chrX|-
# NM_001017991|H2AFB2|chrX|+
# NM_001098408|GAGE12C|chrX|+
# NM_001098409|GAGE12G|chrX|+
# NM_001098406|GAGE12J|chrX|+
# NM_001098407|GAGE2D|chrX|+
# NM_014061|MAGEH1|chrX|+
# NM_021804|ACE2|chrX|-
# NM_205856|SPACA5|chrX|+
# NM_021029|RPL36A|chrX|+
# NM_001042506|PABPC1L2B|chrX|+
# NM_003688|CASK|chrX|-
# NR_033717|SCML2|chrX|-
# NM_177404|MAGEB1|chrX|+
# NM_001178135|HDHD1|chrX|-
# NM_001830|CLCN4|chrX|+
# NM_001012288|CRLF2|chrX|-
# NM_015419|MXRA5|chrX|-
# NM_001146151|AVPR2|chrX|+
# NM_000194|HPRT1|chrX|+
# NR_030785|MIR374A|chrX|-
# NM_001039582|PNCK|chrX|-
# NM_000351|STS|chrX|+
# NM_000354|SERPINA7|chrX|-
# NM_001166448|HDAC8|chrX|-
# NM_001048181|OPN1MW2|chrX|+
# NM_013995|LAMP2|chrX|-
# NM_001002254|AWAT2|chrX|-
# NR_026595|LINC00246A|chrX|-
# NR_015367|LOC550643|chrX|+
# NM_001163265|PCYT1B|chrX|-
# NM_001163264|PCYT1B|chrX|-
# NM_201286|USP51|chrX|-
# NM_182541|TMEM31|chrX|+
# NM_182540|DDX26B|chrX|+
# NM_033670|CCNB3|chrX|+
# NM_001097579|GPR34|chrX|+
# NM_001727|BRS3|chrX|+
# NM_001721|BMX|chrX|+
# NM_017413|APLN|chrX|-
# NM_017416|IL1RAPL2|chrX|+
# NR_027402|LINC00204B|chrX|+
# NM_001142527|BHLHB9|chrX|+
# NM_016120|RLIM|chrX|-
# NM_001242922|CT47A12|chrX|-
# NM_003254|TIMP1|chrX|+
# NM_032796|SYAP1|chrX|+
# NM_005342|HMGB3|chrX|+
# NM_000444|PHEX|chrX|+
# NM_016249|MAGEC2|chrX|-
# NR_030397|MIR660|chrX|+
# NM_007231|SLC6A14|chrX|+
# NM_006517|SLC16A2|chrX|+
# NR_030398|MIR421|chrX|-
# NR_030258|MIR545|chrX|-
# NM_014481|APEX2|chrX|+
# NM_152630|FAM46D|chrX|+
# NM_152631|FAM47B|chrX|+
# NM_152633|FANCB|chrX|-
# NM_001256760|HTR2C|chrX|+
# NM_203474|PORCN|chrX|+
# NM_198511|LANCL3|chrX|+
# NM_198510|ITIH6|chrX|-
# NM_001190708|MTRNR2L10|chrX|-
# NM_001166401|MAGEA8|chrX|+
# NR_029973|MIR452|chrX|-
# NR_024616|INE1|chrX|+
# NM_020665|TMEM27|chrX|-
# NM_207318|FAM199X|chrX|+
# NM_001184750|SLITRK4|chrX|-
# NM_138636|TLR8|chrX|+
# NM_016954|TBX22|chrX|+
# NM_001000|RPL39|chrX|-
# NM_004699|FAM50A|chrX|+
# NM_173470|MMGT1|chrX|-
# NM_021785|RAI2|chrX|-
# NM_021783|EDA2R|chrX|-
# NM_001172732|RAI2|chrX|-
# NR_002718|TDGF1P3|chrX|+
# NM_017514|PLXNA3|chrX|+
# NM_017518|HAUS7|chrX|-
# NM_001168649|CNKSR2|chrX|+
# NM_001080425|BEX4|chrX|+
# NM_001098791|MID1IP1|chrX|+
# NM_001099680|MAGIX|chrX|+
# NM_001099686|NXF2B|chrX|-
# NM_001099685|RHOXF2B|chrX|+
# NM_001099684|FAM156B|chrX|+
# NM_006950|SYN1|chrX|-
# NM_001636|SLC25A6|chrX|-
# NM_001080851|DMRTC1B|chrX|+
# NM_181332|NLGN4X|chrX|-
# NM_001184966|WDR44|chrX|+
# NM_152578|FMR1NB|chrX|+
# NM_152577|ZNF645|chrX|+
# NM_017752|TBC1D8B|chrX|+
# NM_003446|ZNF157|chrX|+
# NM_139058|ARX|chrX|-
# NM_012069|ATP1B4|chrX|+
# NM_001174092|TMEM185A|chrX|-
# NM_001128167|PAK3|chrX|+
# NR_028477|RBMX|chrX|-
# NM_001256155|ARMCX4|chrX|+
# NM_001006683|SPIN2B|chrX|-
# NM_198512|DGAT2L6|chrX|+
# NM_001135565|HDHD1|chrX|-
# NR_024033|IL9R|chrX|+
# NM_207422|FLJ44635|chrX|+
# NM_133499|SYN1|chrX|-
# NM_016500|CXorf26|chrX|+
# NM_001204468|RBM10|chrX|+
# NR_045617|SMPX|chrX|-
# NM_001168474|TAF7L|chrX|-
# NM_021014|SSX3|chrX|-
# NR_002309|RPS26P11|chrX|+
# NR_002308|UQCRBP1|chrX|-
# NM_002367|MAGEB4|chrX|+
# NR_029509|MIR92A2|chrX|-
# NM_001146291|ZNF674|chrX|-
# NM_004615|TSPAN7|chrX|+
# NM_001006682|SPIN2B|chrX|-
# NM_001143978|ZCCHC18|chrX|+
# NM_001170779|FAM122C|chrX|+
# NM_001184898|PHF8|chrX|-
# NM_001184897|PHF8|chrX|-
# NM_001184896|PHF8|chrX|-
# NM_001190417|ZNF674|chrX|-
# NM_017848|FAM120C|chrX|-
# NM_001866|COX7B|chrX|+
# NM_001164803|RBMX|chrX|-
# NM_000808|GABRA3|chrX|-
# NM_014735|PHF16|chrX|+
# NM_001327|CTAG1B|chrX|-
# NM_012196|GAGE8|chrX|+
# NM_001080146|CT47A1|chrX|-
# NM_001080142|CT47A5|chrX|-
# NM_001080140|CT47A7|chrX|-
# NR_030774|UPRT|chrX|+
# NM_181673|OGT|chrX|+
# NR_039925|MIR4768|chrX|+
# NR_039924|MIR4767|chrX|+
# NR_039926|MIR4769|chrX|+
# NR_003255|TSIX|chrX|+
# NM_153488|MAGEA2B|chrX|+
# NM_000307|POU3F4|chrX|+
# NM_006223|PIN4|chrX|+
# NM_001015877|PHF6|chrX|+
# NM_001172436|PHKA1|chrX|-
# NR_033212|CXorf65|chrX|-
# NM_145802|SEPT6|chrX|-
# NM_001006937|TCEAL4|chrX|+
# NM_001006938|TCEAL6|chrX|-
# NR_027761|LOC100132831|chrX|-
# NM_032553|GPR174|chrX|+
# NM_001018024|MTCP1NB|chrX|-
# NM_001018025|MTCP1|chrX|-
# NM_016370|RAB9B|chrX|-
# NR_029522|MIR105-2|chrX|-
# NR_029523|MIR106A|chrX|-
# NR_034116|LOC100129407|chrX|+
# NR_037494|MIR676|chrX|+
# NR_027456|LOC100272228|chrX|+
# NR_027455|LOC100131434|chrX|-
# NM_013427|ARHGAP6|chrX|-
# NM_153346|BEND2|chrX|-
# NM_001162491|ARL13A|chrX|+
# NM_001162490|ARL13A|chrX|+
# NM_198465|NRK|chrX|+
# NM_145305|SLC25A43|chrX|+
# NM_001184819|GNL3L|chrX|+
# NM_001168531|ASB9|chrX|-
# NM_001042453|MST4|chrX|+
# NM_001168399|BEX2|chrX|-
# NR_002191|PPP1R2P9|chrX|-
# NM_032458|PHF6|chrX|+
# NR_001559|VENTXP1|chrX|+
# NM_002625|PFKFB1|chrX|-
# NM_002621|CFP|chrX|-
# NM_005938|FOXO4|chrX|+
# NM_052936|ATG4A|chrX|+
# NM_018015|CXorf57|chrX|+
# NR_028089|NXF5|chrX|-
# NM_001164619|GPC3|chrX|-
# NM_005300|GPR34|chrX|+
# NM_021949|ATP2B3|chrX|+
# NM_021946|BCORL1|chrX|+
# NM_002294|LAMP2|chrX|-
# NR_030380|MIR651|chrX|+
# NR_029491|MIR19B2|chrX|-
# NM_001111125|IQSEC2|chrX|-
# NM_024528|NKAP|chrX|-
# NM_207320|OTUD6A|chrX|+
# NM_032335|PHF6|chrX|+
# NM_001168482|ARMCX5|chrX|+
# NM_001079872|CUL4B|chrX|-
# NR_030631|MIR934|chrX|+
# NM_001166221|UTP14A|chrX|+
# NM_001009933|DNASE1L1|chrX|-
# NM_194277|FRMD7|chrX|-
# NM_001032396|PJA1|chrX|-
# NM_022117|TSPYL2|chrX|+
# NM_175868|MAGEA6|chrX|+
# NR_003539|LOC643486|chrX|-
# NM_001136233|FAM48B2|chrX|-
# NM_001136234|FAM48B1|chrX|+
# NM_031892|SH3KBP1|chrX|-
# NM_031894|FTHL17|chrX|-
# NM_005314|GRPR|chrX|+
# NM_001008537|KIAA2022|chrX|-
# NM_001008535|AKAP14|chrX|+
# NR_004379|SNORD96B|chrX|-
# NM_007268|VSIG4|chrX|-
# NM_017544|NKRF|chrX|-
# NR_000011|SNORA70|chrX|+
# NR_031757|MIR718|chrX|-
# NR_030409|MIR767|chrX|-
# NM_001166699|FAM104B|chrX|-
# NM_177948|ARMCX3|chrX|+
# NM_018666|SAGE1|chrX|+
# NM_014782|ARMCX2|chrX|-
# NM_021118|CYLC1|chrX|+
# NM_001002916|H2BFWT|chrX|-
# NM_001242319|PNMA6D|chrX|+
# NM_080701|TREX2|chrX|-
# NM_001171080|RBM41|chrX|-
# NM_016032|ZDHHC9|chrX|-
# NR_039774|MIR3978|chrX|+
# NM_033518|SLC38A5|chrX|-
# NR_038428|CXorf28|chrX|+
# NM_005296|LPAR4|chrX|+
# NM_005120|MED12|chrX|+
# NM_004458|ACSL4|chrX|-
# NM_000513|OPN1MW|chrX|+
# NM_004988|MAGEA1|chrX|-
# NM_001007551|CT45A5|chrX|-
# NM_001017978|CXorf61|chrX|-
# NM_024917|TRMT2B|chrX|-
# NM_001166550|IDS|chrX|-
# NM_003662|PIR|chrX|-
# NM_002536|TBC1D25|chrX|+
# NR_037859|PIR-FIGF|chrX|-
# NM_001037535|SCML1|chrX|+
# NR_033772|CENPVL1|chrX|+
# NM_001013403|CXorf66|chrX|-
# NM_001012755|SLC25A53|chrX|-
# NM_001171909|CXorf40A|chrX|+
# NM_001171908|CXorf40A|chrX|+
# NM_014271|IL1RAPL1|chrX|+
# NR_027139|SPIN3|chrX|-
# NR_027131|NKAPP1|chrX|-
# NM_001170747|PIN4|chrX|+
# NM_080817|GPR82|chrX|+
# NM_005391|PDK3|chrX|+
# NM_001015038|PAGE2B|chrX|+
# NM_001007|RPS4X|chrX|-
# NM_130388|ASB12|chrX|-
# NM_000273|GPR143|chrX|-
# NM_001171581|ITM2A|chrX|-
# NM_006986|MAGED1|chrX|+
# NM_001669|ARSD|chrX|-
# NM_004299|ABCB7|chrX|-
# NM_001666|ARHGAP4|chrX|-
# NM_000133|F9|chrX|+
# NM_000132|F8|chrX|-
# NR_030727|TLR8-AS1|chrX|-
# NM_001171942|GLRA2|chrX|+
# NM_182607|VSIG1|chrX|+
# NM_031442|TMEM47|chrX|-
# NR_033124|ALG13|chrX|+

# %%
All_sample_coverage_weights = All_samples_sequencing_depths/np.mean(All_samples_sequencing_depths)
All_sample_coverage_weights
# Out:
# array([1.02384623, 0.97615377])
