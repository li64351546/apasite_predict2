# %%
import numpy as np
import os
import sys
import datetime

import scipy as sp
import scipy.stats

from bisect import bisect
from statsmodels.stats.multitest import multipletests

import math

# %%
def parse_cfgfile(cfg_file):
    '''Parse configure file
    '''
    Group1_Tophat_aligned_file=''
    Group2_Tophat_aligned_file=''
    output_directory=''
    Annotated_3UTR_file=''
    Output_result_file=''
    Num_least_in_group1_local=''
    Num_least_in_group2_local=''
    Coverage_cutoff_local = ''
    FDR_cutoff_local = ''
    Fold_change_cutoff_local = ''
    PDUI_cutoff_local = ''
    
    for line in open(cfg_file,'r'):
        if line[0] == '\n' or line[0] == '#':
            comments = line;
        else:
            line = line.rstrip();
            command = line.split('=');
            if command[0] == 'Group1_Tophat_aligned_Wig':
                Group1_Tophat_aligned_file = command[1].split(',');
            if command[0] == 'Group2_Tophat_aligned_Wig':
                Group2_Tophat_aligned_file = command[1].split(',');
            if command[0] == 'Output_directory':
                output_directory = command[1]
                if output_directory[-1] != '/':
                    output_directory += '/'
            if command[0] == 'Annotated_3UTR':
                Annotated_3UTR_file = command[1]
            if command[0] == 'Output_result_file':
                Output_result_file = command[1]
            
            ##Parameters
            if command[0] == 'Num_least_in_group1':
                Num_least_in_group1_local = command[1]
            if command[0] == 'Num_least_in_group2':
                Num_least_in_group2_local = command[1]
            if command[0] == 'Coverage_cutoff':
                Coverage_cutoff_local = command[1]
            if command[0] == 'FDR_cutoff':
                FDR_cutoff_local = command[1]
            if command[0] == 'Fold_change_cutoff':
                Fold_change_cutoff_local = command[1]
            if command[0] == 'PDUI_cutoff':
                PDUI_cutoff_local = command[1]
            
    
    if Group1_Tophat_aligned_file=='':
        print("No Tophat aligned BAM file for group 1!", file=sys.stderr)
        exit(1)
    if Group2_Tophat_aligned_file=='':
        print("No Tophat aligned BAM file for group 2!", file=sys.stderr)
        exit(1)
    if output_directory=='':
        print("No output directory!", file=sys.stderr)
        exit(1)
    if Annotated_3UTR_file=='':
        print("No annotated 3' UTR file!", file=sys.stderr)
        exit(1)
    if Output_result_file=='':
        print("No result file name!", file=sys.stderr)
        exit(1)
    return Group1_Tophat_aligned_file,Group2_Tophat_aligned_file,output_directory,Annotated_3UTR_file,Output_result_file,Num_least_in_group1_local,Num_least_in_group2_local,Coverage_cutoff_local,FDR_cutoff_local,Fold_change_cutoff_local,PDUI_cutoff_local

# %%
Group1_Tophat_aligned_file,Group2_Tophat_aligned_file,output_directory,Annotated_3UTR_file,Output_result_file,Num_least_in_group1_local,Num_least_in_group2_local,Coverage_cutoff_local,FDR_cutoff_local,Fold_change_cutoff_local,PDUI_cutoff_local = parse_cfgfile('/home/li/桌面/PROJECT6/apasite_predict2/DAPARS/DATA/DaPars_test_data_configure.txt')

# %%
output_directory='DaPars_Test_data/'

# %%
num_group_1 = len(Group1_Tophat_aligned_file)
All_Sample_files = Group1_Tophat_aligned_file[:]
All_Sample_files.extend(Group2_Tophat_aligned_file)

# %%
def Load_Target_Wig_files(All_Wig_files, UTR_Annotation_file):
    UTR_events_dict = {}
    All_Samples_Total_depth = []
    for line in open(UTR_Annotation_file,'r'):
        fields = line.strip('\n').split('\t')
        curr_chr = fields[0]
        region_start = int(float(fields[1]))
        region_end   = int(float(fields[2]))
        curr_strand  = fields[-1]
        UTR_pos = "%s:%s-%s" % (curr_chr, region_start, region_end)
        end_shift = int(round(abs(int(region_start) - int(region_end)) * 0.2))
        if curr_strand == '+':
            region_end = str(int(region_end) - end_shift)
        else:
            region_start = str(int(region_start) + end_shift)
        region_start = int(region_start) + 1
        region_end   = int(region_end) - 1
        if region_start + 50 < region_end:
            UTR_events_dict[fields[3]] = [fields[0],region_start,region_end,fields[-1],UTR_pos]

    ##Load coverage for all samples
    All_samples_extracted_3UTR_coverage_dict = {}
    for curr_wig_file in All_Wig_files:
        curr_sample_All_chroms_coverage_dict = {}
        num_line = 0
        cur_sample_total_depth = 0
        for line in open(curr_wig_file,'r'):
            if '#' not in line and line[0:3] == 'chr':
                fields = line.strip('\n').split('\t')
                chrom_name = fields[0]
                region_start = int(float(fields[1]))
                region_end = int(float(fields[2]))
                cur_sample_total_depth += int(float(fields[-1])) * (region_end - region_start)
                if chrom_name not in curr_sample_All_chroms_coverage_dict:
                    curr_sample_All_chroms_coverage_dict[chrom_name] = [[0],[0]]
                if region_start > curr_sample_All_chroms_coverage_dict[chrom_name][0][-1]:
                    curr_sample_All_chroms_coverage_dict[chrom_name][0].append(region_start)
                    curr_sample_All_chroms_coverage_dict[chrom_name][1].append(0)
                curr_sample_All_chroms_coverage_dict[chrom_name][0].append(region_end)
                curr_sample_All_chroms_coverage_dict[chrom_name][1].append(int(float(fields[-1])))
            num_line += 1
        curr_sample_All_chroms_coverage_dict[chrom_name][1].append(0)
        All_Samples_Total_depth.append(cur_sample_total_depth)
        for curr_3UTR_event_id in UTR_events_dict:
            curr_3UTR_structure = UTR_events_dict[curr_3UTR_event_id]
            curr_chr = curr_3UTR_structure[0]
            if curr_chr in curr_sample_All_chroms_coverage_dict:
                curr_chr_coverage = curr_sample_All_chroms_coverage_dict[curr_chr]
                region_start = curr_3UTR_structure[1]
                region_end = curr_3UTR_structure[2]
                left_region_index = bisect(curr_chr_coverage[0],region_start)
                right_region_index = bisect(curr_chr_coverage[0],region_end)

                extracted_coverage = curr_chr_coverage[1][left_region_index:right_region_index+1]
                extracted_3UTR_region = curr_chr_coverage[0][left_region_index:right_region_index]
                extracted_3UTR_region.insert(0,region_start)
                extracted_3UTR_region.append(region_end)
                if curr_3UTR_event_id not in All_samples_extracted_3UTR_coverage_dict:
                    All_samples_extracted_3UTR_coverage_dict[curr_3UTR_event_id] = []
                All_samples_extracted_3UTR_coverage_dict[curr_3UTR_event_id].append([extracted_coverage,extracted_3UTR_region])
    return All_samples_extracted_3UTR_coverage_dict,np.array(All_Samples_Total_depth),UTR_events_dict

# %%
#Load_Target_Wig_files
All_samples_Target_3UTR_coverages, All_samples_sequencing_depths, UTR_events_dict = Load_Target_Wig_files(All_Sample_files, Annotated_3UTR_file)

# %%
#All_samples_Target_3UTR_coverages
len(All_samples_Target_3UTR_coverages)
# Out:
# 1043

# %%
#All_samples_sequencing_depths
All_samples_sequencing_depths
# Out:
# array([475249457, 453111546])

# %%
#UTR_events_dict
len(UTR_events_dict)
# Out:
# 24983

# %%
for i in UTR_events_dict:
    print(i)
# Out:
# NM_001003805|ATP5S|chr14|+
# NM_001003800|BICD2|chr9|-
# NM_001008781|FAT3|chr11|+
# NM_001008783|SLC35D3|chr6|+
# NR_003227|AFG3L1P|chr16|+
# NR_003226|AFG3L1P|chr16|+
# NR_003225|LGALS3|chr14|+
# NR_003224|SNORD114-31|chr14|+
# NR_003223|SNORD114-30|chr14|+
# NR_003222|SNORD114-29|chr14|+
# NR_003221|SNORD114-28|chr14|+
# NR_003220|SNORD114-27|chr14|+
# NR_003229|SNORD113-1|chr14|+
# NR_003228|AFG3L1P|chr16|+
# NM_001468|GAGE1|chrX|+
# NM_001469|XRCC6|chr22|+
# NM_001466|FZD2|chr17|+
# NM_001467|SLC37A4|chr11|-
# NM_001464|ADAM2|chr8|-
# NM_001465|FYB|chr5|-
# NM_001462|FPR2|chr19|+
# NM_001463|FRZB|chr2|-
# NM_001460|FMO2|chr1|+
# NM_000331|SAA1|chr11|+
# NM_001164245|C1orf27|chr1|+
# NM_007101|SARDH|chr9|-
# NM_000332|ATXN1|chr6|-
# NM_007107|SSR3|chr3|-
# NM_007106|UBL3|chr13|-
# NM_000337|SGCD|chr5|+
# NM_000336|SCNN1B|chr16|+
# NM_007109|TCF19|chr6|+
# NM_007108|TCEB2|chr16|-
# NM_001012969|ADAL|chr15|+
# NM_001012968|SPIN4|chrX|-
# NM_001012967|DDX60L|chr4|-
# NM_001012965|KLK6|chr19|-
# NM_001012964|KLK6|chr19|-
# NM_003824|FADD|chr11|+
# NM_003826|NAPG|chr18|+
# NM_001167912|VEPH1|chr3|-
# NM_003820|TNFRSF14|chr1|+
# NM_003821|RIPK2|chr8|+
# NM_003822|NR5A2|chr1|+
# NM_001167916|VEPH1|chr3|-
# NM_003828|MTMR1|chrX|+
# NM_003829|MPDZ|chr9|-
# NM_001025780|FAM108B1|chr9|-
# NM_024036|LRFN4|chr11|+
# NM_024037|C1orf135|chr1|-
# NM_001164796|SLC25A26|chr3|+
# NM_024031|PRR14|chr16|+
# NM_001161546|C5orf65|chr5|-
# NM_024038|C19orf43|chr19|-
# NM_018303|EXOC2|chr6|-
# NR_038433|LINC00330|chr13|-
# NM_018304|PRR11|chr17|+
# NM_018307|RHOT1|chr17|+
# NM_018306|TMEM40|chr3|-
# NM_001193333|CORO1A|chr16|+
# NM_006272|S100B|chr21|-
# NM_001011725|HNRNPA1L2|chr13|+
# NM_006270|RRAS|chr19|-
# NM_006271|S100A1|chr1|+
# NM_001011720|XKR9|chr8|+
# NM_006277|ITSN2|chr2|-
# NM_006274|CCL19|chr9|-
# NM_006275|SRSF6|chr20|+
# NM_006278|ST3GAL4|chr11|+
# NM_001193388|UNKL|chr16|-
# NM_001002034|FAM109B|chr22|+
# NM_001002035|DEFB108B|chr11|+
# NM_001002036|ASTL|chr2|-
# NR_031653|MIR1251|chr12|+
# NR_031652|MIR1250|chr17|-
# NR_031650|MIR1248|chr3|+
# NR_031654|MIR1253|chr17|-
# NM_032961|PCDH10|chr4|+
# NM_032960|MAPKAPK2|chr1|+
# NR_031659|MIR1258|chr2|-
# NR_031658|MIR1257|chr20|-
# NM_032965|CCL15|chr17|-
# NM_032967|PCDH11X|chrX|+
# NM_032966|CXCR5|chr11|+
# NR_030527|MIR765|chr1|-
# NR_030528|MIR770|chr14|+
# NM_003176|SYCP1|chr1|+
# NM_003177|SYK|chr9|+
# NM_003175|XCL2|chr1|-
# NM_003172|SURF1|chr9|-
# NM_003173|SUV39H1|chrX|+
# NM_003170|SUPT6H|chr17|+
# NM_003171|SUPV3L1|chr10|+
# NM_001128847|SMARCA4|chr19|+
# NM_001128843|TNIP3|chr4|-
# NM_003178|SYN2|chr3|+
# NM_003179|SYP|chrX|-
# NM_002889|RARRES2|chr7|-
# NM_002888|RARRES1|chr3|-
# NM_001098398|COPA|chr1|-
# NM_002887|RARS|chr5|+
# NM_002886|RAP2B|chr3|+
# NM_002881|RALB|chr2|+
# NM_002880|RAF1|chr3|-
# NM_002883|RANGAP1|chr22|-
# NM_002882|RANBP1|chr22|+
# NM_001010860|SAMD15|chr14|+
# NM_001077269|WIPF1|chr2|-
# NM_001081559|CPSF4|chr7|+
# NM_001081552|SPAG11A|chr8|+
# NM_001081550|THOC2|chrX|-
# NM_001081551|DEFB103A|chr8|+
# NM_001010895|ERCC6L2|chr9|+
# NM_001010897|SERP2|chr13|+
# NM_001010896|C10orf113|chr10|-
# NM_001010890|PRAMEF9|chr1|+
# NM_001010893|SLC10A5|chr8|-
# NM_001003785|ATP5H|chr17|-
# NM_001010898|SLC6A17|chr1|+
# NM_014008|CCDC22|chrX|+
# NM_014009|FOXP3|chrX|-
# NM_014007|ZBTB43|chr9|+
# NM_014004|PCDHGA8|chr5|+
# NM_014005|PCDHA9|chr5|+
# NM_014002|IKBKE|chr1|+
# NM_014003|DHX38|chr16|+
# NM_014000|VCL|chr10|+
# NM_014001|GGA3|chr17|-
# NM_015351|TTC9|chr14|+
# NM_015350|LRRC8B|chr1|+
# NM_015353|KCTD2|chr17|+
# NM_015352|POFUT1|chr20|+
# NM_015355|SUZ12|chr17|+
# NM_015354|NUP188|chr9|+
# NM_007102|GUCA2B|chr1|+
# NR_027346|LINC00173|chr12|+
# NR_027347|ZNRF2P2|chr7|-
# NM_018584|CAMK2N1|chr1|-
# NR_027342|FKBP9L|chr7|-
# NR_027341|LINC00475|chr9|+
# NM_002229|JUNB|chr19|+
# NM_002228|JUN|chr1|-
# NM_001166139|LCORL|chr4|-
# NM_002221|ITPKB|chr1|-
# NM_002220|ITPKA|chr15|+
# NM_002223|ITPR2|chr12|-
# NM_002222|ITPR1|chr3|+
# NM_002225|IVD|chr15|+
# NM_002224|ITPR3|chr6|+
# NM_002227|JAK1|chr1|-
# NM_001166133|FRAS1|chr4|+
# NM_001004060|NOMO2|chr16|-
# NM_001004063|OR4K1|chr14|+
# NM_001004064|OR8J3|chr11|-
# NM_001004067|NOMO3|chr16|+
# NM_007104|RPL10A|chr6|+
# NM_001163560|C16orf73|chr16|-
# NM_001163561|C2orf61|chr2|-
# NM_018055|NODAL|chr10|-
# NM_018054|ARHGAP17|chr16|-
# NR_033248|LOC100329109|chr2|-
# NM_018056|TMEM39B|chr1|+
# NM_018051|WDR60|chr7|+
# NM_018050|MANSC1|chr12|-
# NM_018053|XKR8|chr1|+
# NM_018052|VAC14|chr16|-
# NR_033242|C19orf79|chr19|+
# NR_033243|UBAP1|chr9|+
# NR_033240|LOC100129794|chr14|+
# NM_001255981|CREB3L4|chr1|+
# NM_018059|RADIL|chr7|-
# NM_018058|CRTAC1|chr10|-
# NR_033244|LOC729080|chr5|-
# NR_033245|LOC641746|chr7|+
# NR_029379|LOC100132163|chrX|+
# NR_029378|LOC100289511|chr14|-
# NR_029374|LOC641518|chr4|+
# NR_029376|LOC100294362|chr17|-
# NR_029372|NT5C3|chr7|-
# NM_001256188|SNX12|chrX|-
# NM_001142352|ST6GAL2|chr2|-
# NM_014911|AAK1|chr2|-
# NM_014912|CPEB3|chr10|-
# NM_014913|ADNP2|chr18|+
# NM_014914|AGAP1|chr2|+
# NM_014915|ANKRD26|chr10|-
# NM_014916|LMTK2|chr7|+
# NM_014918|CHSY1|chr15|-
# NM_001005338|OR5H1|chr3|+
# NM_001032409|OAS1|chr12|+
# NM_001002812|PDE4DIP|chr1|-
# NM_001206972|PTPRB|chr12|-
# NM_001171629|VEGFA|chr6|+
# NM_001167917|VEPH1|chr3|-
# NM_001079653|SDK1|chr7|+
# NM_003823|TNFRSF6B|chr20|+
# NM_001149|ANK3|chr10|-
# NM_004319|ASTN1|chr1|-
# NM_001141|ALOX15B|chr17|+
# NM_004312|ARR3|chrX|+
# NM_001143|AMELY|chrY|-
# NM_004310|RHOH|chr4|+
# NM_004317|ASNA1|chr19|+
# NM_004316|ASCL1|chr12|+
# NM_004315|ASAH1|chr8|-
# NM_001146|ANGPT1|chr8|-
# NM_001201473|CORO7|chr16|-
# NM_001201477|NETO2|chr16|-
# NM_001201476|C18orf21|chr18|+
# NM_001001548|CD36|chr7|+
# NM_001201479|CORO7-PAM16|chr16|-
# NM_025029|MZT2B|chr2|+
# NM_020056|HLA-DQA2|chr6|+
# NM_025027|ZNF606|chr19|-
# NM_024993|LRRTM4|chr2|-
# NM_024991|SORBS1|chr10|-
# NM_024996|GFM1|chr3|+
# NM_018419|SOX18|chr20|-
# NM_020726|NLN|chr5|+
# NR_024066|CLRN1-AS1|chr3|+
# NR_024065|LINC00312|chr3|+
# NR_024062|UBE2DNL|chrX|+
# NR_024063|ZSCAN12P1|chr6|+
# NR_024060|FAM27A|chr9|+
# NR_024061|LOH12CR2|chr12|-
# NM_198887|NUP43|chr6|-
# NM_198881|TBC1D8B|chrX|+
# NM_198883|MTX1|chr1|+
# NM_198889|ANKRD17|chr4|-
# NM_145274|TMEM99|chr17|+
# NM_145276|ZNF563|chr19|-
# NM_145277|HFE2|chr1|+
# NM_145270|C16orf11|chr16|+
# NM_145272|C17orf50|chr17|+
# NM_145273|CD300LG|chr17|+
# NM_145278|C1orf150|chr1|+
# NM_145279|MOB3C|chr1|-
# NM_024039|MIS12|chr17|+
# NM_021821|MRPS35|chr12|+
# NM_021822|APOBEC3G|chr22|+
# NM_021823|PPCDC|chr15|+
# NM_021825|CCDC90B|chr11|-
# NM_021826|FASTKD5|chr20|-
# NM_021827|CCDC81|chr11|+
# NM_078468|BCCIP|chr10|+
# NM_078469|BCCIP|chr10|+
# NM_145858|CRYZL1|chr21|-
# NM_001100916|MBOAT4|chr8|-
# NM_001100917|TSPAN19|chr12|-
# NM_001100915|KCTD19|chr16|-
# NM_001100912|BEND7|chr10|-
# NM_001100910|FAM72B|chr1|+
# NR_026576|SAA3P|chr11|-
# NR_026575|GK3P|chr4|-
# NR_026571|NOX4|chr11|-
# NR_026578|LOC647859|chr5|-
# NM_001204410|SEC14L1|chr17|+
# NM_001105243|PCDH19|chrX|-
# NM_001105244|PTPRM|chr18|+
# NM_001105247|ARMC5|chr16|+
# NM_001105248|TMC5|chr16|+
# NR_027620|SCGB1B2P|chr19|-
# NR_027622|LOC100128164|chr3|-
# NR_027626|CMAHP|chr6|-
# NM_020880|ZNF530|chr19|+
# NM_020883|ZSWIM5|chr1|-
# NM_020882|COL20A1|chr20|+
# NM_020884|MYH7B|chr20|+
# NM_020886|USP28|chr11|-
# NM_020889|PHF12|chr17|-
# NM_181872|DMRT2|chr9|+
# NM_181873|MTMR11|chr1|-
# NM_181871|PKLR|chr1|-
# NM_181877|ZSCAN2|chr15|+
# NM_005116|SLC23A2|chr20|-
# NM_001256872|USP17L8|chr8|-
# NM_005114|HS3ST1|chr4|-
# NM_058187|FAM176C|chr21|+
# NM_001256870|POLD4|chr11|-
# NM_058182|FAM165B|chr21|+
# NM_058181|YBEY|chr21|+
# NM_058180|C21orf58|chr21|-
# NM_187841|TRIM54|chr2|+
# NM_030632|ASXL3|chr18|+
# NM_030631|SLC25A21|chr14|-
# NM_030630|C17orf28|chr17|-
# NM_030636|EEPD1|chr7|+
# NM_030634|ZNF436|chr1|-
# NM_021599|ADAMTS2|chr5|-
# NM_006273|CCL7|chr17|+
# NM_021046|KRTAP5-8|chr11|+
# NM_021047|ZNF253|chr19|+
# NM_021044|DHH|chr12|-
# NM_021045|ZNF248|chr10|-
# NM_173518|C8orf45|chr8|+
# NM_173519|CLVS1|chr8|+
# NM_173514|SLC38A9|chr5|-
# NM_173515|CNKSR3|chr6|-
# NM_173516|PNLDC1|chr6|+
# NM_173517|VKORC1L1|chr7|+
# NM_173510|CCDC117|chr22|+
# NM_173511|FAM117B|chr2|+
# NM_173512|SLC38A11|chr2|-
# NM_021049|MAGEA5|chrX|-
# NM_201550|LRRC10|chr12|-
# NR_034065|CASP12|chr11|-
# NM_201557|FHL2|chr2|-
# NM_201559|FOXO3|chr6|+
# NM_001199097|BAIAP3|chr16|+
# NR_024549|DMTF1|chr7|+
# NM_175913|JPH2|chr20|-
# NM_175910|ZNF493|chr19|+
# NM_175911|OR2L13|chr1|+
# NM_175914|HNF4A|chr20|+
# NR_024541|LY6G6E|chr6|-
# NR_024540|WASH7P|chr1|-
# NM_175918|CRIPAK|chr4|+
# NM_001193630|LOC100132396|chr8|+
# NM_003374|VDAC1|chr5|-
# NM_003377|VEGFB|chr11|+
# NM_001042522|SPRED3|chr19|+
# NM_005193|CDX4|chrX|+
# NM_198141|GANC|chr15|+
# NM_144668|WDR66|chr12|+
# NM_144669|GLT1D1|chr12|+
# NM_198147|ABHD15|chr17|-
# NM_198148|CPXM2|chr10|-
# NR_036678|LOC283299|chr11|-
# NM_144666|DNHD1|chr11|+
# NM_144660|SAMD8|chr10|+
# NM_144661|C10orf82|chr10|-
# NM_144662|PSMA8|chr18|+
# NM_144663|C11orf40|chr11|-
# NM_020319|ANKMY2|chr7|-
# NM_020318|PAPPA2|chr1|+
# NM_001197293|DPYSL2|chr8|+
# NM_001197295|ECM2|chr9|-
# NM_001197297|GABPA|chr21|+
# NM_001197296|ECM2|chr9|-
# NM_020311|CXCR7|chr2|+
# NM_020310|MNT|chr17|-
# NM_020313|CIAPIN1|chr16|-
# NM_020312|COQ9|chr16|+
# NM_020315|PDXP|chr22|+
# NM_020314|C16orf62|chr16|+
# NM_020317|C1orf63|chr1|-
# NM_022781|RNF38|chr9|-
# NM_022782|MPHOSPH9|chr12|-
# NM_001135937|SMAD2|chr18|-
# NM_032963|CCL14|chr17|-
# NM_201430|RTN3|chr11|+
# NR_002770|DIO3OS|chr14|-
# NM_018217|EDEM2|chr20|-
# NM_018216|PANK4|chr1|-
# NM_018215|PNMAL1|chr19|-
# NM_018214|LRRC1|chr6|+
# NM_005194|CEBPB|chr20|+
# NM_018212|ENAH|chr1|-
# NM_018211|RAVER2|chr1|+
# NM_018210|CARKD|chr13|+
# NM_018219|CCDC87|chr11|-
# NM_018218|USP40|chr2|-
# NM_001039481|ETNK1|chr12|+
# NM_032667|BSCL2|chr11|-
# NM_032569|GLYR1|chr16|-
# NM_032565|EBPL|chr13|-
# NM_032564|DGAT2|chr11|+
# NM_032567|SPZ1|chr5|+
# NM_032566|SPINK7|chr5|+
# NM_032561|C22orf23|chr22|-
# NM_032560|SMEK1|chr14|-
# NM_032563|LCE3D|chr1|-
# NM_032562|PLA2G12B|chr10|-
# NM_182751|MCM10|chr10|+
# NR_002774|HTR7P1|chr12|+
# NM_033382|SEC14L2|chr22|+
# NM_033380|COL4A5|chrX|+
# NM_033386|MICALL1|chr22|+
# NM_033387|FAM78A|chr9|-
# NM_012351|OR10J1|chr1|+
# NM_033388|ATG16L2|chr11|+
# NM_033389|SSH2|chr17|-
# NM_001168368|GALNTL1|chr14|+
# NR_002775|RPLP0P2|chr11|+
# NM_004999|MYO6|chr6|+
# NR_028351|FLJ33360|chr5|-
# NM_001195103|GSR|chr8|-
# NM_005001|NDUFA7|chr19|-
# NM_005002|NDUFA9|chr12|+
# NM_005003|NDUFAB1|chr16|-
# NR_002435|SNORD100|chr6|+
# NR_002434|SNORD101|chr6|+
# NR_002436|SNORA33|chr6|+
# NM_005008|NHP2L1|chr22|-
# NR_002438|ZFAT-AS1|chr8|+
# NM_032383|HPS3|chr3|+
# NM_001195108|TLR10|chr4|-
# NM_032385|C5orf4|chr5|-
# NM_032387|WNK4|chr17|+
# NM_213613|SLC26A1|chr4|-
# NM_177424|STX12|chr1|+
# NM_080474|SERPINB12|chr18|+
# NM_080475|SERPINB11|chr18|+
# NM_001128840|CACNA1D|chr3|+
# NM_177423|PPFIA1|chr11|+
# NM_001168361|PCDH11X|chrX|+
# NM_001783|CD79A|chr19|+
# NM_001782|CD72|chr9|-
# NM_001781|CD69|chr12|-
# NM_001785|CDA|chr1|+
# NM_001784|CD97|chr19|+
# NM_174881|CRB3|chr19|+
# NM_001129727|PLEKHG4|chr16|+
# NM_174889|NDUFAF2|chr5|+
# NM_001011880|CLEC18B|chr16|-
# NM_001206847|LOC100507341|chr8|+
# NR_045106|C15orf44|chr15|-
# NM_020783|SYT4|chr18|-
# NM_004663|RAB11A|chr15|+
# NM_004661|CDC23|chr5|-
# NM_001017398|TRIM36|chr5|-
# NM_004667|HERC2|chr15|-
# NM_004666|VNN1|chr6|-
# NM_025228|TRAF3IP3|chr1|+
# NM_004664|LIN7A|chr12|-
# NM_001017392|SUGP2|chr19|-
# NM_004669|CLIC3|chr9|-
# NM_004668|MGAM|chr7|+
# NM_025222|WDR82|chr3|-
# NM_000784|CYP27A1|chr2|+
# NM_000785|CYP27B1|chr12|-
# NM_000786|CYP51A1|chr7|-
# NM_000787|DBH|chr9|+
# NM_000780|CYP7A1|chr8|-
# NM_000782|CYP24A1|chr20|-
# NM_000783|CYP26A1|chr10|+
# NM_000788|DCK|chr4|+
# NR_002433|SNORD12C|chr20|+
# NM_001164189|PLIN3|chr19|-
# NM_016309|LCMT1|chr16|+
# NM_016308|CMPK1|chr1|+
# NM_016307|PRRX2|chr9|+
# NM_016306|DNAJB11|chr3|+
# NM_016305|SS18L2|chr3|+
# NM_016304|RSL24D1|chr15|-
# NM_016303|WBP5|chrX|+
# NM_016301|GPN3|chr12|-
# NM_016300|ARPP21|chr3|+
# NM_015962|FCF1|chr14|+
# NM_015960|CUTC|chr10|+
# NM_015966|ERGIC3|chr20|+
# NM_015964|TPPP3|chr16|-
# NM_015965|NDUFA13|chr19|+
# NM_015969|MRPS17|chr7|+
# NM_153809|TAF1L|chr9|-
# NM_001015508|PURG|chr8|-
# NM_138448|ACYP2|chr2|+
# NM_138447|ZNF689|chr16|-
# NM_138446|MALSU1|chr7|+
# NM_138445|GPR146|chr7|+
# NM_138444|KCTD12|chr13|-
# NM_001161353|KCNMA1|chr10|-
# NM_138441|MB21D1|chr6|-
# NM_138440|VASN|chr16|+
# NR_031598|MIR1229|chr5|-
# NR_031599|MIR1231|chr1|+
# NR_029515|MIR100|chr11|-
# NR_031595|MIR1226|chr3|+
# NR_029517|MIR29B1|chr7|-
# NR_029516|MIR101-1|chr1|-
# NR_031590|MIR1179|chr15|+
# NR_029510|MIR93|chr7|-
# NR_029513|MIR98|chrX|-
# NR_031593|MIR1182|chr1|-
# NM_007312|HYAL1|chr3|-
# NM_007313|ABL1|chr9|+
# NM_001164457|ZNF705G|chr8|-
# NM_007317|KIF22|chr16|+
# NM_007314|ABL2|chr1|-
# NM_007315|STAT1|chr2|-
# NM_001164459|ACTR3C|chr7|-
# NM_002926|RGS12|chr4|+
# NM_002927|RGS13|chr1|+
# NM_002924|RGS7|chr1|-
# NM_002925|RGS10|chr10|-
# NM_002922|RGS1|chr1|+
# NM_002923|RGS2|chr1|+
# NM_002928|RGS16|chr1|-
# NM_002929|GRK1|chr13|+
# NM_001080520|DRGX|chr10|-
# NM_001080521|RASSF10|chr11|+
# NM_001080522|CC2D2A|chr4|+
# NM_001080523|ARRDC5|chr19|-
# NM_001080524|C16orf90|chr16|-
# NM_001080525|SPINK8|chr3|-
# NM_001080527|MYO7B|chr2|+
# NM_001080528|LOC646498|chr3|-
# NM_001080529|WIPF3|chr7|+
# NR_026778|HNRNPU-AS1|chr1|-
# NR_026779|LINC00341|chr14|-
# NR_026770|FAM215A|chr17|+
# NR_026771|DKFZP434L187|chr15|+
# NR_026772|C8orf71|chr8|+
# NR_026773|C6orf123|chr6|-
# NR_026774|LINC00239|chr14|+
# NR_026775|LINC00240|chr6|+
# NR_026776|LOC100270746|chr6|-
# NR_026777|ZNF37BP|chr10|-
# NM_001163150|ETV1|chr7|-
# NM_001160109|NOS3|chr7|+
# NM_001672|ASIP|chr20|+
# NM_152447|LRFN5|chr14|+
# NM_152446|CEP128|chr14|-
# NM_152445|FAM161B|chr14|-
# NM_152443|RDH12|chr14|+
# NM_152442|RAD9B|chr12|+
# NM_152441|FBXL14|chr12|-
# NM_152440|C12orf66|chr12|-
# NM_020433|JPH2|chr20|-
# NM_152449|LYSMD4|chr15|-
# NM_152448|C15orf43|chr15|+
# NM_001123378|ADSL|chr22|+
# NM_001123375|HIST2H3D|chr1|-
# NM_001257134|COX14|chr12|+
# NM_001123377|PARK7|chr1|+
# NM_001123376|TMEM72|chr10|+
# NM_001204160|SPHK2|chr19|+
# NM_152995|NFXL1|chr4|-
# NM_152994|PPP1R21|chr2|+
# NM_152997|FDCSP|chr4|+
# NM_152996|ST6GALNAC3|chr1|+
# NM_152991|EED|chr11|+
# NM_152990|PXT1|chr6|-
# NM_152992|POMZP3|chr7|-
# NM_001127612|PAX6|chr11|-
# NM_001077358|PDE11A|chr2|-
# NM_001040659|TTC23|chr15|-
# NM_001127615|ENOX1|chr13|-
# NM_001077351|RBM23|chr14|-
# NM_001040653|ZXDC|chr3|-
# NM_001040651|CD3D|chr11|-
# NM_001004744|OR5R1|chr11|-
# NM_001098634|RBM47|chr4|-
# NM_001004746|OR5T2|chr11|-
# NM_001004747|OR5T3|chr11|+
# NM_001004740|OR5M1|chr11|-
# NM_001098630|IRF5|chr7|+
# NM_001004742|OR5M3|chr11|-
# NM_001004743|OR5M9|chr11|-
# NM_001004748|OR51A2|chr11|-
# NM_001004749|OR51A7|chr11|+
# NM_015140|TTLL12|chr22|-
# NM_015141|GPD1L|chr3|+
# NM_015143|METAP1|chr4|+
# NM_015144|ZCCHC14|chr16|-
# NM_015146|SEPT8|chr5|-
# NM_015147|CEP68|chr2|+
# NM_015149|RGL1|chr1|+
# NM_001004297|OR13A1|chr10|-
# NM_001004298|C10orf90|chr10|-
# NM_001005163|OR52D1|chr11|+
# NM_001178118|MINPP1|chr10|+
# NM_001005161|OR52B4|chr11|-
# NM_001005160|OR52A5|chr11|-
# NM_001005167|OR52E6|chr11|-
# NM_001005165|OR52E4|chr11|+
# NM_001005164|OR52E2|chr11|-
# NM_001005169|OR52I1|chr11|+
# NM_001005168|OR52E8|chr11|-
# NM_194439|RNF212|chr4|-
# NM_194431|RNASE4|chr14|+
# NR_027349|MIR17HG|chr13|+
# NM_015358|MORC3|chr21|+
# NR_027345|LINC00173|chr12|+
# NM_021201|MS4A7|chr11|+
# NM_021202|TP53INP2|chr20|+
# NM_021203|SRPRB|chr3|+
# NM_021204|ENOPH1|chr4|+
# NM_001099218|RAD51AP2|chr2|-
# NM_001099219|KRTAP19-8|chr21|-
# NM_203364|CAPRIN1|chr11|+
# NM_017966|VPS37C|chr11|-
# NR_024389|FLJ16779|chr20|+
# NR_024388|LOC152217|chr3|+
# NR_024383|LINC00461|chr5|-
# NM_001142673|ATG13|chr11|+
# NR_024380|LOC441666|chr10|-
# NR_024387|CXADRP2|chr15|-
# NM_001142674|CHID1|chr11|-
# NR_024385|LOC151300|chr2|+
# NM_001001664|SPOPL|chr2|+
# NM_001001665|CYP27C1|chr2|-
# NM_001001666|ANO7|chr2|+
# NM_001001667|OR6V1|chr7|+
# NM_001001660|LYRM5|chr12|+
# NM_001001661|ZNF425|chr7|-
# NM_001001662|ZNF782|chr9|-
# NM_001001663|TMEM211|chr22|-
# NM_001001668|ZNF470|chr19|+
# NM_001001669|ARHGEF37|chr5|+
# NM_001166131|EME1|chr17|+
# NM_181472|CMTM7|chr3|+
# NM_181471|RFC2|chr7|-
# NM_182920|ADAMTS9|chr3|-
# NM_145333|MAP3K7|chr6|-
# NM_182922|HEATR3|chr16|+
# NM_182925|FLT4|chr5|-
# NM_182924|MICALL2|chr7|-
# NM_182926|KTN1|chr14|+
# NM_004508|IDI1|chr10|-
# NM_004509|SP110|chr2|-
# NM_004502|HOXB7|chr17|-
# NM_004503|HOXC6|chr12|+
# NM_004500|HNRNPC|chr14|-
# NM_004507|HUS1|chr7|-
# NM_004504|AGFG1|chr2|+
# NM_004505|USP6|chr17|+
# NM_004280|EEF1E1|chr6|-
# NM_001199828|SPRR1A|chr1|+
# NM_001199829|HORMAD1|chr1|-
# NR_029408|LOC439994|chr10|+
# NM_001159388|B4GALNT2|chr17|+
# NM_001039649|ZMYM5|chr13|-
# NR_030311|MIR585|chr5|-
# NM_018057|SLC6A15|chr12|-
# NM_001177800|ADIPOQ|chr3|+
# NR_030312|MIR548A1|chr6|+
# NM_001136023|NFE2|chr12|-
# NM_001136022|NFATC4|chr14|+
# NM_001136020|ICA1|chr7|-
# NM_006591|POLD3|chr11|+
# NM_001024593|MSS51|chr10|-
# NM_001177701|IFT27|chr22|-
# NM_001024594|C1orf53|chr1|+
# NM_001024599|HIST2H2BF|chr1|-
# NM_001024598|HES3|chr1|+
# NM_001170570|CXorf56|chrX|-
# NM_033140|CALD1|chr7|+
# NM_033141|MAP3K9|chr14|-
# NM_033142|CGB7|chr19|-
# NM_033143|FGF5|chr4|+
# NM_033148|DTNB|chr2|-
# NM_033107|GTPBP10|chr7|+
# NM_080678|UBE2F|chr2|+
# NM_080679|COL11A2|chr6|-
# NM_080670|SLC35A4|chr5|+
# NM_080671|KCNE4|chr2|+
# NM_080675|SUN5|chr20|-
# NM_080676|MACROD2|chr20|+
# NM_080677|DYNLL2|chr17|+
# NM_001145951|TIMM8A|chrX|-
# NM_001007156|NTRK3|chr15|-
# NM_001110533|C1orf177|chr1|+
# NM_001190441|LGALS16|chr19|+
# NM_147223|NCOA1|chr2|+
# NM_001190442|CAST|chr5|+
# NM_001813|CENPE|chr4|-
# NM_001812|CENPC1|chr4|-
# NM_130470|MADD|chr11|+
# NM_001810|CENPB|chr20|-
# NM_001817|CEACAM4|chr19|-
# NM_001816|CEACAM8|chr19|-
# NM_001815|CEACAM3|chr19|+
# NM_001814|CTSC|chr11|-
# NM_001819|CHGB|chr20|+
# NM_001818|AKR1C4|chr10|+
# NM_020928|ZSWIM6|chr5|+
# NM_020929|LRRC4C|chr11|-
# NM_020922|WNK3|chrX|-
# NM_020923|ZDBF2|chr2|+
# NM_020920|CHD8|chr14|-
# NM_020921|NIN|chr14|-
# NM_020927|VAT1L|chr16|+
# NM_020924|ZBTB26|chr9|-
# NM_020925|CACHD1|chr1|+
# NR_038985|LOC100132987|chr10|+
# NR_038986|LOC100507470|chr10|+
# NR_038987|LOC100507489|chr6|-
# NR_038980|LOC100506207|chr6|+
# NR_038981|LOC100507254|chr6|+
# NR_038982|LOC100507346|chr9|+
# NR_038983|LOC100506134|chr2|+
# NR_038988|LOC100287765|chrX|+
# NR_038989|LOC100507584|chr6|-
# NM_016141|DYNC1LI1|chr3|-
# NM_016142|HSD17B12|chr11|+
# NM_016145|WDR83OS|chr19|-
# NM_016144|COMMD10|chr5|+
# NM_016147|PPME1|chr11|+
# NM_016146|TRAPPC4|chr11|+
# NM_016148|SHANK1|chr19|-
# NM_001159601|RAB28|chr4|-
# NM_017816|LYAR|chr4|-
# NM_017817|RAB20|chr13|-
# NM_017810|ZNF434|chr16|-
# NM_017811|UBE2R2|chr9|+
# NM_017812|CHCHD3|chr7|-
# NM_017813|IMPAD1|chr8|-
# NM_017818|WRAP73|chr1|-
# NM_017819|RG9MTD1|chr3|+
# NM_016497|MRPL51|chr12|-
# NM_016495|TBC1D7|chr6|-
# NM_016494|RNF181|chr2|+
# NM_016492|RANGRF|chr17|+
# NM_016491|MRPL37|chr1|+
# NM_016499|TMEM216|chr11|+
# NM_016498|MTFP1|chr22|+
# NM_001012512|GRP|chr18|+
# NM_001012511|GOSR2|chr17|+
# NM_001130404|PRR20B|chr13|+
# NM_017646|TRIT1|chr1|-
# NM_173499|SPATA8|chr15|+
# NM_173491|LSM11|chr5|+
# NM_173490|TMEM171|chr5|+
# NM_173493|PASD1|chrX|+
# NM_173495|PTCHD1|chrX|+
# NM_173494|CXorf41|chrX|+
# NM_173497|HECTD2|chr10|+
# NM_173496|MPP7|chr10|-
# NM_199420|POLQ|chr3|-
# NM_199423|WWP2|chr16|+
# NM_199425|VSX1|chr20|-
# NM_199427|ZFP64|chr20|-
# NR_046354|FAM90A2P|chr8|-
# NR_046357|RNF165|chr18|+
# NR_046351|FAM90A10P|chr8|+
# NM_178861|RNF113B|chr13|-
# NM_178860|SEZ6|chr17|-
# NM_178863|KCTD13|chr16|-
# NM_178862|STT3B|chr3|+
# NM_178864|NPAS4|chr11|+
# NM_178868|CMTM8|chr3|+
# NM_175895|C12orf61|chr12|-
# NM_173728|ARHGEF15|chr17|+
# NM_001042482|TPK1|chr7|-
# NM_001042486|DLGAP4|chr20|+
# NM_175767|IL6ST|chr5|-
# NM_003508|FZD9|chr7|+
# NM_003502|AXIN1|chr16|-
# NM_003501|ACOX3|chr4|-
# NM_003500|ACOX2|chr3|-
# NM_175769|TCF23|chr2|+
# NM_003506|FZD6|chr8|+
# NM_003505|FZD1|chr7|+
# NM_001197318|CLEC2D|chr12|+
# NM_001166340|SENP8|chr15|+
# NM_001166346|MDFIC|chr7|+
# NM_001256064|CNTN1|chr12|+
# NM_005900|SMAD1|chr4|+
# NM_005903|SMAD5|chr5|+
# NM_001256067|NOXA1|chr9|+
# NM_005904|SMAD7|chr18|-
# NM_005907|MAN1A1|chr6|-
# NM_005906|MAK|chr6|-
# NM_005909|MAP1B|chr5|+
# NM_005908|MANBA|chr4|-
# NM_032486|DCTN5|chr16|+
# NM_032487|ACTRT3|chr3|-
# NM_032482|DOT1L|chr19|+
# NM_032483|PPAPDC1B|chr8|-
# NM_032488|CNFN|chr19|-
# NM_032489|ACRBP|chr12|-
# NM_031288|INO80B|chr2|+
# NM_031287|SF3B5|chr6|-
# NM_031286|SH3BGRL3|chr1|+
# NM_031280|MRPS15|chr1|-
# NM_031283|TCF7L1|chr2|+
# NM_031282|FCRL4|chr1|-
# NM_032738|FCRLA|chr1|+
# NM_032735|BEST3|chr12|-
# NM_032737|LMNB2|chr19|-
# NM_032730|RTN4IP1|chr6|-
# NM_032731|TXNDC17|chr17|+
# NR_003615|LOC728554|chr5|+
# NR_003612|FAM92A3|chr4|+
# NR_003613|PMS2P1|chr7|-
# NR_003610|PDXDC2P|chr16|-
# NR_003611|BMS1P5|chr10|-
# NM_002673|PLXNB1|chr3|-
# NM_002670|PLS1|chr3|+
# NM_002676|PMM1|chr22|-
# NM_002677|PMP2|chr8|-
# NM_178836|PLD6|chr17|-
# NM_001039360|ZBTB7C|chr18|-
# NM_001039361|PRAMEF10|chr1|-
# NM_015439|CCDC28A|chr6|+
# NM_015431|TRIM58|chr1|+
# NM_015434|INTS7|chr1|-
# NR_002201|FTH1P3|chr2|-
# NM_003262|SEC62|chr3|+
# NM_052909|PLEKHG4B|chr5|+
# NM_052905|FMNL2|chr2|+
# NM_052904|KLHL32|chr6|+
# NM_052907|TMEM132B|chr12|+
# NM_052906|ELFN2|chr22|-
# NM_052901|SLC25A25|chr9|+
# NM_052903|TUBGCP5|chr15|+
# NM_052902|STK11IP|chr2|+
# NM_170606|MLL3|chr7|-
# NM_003265|TLR3|chr4|+
# NM_170609|CRISP1|chr6|-
# NM_033468|ZNF257|chr19|+
# NR_029894|MIR148B|chr12|+
# NR_029895|MIR331|chr12|+
# NR_029896|MIR324|chr17|-
# NR_029890|MIR323A|chr14|+
# NR_029891|MIR326|chr11|-
# NM_001378|DYNC1I2|chr2|+
# NR_029893|MIR135B|chr1|-
# NM_001376|DYNC1H1|chr14|+
# NM_001374|DNASE1L2|chr16|+
# NM_001375|DNASE2|chr19|-
# NR_029898|MIR339|chr7|-
# NM_001373|DNAH14|chr1|+
# NM_001370|DNAH6|chr2|+
# NM_001017438|CT45A6|chrX|-
# NM_174963|ST3GAL3|chr1|+
# NM_001146173|SLAMF9|chr1|-
# NM_001146171|TATDN3|chr1|+
# NR_036447|PKD1P1|chr16|+
# NR_036446|LOC283693|chr15|-
# NR_036445|OR5AK4P|chr11|+
# NR_036444|LOC400550|chr16|-
# NR_036443|HERC2P9|chr15|+
# NR_036442|LMF1|chr16|-
# NM_001146179|IP6K2|chr3|-
# NM_001244960|FRMD3|chr9|-
# NM_000421|KRT10|chr17|-
# NM_000420|KEL|chr7|-
# NM_000423|KRT2|chr12|-
# NM_000422|KRT17|chr17|-
# NM_000425|L1CAM|chrX|-
# NM_000424|KRT5|chr12|-
# NM_000427|LOR|chr1|+
# NM_000429|MAT1A|chr10|-
# NM_000428|LTBP2|chr14|-
# NM_006742|PSKH1|chr16|+
# NM_006743|RBM3|chrX|+
# NM_006741|PPP1R1A|chr12|-
# NM_006747|SIPA1|chr11|+
# NM_006744|RBP4|chr10|-
# NM_006745|MSMO1|chr4|+
# NM_153633|HOXC4|chr12|+
# NM_003999|OSMR|chr5|+
# NM_006749|SLC20A2|chr8|-
# NM_153635|CPNE9|chr3|+
# NM_153634|CPNE8|chr12|-
# NM_001165937|STARD3|chr17|+
# NM_001165931|RRM2|chr2|+
# NM_001100396|C2orf73|chr2|+
# NM_001165933|RGS9|chr17|+
# NM_001127388|DUX4L6|chr10|+
# NM_001204344|TNFSF15|chr9|-
# NM_001167575|C9orf82|chr9|-
# NM_001127380|SAA2|chr11|-
# NM_001167579|SLC34A1|chr5|+
# NM_001127383|CYBRD1|chr2|+
# NM_001127384|CTNNA3|chr10|-
# NM_001127387|DUX4L7|chr10|+
# NM_007297|BRCA1|chr17|-
# NM_080591|PTGS1|chr9|+
# NM_007293|C4A|chr6|+
# NM_007292|ACOX1|chr17|-
# NR_029708|MIR188|chrX|+
# NR_029709|MIR190A|chr15|+
# NR_029704|MIR154|chr14|+
# NR_029705|MIR184|chr15|+
# NR_029706|MIR185|chr22|+
# NR_029707|MIR186|chr1|-
# NR_029700|MIR138-1|chr3|+
# NR_029701|MIR146A|chr5|+
# NR_029702|MIR149|chr2|+
# NR_029703|MIR150|chr19|-
# NR_030233|MIR506|chrX|-
# NR_030230|MIR505|chrX|-
# NR_030236|MIR509-1|chrX|-
# NR_030237|MIR510|chrX|-
# NR_030234|MIR507|chrX|-
# NR_030235|MIR508|chrX|-
# NR_030238|MIR514A1|chrX|-
# NR_030239|MIR514A2|chrX|-
# NM_172231|SUGP1|chr19|-
# NM_006520|DYNLT3|chrX|-
# NM_006521|TFE3|chrX|-
# NM_001166621|TRAPPC1|chr17|-
# NM_001257072|C4orf26|chr4|+
# NM_001017961|FAM78B|chr1|-
# NM_001206641|C1orf31|chr1|+
# NM_001140|ALOX15|chr17|-
# NM_001017964|YDJC|chr22|-
# NM_004311|ARL3|chr10|-
# NR_033832|LOC340113|chr5|+
# NM_001252598|CLPS|chr6|-
# NM_001144|AMFR|chr16|-
# NM_004314|ART1|chr11|+
# NM_001144941|VMO1|chr17|-
# NR_027850|MTX2|chr2|+
# NM_014420|DKK4|chr8|-
# NM_014421|DKK2|chr4|-
# NM_014423|AFF4|chr5|-
# NM_014424|HSPB7|chr1|-
# NM_014426|SNX5|chr20|-
# NM_014427|CPNE7|chr16|+
# NM_014428|TJP3|chr19|+
# NM_014429|MORC1|chr3|-
# NR_033958|LOC283440|chr12|-
# NR_033959|LOC100506060|chr16|-
# NR_033957|LOC643650|chr10|-
# NM_182689|EFNA4|chr1|+
# NM_022470|ZMAT3|chr3|-
# NM_022476|AKTIP|chr16|-
# NM_022475|HHIP|chr4|+
# NM_182681|AMELX|chrX|+
# NM_022479|WBSCR17|chr7|+
# NM_182684|UPK3B|chr7|+
# NM_182685|EFNA1|chr1|+
# NR_027279|USP17L6P|chr4|+
# NR_027272|LINC00479|chr21|-
# NR_027273|ZNF295-AS1|chr21|+
# NR_027270|ANKRD20A11P|chr21|-
# NR_027271|CIRBP-AS1|chr19|-
# NR_027276|LOC100128239|chr11|+
# NR_027277|LOC344967|chr4|-
# NR_027275|LOC100128788|chr16|-
# NM_001178099|ZNF182|chrX|-
# NM_001178094|BCAT1|chr12|-
# NM_001178096|F3|chr1|-
# NM_001178097|C12orf74|chr12|+
# NM_001101391|LINGO3|chr19|-
# NM_172037|RDH10|chr8|+
# NR_046116|LOC550113|chr4|+
# NR_046114|FLJ46284|chr8|-
# NR_046113|FLJ16171|chr5|-
# NR_046111|LOC440894|chr2|+
# NM_001135171|C1QTNF7|chr4|+
# NM_001242507|GDA|chr9|+
# NM_001199934|SESN1|chr6|-
# NM_001242505|GDA|chr9|+
# NM_001135178|ZNF397|chr18|+
# NM_001199938|EBLN1|chr10|-
# NM_001024628|NRP1|chr10|-
# NM_001130524|AP1M1|chr19|+
# NM_024869|FAM110D|chr1|+
# NM_024867|SPEF2|chr5|+
# NM_024866|ADM2|chr22|+
# NM_024865|NANOG|chr12|+
# NM_024864|MRM1|chr17|+
# NM_024863|TCEAL4|chrX|+
# NM_024861|C2orf54|chr2|-
# NR_024199|CBLL1|chr7|+
# NR_024192|HILS1|chr17|-
# NR_024193|HILS1|chr17|-
# NR_024191|ATL2|chr2|-
# NM_175569|XG|chrX|+
# NR_024195|TOM1|chr22|+
# NM_001014830|C14orf183|chr14|-
# NR_040013|LOC644554|chr19|+
# NR_040012|SPAG5-AS1|chr17|+
# NR_040015|LOC100631378|chr19|-
# NR_040017|LOC100507218|chr17|+
# NR_040016|TMEM50B|chr21|-
# NM_001102608|COL6A6|chr3|+
# NR_040018|LOC100507410|chr17|-
# NM_001204818|ZNF587B|chr19|+
# NR_026846|LOC285074|chr2|-
# NR_026847|LOC286359|chr9|-
# NR_026844|ANKRD36BP1|chr1|-
# NR_026845|C21orf119|chr21|+
# NM_001037533|GON4L|chr1|-
# NM_032138|KBTBD7|chr13|-
# NM_032139|ANKRD27|chr19|-
# NM_032136|TKTL2|chr4|-
# NM_032137|C3orf20|chr3|+
# NM_032134|QRICH2|chr17|-
# NM_032135|FSCB|chr14|-
# NM_032133|MYCBPAP|chr17|+
# NM_032130|FAM186B|chr12|-
# NM_032131|ARMC2|chr6|+
# NM_001039567|RPS4Y2|chrY|+
# NM_001039569|AP1S3|chr2|-
# NM_001145852|PROM1|chr4|-
# NM_001145853|WFS1|chr4|+
# NR_027063|LINC00116|chr2|-
# NM_015053|PPFIA4|chr1|+
# NR_027061|FAM182B|chr20|-
# NM_079421|CDKN2D|chr19|-
# NM_079422|MYL1|chr2|-
# NR_027067|LINC00114|chr21|-
# NR_027066|LINC00114|chr21|-
# NR_027064|PLAC2|chr19|-
# NM_033261|IDI2|chr10|-
# NM_033260|FOXQ1|chr6|+
# NM_033267|IRX2|chr5|-
# NM_033266|ERN2|chr16|-
# NM_004520|KIF2A|chr5|+
# NR_039682|MIR4472-1|chr8|+
# NR_003040|RPL23AP64|chr11|-
# NM_033197|BPIFB1|chr20|+
# NR_039978|1/2-SBSRNA4|chr4|-
# NR_039979|LOC100505659|chr8|+
# NR_039977|LOC100506229|chr4|-
# NR_039974|LOC100507240|chr13|+
# NM_033191|KRTAP9-4|chr17|+
# NM_001190764|TMEM238|chr19|-
# NM_001190765|KLRF2|chr12|+
# NM_001190766|FLJ23152|chr6|+
# NM_001134651|EIF4E3|chr3|-
# NM_001134657|PRR23C|chr3|-
# NM_001014797|KCNMA1|chr10|-
# NM_153439|ODF2|chr9|+
# NM_153433|ODF2|chr9|+
# NM_153432|ODF2|chr9|+
# NM_001195279|LOC100129480|chr3|-
# NM_001195278|LOC100507421|chr7|+
# NM_001195272|LOC100129520|chrX|+
# NM_133510|RAD51B|chr14|+
# NM_001161630|KDM4E|chr11|+
# NR_046258|LOC100216479|chr2|-
# NR_046251|FGD5-AS1|chr3|-
# NM_001256030|CD48|chr1|-
# NR_004858|POFUT2|chr21|-
# NR_004855|HULC|chr6|+
# NM_016094|COMMD2|chr3|-
# NM_172377|CTAG2|chrX|-
# NM_172376|KCNH5|chr14|-
# NM_172375|KCNH5|chr14|-
# NM_172370|DAOA|chr13|+
# NM_001253357|TIE1|chr1|+
# NM_001012302|ANO9|chr11|-
# NM_001012301|ARSI|chr5|-
# NM_001193302|SEMA4A|chr1|+
# NM_001193307|SAMD9|chr7|-
# NM_001193306|FPR1|chr19|-
# NM_001165928|DAG1|chr3|+
# NM_001193304|TMEM127|chr2|-
# NM_001040425|U2AF1L4|chr19|-
# NM_001040424|PRDM15|chr21|-
# NM_001040429|PCDH17|chr13|+
# NM_001003702|ARHGEF35|chr7|-
# NM_001166305|TMEM44|chr3|-
# NM_001166301|DHX40|chr17|+
# NM_001014440|ODF3B|chr22|-
# NM_014622|VWA5A|chr11|+
# NM_014623|MEA1|chr6|-
# NM_014621|HOXD4|chr2|+
# NM_014626|TAAR2|chr6|-
# NM_014624|S100A6|chr1|-
# NM_014625|NPHS2|chr1|-
# NM_014628|MAD2L1BP|chr6|+
# NM_014629|ARHGEF10|chr8|+
# NM_003719|PDE8B|chr5|+
# NM_003712|PPAP2C|chr19|-
# NM_003713|PPAP2B|chr1|-
# NM_003710|SPINT1|chr15|+
# NM_003716|CADPS|chr3|-
# NM_003717|NPFF|chr12|-
# NM_003714|STC2|chr5|-
# NM_003715|USO1|chr4|+
# NM_018502|TMCO6|chr5|+
# NM_001197108|SCHIP1|chr3|+
# NM_018509|LRRC59|chr17|-
# NM_014999|RAB21|chr12|+
# NM_014990|RALGAPA1|chr14|-
# NM_014991|WDFY3|chr4|-
# NM_014992|DAAM1|chr14|+
# NM_014997|KLHDC10|chr7|+
# NM_032679|ZNF577|chr19|-
# NM_005711|EDIL3|chr5|-
# NM_000224|KRT18|chr12|+
# NM_005714|KCNK7|chr11|-
# NM_005715|UST|chr6|+
# NM_005717|ARPC5|chr1|-
# NM_005718|ARPC4|chr3|+
# NM_005719|ARPC3|chr12|-
# NM_032673|PCGF1|chr2|-
# NM_176881|TAS2R39|chr7|+
# NM_176880|NR2C2AP|chr19|-
# NM_176883|TAS2R41|chr7|+
# NM_176882|TAS2R40|chr7|+
# NM_176885|TAS2R31|chr12|-
# NM_176884|TAS2R43|chr12|-
# NM_176887|TAS2R46|chr12|-
# NM_176889|TAS2R20|chr12|-
# NM_176888|TAS2R19|chr12|-
# NR_038210|SAMD12-AS1|chr8|+
# NR_038213|IQCF4|chr3|+
# NR_038215|IQCF4|chr3|+
# NR_038216|LOC154092|chr6|+
# NM_032786|ZC3H10|chr12|+
# NM_001037225|C11orf85|chr11|-
# NR_037926|SENP3-EIF4A1|chr17|+
# NM_001040168|LFNG|chr7|+
# NR_029911|MIR196B|chr7|-
# NM_004392|DACH1|chr13|-
# NM_004391|CYP8B1|chr3|-
# NM_004390|CTSH|chr15|-
# NM_004396|DDX5|chr17|-
# NM_004394|DAP|chr5|-
# NM_004398|DDX10|chr11|+
# NM_001164165|GPR75-ASB3|chr2|-
# NM_001164164|PPP6R3|chr11|+
# NM_000672|ADH6|chr4|-
# NM_000675|ADORA2A|chr22|+
# NM_000676|ADORA2B|chr17|+
# NM_000677|ADORA3|chr1|-
# NM_000678|ADRA1D|chr20|-
# NM_000679|ADRA1B|chr5|+
# NM_001002275|FCGR2B|chr1|+
# NR_002788|CYP4Z2P|chr1|-
# NM_001013694|SRRD|chr22|+
# NM_004979|KCND1|chrX|-
# NM_001017408|GOPC|chr6|-
# NM_004977|KCNC3|chr19|-
# NM_004976|KCNC1|chr11|+
# NM_001017405|MAEA|chr4|+
# NM_004974|KCNA2|chr1|-
# NM_001017403|LGR6|chr1|+
# NM_001017402|LAMB3|chr1|-
# NR_002781|TSPY26P|chr20|-
# NM_001243168|PTCRA|chr6|+
# NM_005376|MYCL1|chr1|-
# NM_001243160|TAF1C|chr16|-
# NM_001202543|CUX1|chr7|+
# NM_006536|CLCA2|chr1|+
# NM_006531|IFT88|chr13|+
# NM_006530|YEATS4|chr12|+
# NM_006532|ELL|chr19|-
# NM_001202549|SYNJ2BP-COX16|chr14|-
# NM_006539|CACNG3|chr16|+
# NM_001206652|SH3GLB1|chr1|+
# NM_001127227|CD59|chr11|-
# NM_178537|B4GALNT4|chr11|+
# NR_015342|PCA3|chr9|+
# NR_015341|LRRC37BP1|chr17|+
# NR_015340|SERPINA13|chr14|+
# NR_038957|LOC100506714|chr22|-
# NM_152289|ZNF561|chr19|-
# NM_152288|ORAI3|chr16|+
# NM_152285|ARRDC1|chr9|+
# NM_152284|CHMP4C|chr8|+
# NM_152280|SYT11|chr1|+
# NM_152283|ZFP62|chr5|-
# NM_152282|ACPL2|chr3|+
# NR_000027|SNORD83A|chr22|-
# NR_000021|SNORD32A|chr19|+
# NM_001255976|PMEPA1|chr20|-
# NM_001100631|PRAMEF22|chr1|+
# NM_201262|DNAJC12|chr10|-
# NM_201263|WARS2|chr1|-
# NM_201266|NRP2|chr2|+
# NM_201264|NRP2|chr2|+
# NR_023362|LOC100169752|chr10|+
# NM_182524|ZNF595|chr4|+
# NM_182527|CABP7|chr22|+
# NM_182526|TMEM229B|chr14|-
# NM_182521|ZSWIM2|chr2|-
# NM_182520|C22orf15|chr22|+
# NM_182523|CMC1|chr3|+
# NM_182529|THAP5|chr7|-
# NM_182528|C1QL2|chr2|-
# NM_173595|ANKRD52|chr12|-
# NR_046099|LOC284757|chr20|+
# NM_173591|OTOGL|chr12|+
# NM_173593|B4GALNT3|chr12|+
# NR_046093|DACT1|chr14|+
# NR_046091|LOC728218|chr10|-
# NR_046090|LOC283214|chr11|-
# NR_046097|LOC284581|chr1|+
# NR_046096|LOC283692|chr15|+
# NR_046094|LOC283587|chr14|+
# NR_023313|CIRBP|chr19|+
# NM_001199011|DCTN5|chr16|+
# NM_001199012|C1orf201|chr1|-
# NM_001199018|LRRC49|chr15|+
# NM_001105570|NUDT19|chr19|+
# NM_172173|CAMK2G|chr10|-
# NM_172175|IL15|chr4|+
# NM_020390|EIF5A2|chr3|-
# NM_020393|PGLYRP4|chr1|-
# NM_020395|INTS12|chr4|-
# NM_020394|ZNF695|chr1|-
# NM_020397|CAMK1D|chr10|+
# NM_020396|BCL2L10|chr15|-
# NM_020398|SPINLW1|chr20|-
# NM_144598|LRRC28|chr15|+
# NM_144593|RHEBL1|chr12|-
# NM_144590|ANKRD22|chr10|-
# NM_144591|C10orf32|chr10|+
# NM_144597|C15orf40|chr15|-
# NM_144594|GTSF1|chr12|-
# NM_001198952|RNF103|chr2|-
# NM_002023|FMOD|chr1|-
# NM_002022|FMO4|chr1|+
# NM_002021|FMO1|chr1|+
# NM_002020|FLT4|chr5|-
# NM_002026|FN1|chr2|-
# NM_205545|LYPD2|chr8|-
# NM_002029|FPR1|chr19|-
# NM_002028|FNTB|chr14|+
# NM_001242713|LOC100289561|chr7|+
# NM_001039152|RGS21|chr1|+
# NM_001076680|C17orf108|chr17|-
# NM_001025161|CYP2D6|chr22|-
# NM_001076682|NCAM1|chr11|+
# NM_001029859|KCTD21|chr11|-
# NM_001029858|SLC35F1|chr6|+
# NM_001114636|FANCL|chr2|-
# NM_052945|TNFRSF13C|chr22|-
# NM_001114632|JMJD7|chr15|+
# NM_207379|TMEM179|chr14|-
# NM_207373|C10orf99|chr10|+
# NM_207370|GPR153|chr1|-
# NM_207371|C10orf140|chr10|-
# NM_207377|TOMM20L|chr14|+
# NM_207374|OR10W1|chr11|-
# NM_001025290|DPPA5|chr6|-
# NM_001025295|IFITM5|chr11|-
# NM_005552|KLC1|chr14|+
# NM_005553|KRTAP5-9|chr11|+
# NM_005551|KLK2|chr19|+
# NM_005556|KRT7|chr12|+
# NM_005557|KRT16|chr17|-
# NM_005554|KRT6A|chr12|-
# NM_005555|KRT6B|chr12|-
# NM_005558|LAD1|chr1|-
# NM_005559|LAMA1|chr18|-
# NM_001145463|YIF1B|chr19|-
# NM_001145465|NANOGNB|chr12|+
# NM_001145464|EXOG|chr3|+
# NM_001145467|NCR3|chr6|-
# NM_001145466|NCR3|chr6|-
# NM_005088|AKAP17A|chrY|+
# NM_005089|ZRSR2|chrX|+
# NR_036236|MIR4276|chr4|+
# NR_036237|MIR4275|chr4|+
# NR_036230|MIR4263|chr2|+
# NR_036232|MIR4270|chr3|-
# NR_036233|MIR4271|chr3|+
# NM_005080|XBP1|chr22|-
# NM_005082|TRIM25|chr17|-
# NR_036238|MIR4274|chr4|+
# NM_005087|FXR1|chr3|+
# NM_032301|FBXW9|chr19|-
# NM_032305|POLR3GL|chr1|-
# NM_032304|HAGHL|chr16|+
# NM_032307|C9orf64|chr9|-
# NM_032306|ALKBH7|chr19|+
# NM_032309|CHCHD5|chr2|+
# NM_001159279|ZNF716|chr7|+
# NM_033655|CNTNAP3|chr9|-
# NM_033656|BRWD1|chr21|-
# NR_045181|SPG20OS|chr13|+
# NR_003308|SNORD115-16|chr15|+
# NR_039602|MIR378D2|chr8|-
# NR_003300|SNORD115-8|chr15|+
# NR_003301|SNORD115-9|chr15|+
# NR_003302|SNORD115-10|chr15|+
# NR_003305|SNORD115-13|chr15|+
# NR_003306|SNORD115-14|chr15|+
# NM_138371|FAM113B|chr12|+
# NM_138370|PKDCC|chr2|+
# NM_138373|MYADM|chr19|+
# NM_138374|ZNF845|chr19|+
# NM_138376|TTC5|chr14|-
# NM_138379|TIMD4|chr5|-
# NM_138378|FDXACB1|chr11|-
# NM_001703|BAI2|chr1|-
# NM_001702|BAI1|chr8|+
# NM_001701|BAAT|chr9|-
# NM_001700|AZU1|chr19|+
# NM_001704|BAI3|chr6|+
# NM_001018073|PCK2|chr14|+
# NM_001018072|BTBD11|chr12|+
# NM_001018071|FRMPD2|chr10|-
# NM_001253835|IGFBP7|chr4|-
# NM_133497|KCNV2|chr9|+
# NM_001253837|PKD2L1|chr10|-
# NM_133491|SAT2|chr17|-
# NM_133493|CD109|chr6|+
# NM_000075|CDK4|chr12|-
# NM_000078|CETP|chr16|+
# NM_000079|CHRNA1|chr2|-
# NM_197941|ADAMTS6|chr5|-
# NM_133498|SPACA4|chr19|+
# NM_016388|TRAT1|chr3|+
# NM_001042762|FIGNL1|chr7|-
# NM_019839|LTB4R2|chr14|+
# NM_001025930|TTLL3|chr3|+
# NM_001044391|MUC1|chr1|-
# NR_034148|LOC283143|chr11|-
# NR_034149|LOC200261|chr20|-
# NR_034144|FLJ34690|chr17|+
# NR_034147|LOC149773|chr20|+
# NR_034140|C12orf33|chr12|-
# NR_034141|LOC645591|chr7|-
# NR_034142|LOC645591|chr7|-
# NR_034143|LOC729177|chr6|-
# NR_038871|C21orf91-OT1|chr21|-
# NR_038872|LINC00317|chr21|-
# NR_038873|LOC286059|chr8|+
# NR_038874|LOC286177|chr8|+
# NR_038875|LOC286184|chr8|+
# NR_038876|LOC100129027|chr21|-
# NR_038877|LOC286189|chr8|-
# NR_038878|LINC00550|chr13|-
# NR_038879|GCFC1-AS1|chr21|+
# NM_032888|COL27A1|chr9|+
# NM_032882|PNMA6A|chrX|-
# NM_032880|IGSF21|chr1|+
# NM_032881|LSM10|chr1|-
# NM_032885|ATG4D|chr19|+
# NR_030646|MIR1225|chr16|-
# NM_003039|SLC2A5|chr1|-
# NM_003038|SLC1A4|chr2|+
# NM_006049|SNAPC5|chr15|-
# NM_006048|UBE4B|chr1|+
# NR_030641|MIR943|chr4|-
# NR_030640|MIR942|chr1|+
# NM_003033|ST3GAL1|chr8|-
# NM_006044|HDAC6|chrX|+
# NM_003031|SIAH1|chr16|-
# NM_003037|SLAMF1|chr1|-
# NM_003036|SKI|chr1|+
# NM_006043|HS3ST2|chr16|+
# NM_001160333|NFASC|chr1|+
# NM_001128929|ROBO2|chr3|+
# NM_001128928|INPP1|chr2|+
# NM_001128923|SH3D19|chr4|-
# NM_001128925|CYP2C18|chr10|+
# NM_001128926|FAM71F2|chr7|+
# NM_001123041|CCR2|chr3|+
# NM_001123040|C3orf71|chr3|-
# NM_001079823|LAMA2|chr6|+
# NM_001037806|NCKAP5L|chr12|-
# NM_001098506|CEACAM21|chr19|+
# NM_013388|PREB|chr2|-
# NM_001098502|CHCHD4|chr3|-
# NM_001098500|KIAA1217|chr10|+
# NM_013385|CYTH4|chr22|+
# NM_013386|SLC25A24|chr1|-
# NM_013387|UQCR10|chr22|+
# NM_013380|ZFP112|chr19|-
# NM_013381|TRHDE|chr12|+
# NM_001098509|SGSM2|chr17|+
# NR_027423|FAM66B|chr8|-
# NR_027422|FAM27B|chr9|-
# NR_027421|FAM27C|chr9|+
# NR_027426|LOC648691|chr22|+
# NR_027425|FAM66D|chr8|+
# NR_027424|FAM66E|chr8|+
# NM_002348|LY9|chr1|+
# NM_002349|LY75|chr2|-
# NM_001166279|PAN2|chr12|-
# NM_001166278|DLG3|chrX|+
# NM_001166277|ARHGAP25|chr2|+
# NM_002343|LTF|chr3|-
# NM_002340|LSS|chr21|-
# NM_002346|LY6E|chr8|+
# NM_002345|LUM|chr12|-
# NM_001256550|MPP5|chr14|+
# NM_018717|MAML3|chr4|-
# NM_018715|RCC2|chr1|-
# NM_018712|ELMOD1|chr11|+
# NM_018713|SLC30A10|chr1|-
# NM_018710|TMEM55A|chr8|-
# NM_018711|SVOP|chr12|-
# NM_001077686|AGAP8|chr10|-
# NM_001077685|AGAP7|chr10|-
# NM_001177428|TRPV4|chr12|-
# NM_001039753|EML6|chr2|+
# NM_014815|MED24|chr17|-
# NM_014814|PSMD6|chr3|-
# NM_014817|TRIL|chr7|-
# NM_001005479|OR5H6|chr3|+
# NM_014810|CEP350|chr1|+
# NM_014813|LRIG2|chr1|+
# NM_014812|CEP170|chr1|-
# NM_001005474|NFKBIZ|chr3|+
# NM_001005471|OR2T6|chr1|+
# NM_014818|TRIM66|chr11|-
# NM_001030059|PPAPDC1A|chr10|+
# NM_001172285|GLRA4|chrX|-
# NM_001099294|KIAA1644|chr22|-
# NM_012419|RGS17|chr6|-
# NM_012418|FSCN2|chr17|+
# NM_001099293|KIF4B|chr5|+
# NM_012413|QPCT|chr2|+
# NM_012412|H2AFV|chr7|-
# NM_012411|PTPN22|chr1|-
# NM_012416|RANBP6|chr9|-
# NM_012415|RAD54B|chr8|-
# NM_012414|RAB3GAP2|chr1|-
# NM_001171747|C3orf52|chr3|+
# NR_036179|MIR4297|chr10|-
# NR_036178|MIR4296|chr10|-
# NR_036177|MIR4295|chr10|+
# NR_036173|MIR514B|chrX|-
# NR_036171|MIR3200|chr22|+
# NM_001172131|HCK|chr20|+
# NR_027294|FAM201A|chr9|+
# NM_001068|TOP2B|chr3|-
# NM_001069|TUBB2A|chr6|-
# NM_001062|TCN1|chr11|-
# NM_001063|TF|chr3|+
# NM_001060|TBXA2R|chr19|-
# NM_001066|TNFRSF1B|chr1|+
# NM_001067|TOP2A|chr17|-
# NM_001064|TKT|chr3|-
# NM_001065|TNFRSF1A|chr12|-
# NM_001173425|DFNB31|chr9|-
# NR_027291|NAP1L6|chrX|-
# NM_001164825|C1orf212|chr1|-
# NR_027292|SSR4P1|chr21|-
# NM_006874|ELF2|chr4|-
# NM_006875|PIM2|chrX|-
# NM_006876|B3GNT1|chr11|-
# NM_006877|GMPR|chr6|+
# NM_006870|DSTN|chr20|+
# NM_001164829|C1orf210|chr1|-
# NM_006872|GTF2A1L|chr2|+
# NM_006873|STON1|chr2|+
# NM_001037582|SCD5|chr4|-
# NM_001142548|RAD54L|chr1|+
# NM_006737|KIR3DL2|chr19|+
# NM_001142540|SLC35B3|chr6|-
# NM_001142547|RPUSD3|chr3|-
# NM_003924|PHOX2B|chr4|-
# NM_004582|RABGGTB|chr1|+
# NM_004583|RAB5C|chr17|-
# NM_020151|STARD7|chr2|-
# NM_004581|RABGGTA|chr14|-
# NM_004586|RPS6KA3|chrX|-
# NM_020156|C1GALT1|chr7|+
# NM_004584|RAD9A|chr11|+
# NM_004585|RARRES3|chr11|+
# NM_001146040|GLRA1|chr5|-
# NM_004589|SCO1|chr17|-
# NM_018638|ETNK1|chr12|+
# NM_006052|DSCR3|chr21|-
# NM_001001888|VCX3B|chrX|+
# NM_004124|GMFB|chr14|-
# NM_001242729|ARHGEF38|chr4|+
# NM_194287|C14orf166B|chr14|+
# NM_001330|CTF1|chr16|+
# NM_194285|SPTY2D1|chr11|-
# NM_194284|CLDN23|chr8|+
# NM_001336|CTSZ|chr20|-
# NM_001334|CTSO|chr4|-
# NM_001335|CTSW|chr11|+
# NM_007055|POLR3A|chr10|-
# NM_007054|KIF3A|chr5|-
# NM_007057|ZWINT|chr10|-
# NM_007056|CLASRP|chr19|+
# NM_007051|FAF1|chr1|-
# NM_007050|PTPRT|chr20|-
# NM_007053|CD160|chr1|-
# NM_007052|NOX1|chrX|-
# NM_007059|KPTN|chr19|-
# NM_007058|CAPN11|chr6|+
# NM_001243288|PVRL3|chr3|+
# NM_001243286|PVRL3|chr3|+
# NM_001243283|ALCAM|chr3|+
# NM_001243281|ALCAM|chr3|+
# NM_001145668|CTXN2|chr15|+
# NR_024873|SLC25A51|chr9|-
# NM_001145665|ZNF181|chr19|+
# NM_001145664|RFX8|chr2|-
# NM_001203260|NDUFC2-KCTD14|chr11|-
# NM_001203265|IL17RC|chr3|+
# NM_152326|ANKRD9|chr14|-
# NM_152327|AK7|chr14|+
# NM_152324|TEX29|chr13|+
# NM_152325|TEX26|chr13|+
# NM_152323|SPIC|chr12|+
# NM_152321|ERP27|chr12|-
# NM_152328|ADSSL1|chr14|+
# NM_001185057|NOL3|chr16|+
# NM_022142|ELSPBP1|chr19|+
# NM_022143|LRRC4|chr7|-
# NM_022140|EPB41L4A|chr5|-
# NM_022141|PARVG|chr22|+
# NM_022146|NPFFR1|chr10|-
# NM_022147|RTP4|chr3|+
# NM_022144|TNMD|chrX|+
# NM_022145|CENPK|chr5|-
# NM_022148|CRLF2|chrX|-
# NM_022149|MAGEF1|chr3|-
# NM_001004465|OR10H4|chr19|+
# NM_001004464|OR10G8|chr11|+
# NM_001004467|OR10J3|chr1|-
# NM_001004466|OR10H5|chr19|+
# NM_001004461|OR10A6|chr11|-
# NM_001004460|OR10A2|chr11|+
# NM_001004463|OR10G7|chr11|-
# NM_001004462|OR10G4|chr11|+
# NM_001004469|OR10J5|chr1|-
# NM_001242907|LOC100506888|chr18|-
# NM_001242903|AKAP1|chr17|+
# NM_001242900|PPP6R2|chr22|+
# NM_001242901|LOC100131094|chr19|+
# NM_001207023|IQCF3|chr3|+
# NM_001207020|SHISA8|chr22|-
# NM_001207026|POU2F2|chr19|-
# NM_001207024|M6PR|chr12|-
# NM_001207025|POU2F2|chr19|-
# NM_199133|FAM173B|chr5|-
# NM_199131|VAX1|chr10|-
# NM_199136|FAM221A|chr7|+
# NM_134266|SLC26A7|chr8|+
# NM_199135|FOXD4L3|chr9|+
# NM_199138|FAM123A|chr13|-
# NM_134268|CYGB|chr17|-
# NR_026667|RPS10P7|chr1|+
# NM_017678|FAM55D|chr11|-
# NM_017679|BCAS3|chr17|+
# NM_021729|VPS11|chr11|+
# NM_017670|OTUB1|chr11|+
# NM_017671|FERMT1|chr20|-
# NM_017672|TRPM7|chr15|-
# NM_017673|SWT1|chr1|+
# NM_021727|FADS3|chr11|-
# NM_017676|GIN1|chr5|-
# NM_017677|MTMR8|chrX|-
# NM_001135993|TTC39C|chr18|+
# NM_001135995|ATXN3L|chrX|-
# NR_024468|LOC730811|chr2|+
# NR_024469|LOC100130987|chr11|+
# NM_003239|TGFB3|chr14|-
# NR_024462|LOC100190938|chr17|-
# NR_024463|LOC100189589|chr2|+
# NR_024461|LOC100190938|chr17|-
# NR_024467|LOC100188947|chr10|-
# NR_024464|LINC00426|chr13|-
# NM_001042402|NAAA|chr4|-
# NM_001042406|HMGCLL1|chr6|-
# NM_006197|PCM1|chr8|+
# NM_001135662|RAB7L1|chr1|-
# NM_006196|PCBP1|chr2|+
# NM_001135669|XPR1|chr1|+
# NM_003583|DYRK2|chr12|+
# NM_003582|DYRK3|chr1|+
# NM_003581|NCK2|chr2|+
# NM_003580|NSMAF|chr8|-
# NM_003587|DHX16|chr6|-
# NM_003586|DOC2A|chr16|-
# NM_003585|DOC2B|chr17|-
# NM_003584|DUSP11|chr2|-
# NM_001099852|PRAMEF20|chr1|+
# NM_139178|ALKBH3|chr11|+
# NM_139179|DAGLB|chr7|-
# NM_020458|TTC7A|chr2|+
# NM_020459|PAIP2B|chr2|-
# NM_020452|ATP8B2|chr1|+
# NM_020453|ATP10D|chr4|+
# NM_001099851|PRAMEF17|chr1|+
# NM_020456|SPRYD7|chr13|-
# NM_020457|THAP11|chr16|+
# NM_020455|GPR126|chr6|+
# NM_021048|MAGEA10|chrX|-
# NR_003569|ABCC6P1|chr16|+
# NR_003563|PI4KAP1|chr22|-
# NM_002188|IL13|chr5|+
# NM_002185|IL7R|chr5|+
# NM_002186|IL9R|chrY|+
# NM_002187|IL12B|chr5|-
# NM_002180|IGHMBP2|chr11|+
# NM_002181|IHH|chr2|-
# NM_002182|IL1RAP|chr3|+
# NM_002183|IL3RA|chrY|+
# NR_001588|SBDSP1|chr7|+
# NR_001589|HBBP1|chr11|-
# NR_001580|SDC4P|chr22|-
# NR_001587|AURKAPS1|chr1|-
# NM_004789|LHX2|chr9|+
# NR_003698|LOC729234|chr2|+
# NR_003699|ZNF525|chr19|+
# NR_003697|SNHG15|chr7|-
# NR_003694|SNORD11B|chr2|+
# NR_003695|SNORD12B|chr20|+
# NR_003692|SNORD124|chr17|+
# NR_003693|SNORD126|chr14|-
# NR_003690|SNORD121B|chr9|+
# NR_003691|SNORD127|chr14|+
# NM_032408|BAZ1B|chr7|-
# NM_032409|PINK1|chr1|+
# NM_032406|PCDHGC4|chr5|+
# NM_032407|PCDHGC5|chr5|+
# NM_032404|TMPRSS3|chr21|-
# NM_032405|TMPRSS3|chr21|-
# NM_032402|PCDHGC3|chr5|+
# NM_018158|SLC4A1AP|chr2|+
# NM_018159|NUDT11|chrX|-
# NM_001145348|KDM8|chr16|+
# NM_001145349|IPP|chr1|-
# NM_018150|RNF220|chr1|+
# NM_001145346|RBMXL3|chrX|+
# NM_018153|ANTXR1|chr2|+
# NM_018154|ASF1B|chr19|-
# NM_018155|SLC25A36|chr3|+
# NM_018156|VPS13D|chr1|+
# NM_018157|RIC8B|chr12|+
# NM_003378|VGF|chr7|-
# NM_005560|LAMA5|chr20|-
# NM_001190255|ZNF630|chrX|-
# NM_005325|HIST1H1A|chr6|-
# NM_005324|H3F3B|chr17|-
# NM_080539|COLQ|chr3|-
# NR_002771|DLEU2L|chr1|+
# NM_005321|HIST1H1E|chr6|+
# NM_005320|HIST1H1D|chr6|-
# NM_005323|HIST1H1T|chr6|-
# NM_005322|HIST1H1B|chr6|-
# NR_002778|RPL29P2|chr17|+
# NR_002779|NUDT9P1|chr10|-
# NM_005328|HAS2|chr8|-
# NM_001112741|KCNC1|chr11|+
# NR_024543|SNHG7|chr9|-
# NM_012163|LRRC29|chr16|-
# NM_012162|FBXL6|chr8|-
# NM_012161|FBXL5|chr4|-
# NM_012160|FBXL4|chr6|-
# NM_012166|FBXO10|chr9|-
# NM_012164|FBXW2|chr9|-
# NM_001193637|DHRS4L2|chr14|+
# NM_012168|FBXO2|chr1|-
# NR_024546|TXNL1|chr18|-
# NM_170685|TAC4|chr17|-
# NM_206925|CA12|chr15|-
# NM_206926|SEPN1|chr1|+
# NM_170686|ZNF398|chr7|+
# NM_170681|GFM2|chr5|-
# NM_206921|CEP85L|chr6|-
# NM_206922|CRIP3|chr6|-
# NM_206923|YY2|chrX|+
# NM_004744|LRAT|chr4|+
# NM_004745|DLGAP2|chr8|+
# NM_001510|GRID2|chr4|+
# NM_001511|CXCL1|chr4|+
# NM_004740|TIAF1|chr17|-
# NM_001517|GTF2H4|chr6|+
# NM_004742|MAGI1|chr3|-
# NM_001515|GTF2H2|chr5|-
# NM_001008540|CXCR4|chr2|-
# NM_012265|RHBDD3|chr22|-
# NR_029843|MIR99B|chr19|+
# NM_016262|TUBE1|chr6|-
# NM_016263|FZR1|chr19|+
# NM_016265|ZNF12|chr7|-
# NM_016267|VGLL1|chrX|+
# NM_012263|TTLL1|chr22|-
# NM_001111101|CNRIP1|chr2|-
# NM_007215|POLG2|chr17|-
# NM_007214|SEC63|chr6|-
# NM_007213|PRAF2|chrX|-
# NM_007212|RNF2|chr1|+
# NM_007211|RASSF8|chr12|+
# NM_007210|GALNT6|chr12|-
# NM_007218|RNF139|chr8|+
# NM_003918|GYG2|chrX|+
# NM_003913|PRPF4B|chr6|+
# NM_003916|AP1S2|chrX|-
# NM_003917|AP1G2|chr14|-
# NM_014499|P2RY10|chrX|+
# NM_000178|GSS|chr20|-
# NM_024729|MYH14|chr19|+
# NR_029782|MIR181B2|chr9|+
# NM_024721|ZFHX4|chr8|+
# NM_001164664|MAST4|chr5|+
# NM_001164665|KIAA1549|chr7|-
# NM_024725|CCDC82|chr11|-
# NM_024726|IQCA1|chr2|-
# NM_024727|LRRC31|chr3|-
# NM_144664|FAM76B|chr11|-
# NM_144665|SESN3|chr11|-
# NM_001080779|MYO1C|chr17|-
# NM_001080772|KIR2DL4|chr19|+
# NM_001170937|FUS|chr16|+
# NM_001139500|FGF13|chrX|-
# NM_153018|ZFP3|chr17|+
# NM_153015|TMEM74|chr8|-
# NM_153013|NADKD1|chr5|-
# NM_014139|SCN11A|chr3|-
# NM_001037666|GATSL3|chr22|-
# NM_139239|NFKBID|chr19|-
# NM_139235|NOL6|chr9|-
# NM_001252043|TAOK2|chr16|+
# NM_001256741|CNOT10|chr3|+
# NM_001256743|GRIA3|chrX|+
# NM_152657|GGN|chr19|-
# NM_152654|DAND5|chr19|+
# NM_152655|ZNF585A|chr19|-
# NM_152653|UBE2E2|chr3|+
# NM_001639|APCS|chr1|+
# NM_020239|CDC42SE1|chr1|-
# NM_001635|AMPH|chr7|-
# NM_001146184|PEG3|chr19|-
# NM_020232|PSMG2|chr18|+
# NM_001004699|OR2Z1|chr19|+
# NM_001632|ALPP|chr2|+
# NM_001127889|SPG21|chr15|-
# NM_001146181|LOC649330|chr1|-
# NR_037181|LOC100507362|chr6|+
# NR_037183|SPANXA2-OT1|chrX|+
# NR_037182|LOC653513|chr1|-
# NR_037185|PRPF38B|chr1|+
# NR_037184|FLJ21408|chr16|+
# NM_001178016|SLC4A10|chr2|+
# NM_001178010|CDC45|chr22|+
# NM_183009|KIAA1429|chr8|-
# NM_001101311|TMEM176B|chr7|-
# NM_001134734|C1orf94|chr1|+
# NM_001134738|BCL6|chr3|-
# NM_001163942|ABCB5|chr7|+
# NM_001163940|PYGL|chr14|-
# NM_001163941|ABCB5|chr7|+
# NM_021129|PPA1|chr10|-
# NM_021128|POLR2L|chr11|-
# NM_021127|PMAIP1|chr18|+
# NM_021123|GAGE7|chrX|+
# NM_001005209|TMEM198|chr2|+
# NM_001005204|OR8U1|chr11|+
# NM_001005205|OR8J1|chr11|+
# NM_001005202|OR8K3|chr11|+
# NM_001005203|OR8S1|chr12|+
# NM_001005200|OR8H2|chr11|+
# NM_001005201|OR8H3|chr11|+
# NM_012208|HARS2|chr5|+
# NM_012202|GNG3|chr11|+
# NM_012203|GRHPR|chr9|+
# NM_012200|B3GAT3|chr11|-
# NM_012201|GLG1|chr16|-
# NM_012206|HAVCR1|chr5|-
# NM_012207|HNRNPH3|chr10|+
# NM_012204|GTF3C4|chr9|+
# NM_012205|HAAO|chr2|-
# NM_006939|SOS2|chr14|-
# NM_144702|LRRC71|chr1|+
# NM_144701|IL23R|chr1|+
# NM_181537|KRT27|chr17|-
# NM_144706|C2orf15|chr2|+
# NM_181535|KRT28|chr17|-
# NM_181534|KRT25|chr17|-
# NM_006931|SLC2A3|chr12|-
# NM_006930|SKP1|chr5|-
# NM_181539|KRT26|chr17|-
# NM_181538|GJC3|chr7|-
# NM_006934|SLC6A9|chr1|-
# NM_006937|SUMO2|chr17|-
# NM_006936|SUMO3|chr21|-
# NM_203453|PPAPDC2|chr9|+
# NM_203451|SERTM1|chr13|+
# NM_001102576|CSAG1|chrX|+
# NR_024117|MSTO2P|chr1|+
# NM_203454|APOBEC4|chr1|-
# NM_203459|CAMSAP2|chr1|+
# NM_203458|NOTCH2NL|chr1|+
# NM_020299|AKR1B10|chr7|+
# NM_004269|MED27|chr9|-
# NM_004268|MED17|chr11|+
# NM_004267|CHST2|chr3|+
# NM_004265|FADS2|chr11|+
# NM_004264|MED21|chr12|+
# NM_004263|SEMA4F|chr2|+
# NM_004262|TMPRSS11D|chr4|-
# NM_001206557|KIAA1432|chr9|+
# NM_004260|RECQL4|chr8|-
# NM_001100592|ATP6V0E2|chr7|+
# NM_198578|LRRK2|chr12|+
# NM_001100595|SKA2|chr17|-
# NM_198576|AGRN|chr1|+
# NM_198571|NAT16|chr7|-
# NM_198570|VWC2|chr7|+
# NM_198573|ENHO|chr9|-
# NM_198572|SPATC1|chr8|+
# NM_025112|ZXDC|chr3|-
# NM_025113|KIAA0226L|chr13|-
# NM_080389|DEFB104A|chr8|+
# NM_001204890|ISY1-RAB43|chr3|-
# NM_080739|C20orf141|chr20|+
# NM_080738|EDARADD|chr1|+
# NM_021915|ZNF69|chr19|+
# NM_021916|ZNF70|chr22|-
# NM_001243094|HSF2|chr6|+
# NM_145016|GLYATL2|chr11|-
# NM_145010|ENKUR|chr10|-
# NM_145013|C11orf45|chr11|-
# NM_152519|KANSL1L|chr2|-
# NM_152511|DUSP18|chr22|-
# NM_152510|HORMAD2|chr22|+
# NM_152513|MEI1|chr22|+
# NM_152512|ENTHD1|chr22|-
# NM_152515|CKAP2L|chr2|-
# NM_152517|TTC30B|chr2|-
# NM_152516|COMMD1|chr2|+
# NM_145018|C11orf82|chr11|+
# NM_016062|FAM96B|chr16|-
# NM_016063|HDDC2|chr6|-
# NM_022337|RAB38|chr11|-
# NM_022336|EDAR|chr2|-
# NM_016066|GLRX2|chr1|-
# NM_016065|MRPS16|chr10|-
# NM_016068|FIS1|chr7|-
# NM_022338|C11orf24|chr11|-
# NM_001191055|ERVV-2|chr19|+
# NM_001159726|TSPO2|chr6|+
# NM_001191056|PDE1C|chr7|-
# NM_001191058|PDE1C|chr7|-
# NM_001713|BHMT|chr5|+
# NM_001134479|LRRC8D|chr1|+
# NM_001253827|GALNT14|chr2|-
# NM_000959|PTGFR|chr1|+
# NM_000958|PTGER4|chr5|+
# NM_001199382|RNF145|chr5|-
# NM_000955|PTGER1|chr19|-
# NM_000954|PTGDS|chr9|+
# NM_000956|PTGER2|chr14|+
# NM_001199389|EPB41L2|chr6|-
# NM_000045|ARG1|chr6|+
# NM_000953|PTGDR|chr14|+
# NM_000043|FAS|chr10|+
# NM_133480|TADA3|chr3|-
# NM_001160147|DDHD1|chr14|-
# NR_030359|MIR630|chr15|+
# NR_047566|CARD14|chr17|+
# NR_047567|GOLGA6L7P|chr15|-
# NR_047568|LINC00578|chr3|+
# NR_047569|LOC100507384|chr11|+
# NM_001029996|PCDP1|chr2|+
# NM_001029991|METTL17|chr14|+
# NM_001029998|SLC10A7|chr4|-
# NM_173602|DIP2B|chr12|+
# NM_173605|KCNRG|chr13|+
# NM_173607|FAM177A1|chr14|+
# NR_034023|LOC339807|chr2|+
# NM_139034|MAPK7|chr17|+
# NM_138924|GAMT|chr19|-
# NM_001166424|PGC|chr6|-
# NM_001166425|GNAI2|chr3|+
# NM_001166422|HDAC8|chrX|-
# NM_001166420|HDAC8|chrX|-
# NM_138929|DIABLO|chr12|-
# NM_005823|MSLN|chr16|+
# NM_005826|HNRNPR|chr1|-
# NM_005827|SLC35B1|chr17|-
# NM_005828|DCAF7|chr17|+
# NM_003792|EDF1|chr9|-
# NM_003793|CTSF|chr11|-
# NM_001172415|BAG1|chr9|-
# NM_003796|URI1|chr19|+
# NM_003797|EED|chr11|+
# NM_003794|SNX4|chr3|-
# NM_003795|SNX3|chr6|-
# NM_003798|CTNNAL1|chr9|-
# NM_003799|RNMT|chr18|+
# NM_001197181|TUBB3|chr16|+
# NM_001172418|BTBD9|chr6|-
# NR_039741|MIR4516|chr16|+
# NR_039740|MIR4515|chr15|+
# NR_039743|MIR4518|chr16|+
# NR_039742|MIR4517|chr16|+
# NR_039749|MIR4523|chr17|+
# NR_039748|MIR4522|chr17|-
# NR_003719|NBPF22P|chr5|+
# NR_003713|LOC728613|chr5|-
# NR_038291|LOC100507127|chr10|+
# NR_038292|LOC100507173|chr6|+
# NR_003710|SNORA11C|chrX|+
# NR_038294|LOC100507173|chr6|+
# NR_038296|LOC100507194|chr6|-
# NR_003714|POM121L9P|chr22|+
# NM_015578|LSM14A|chr19|+
# NM_015577|RAI14|chr5|+
# NM_015576|ERC2|chr3|-
# NM_015570|AUTS2|chr7|+
# NM_002445|MSR1|chr8|-
# NM_002444|MSN|chrX|+
# NM_002447|MST1R|chr3|-
# NM_031949|TTLL2|chr6|+
# NM_002441|MSH5|chr6|+
# NM_002440|MSH4|chr1|+
# NM_002442|MSI1|chr12|-
# NM_031942|CDCA7|chr2|+
# NM_031940|TM2D2|chr8|-
# NM_031941|USHBP1|chr19|-
# NM_002449|MSX2|chr5|+
# NM_002448|MSX1|chr4|+
# NM_031944|MIXL1|chr1|+
# NM_031945|TSPAN10|chr17|+
# NM_001256238|PGAP2|chr11|+
# NM_052828|TRIM10|chr6|-
# NM_005791|MPHOSPH10|chr2|+
# NM_005792|MPHOSPH6|chr16|-
# NM_005793|NME6|chr3|-
# NM_005794|DHRS2|chr14|+
# NM_005795|CALCRL|chr2|-
# NM_005796|NUTF2|chr16|+
# NM_005797|MPZL2|chr11|-
# NM_170726|ALDH4A1|chr1|-
# NM_170724|PKHD1|chr6|-
# NM_170725|PGBD2|chr1|+
# NM_170722|NLRX1|chr11|+
# NM_170723|CDY1|chrY|+
# NM_170720|KCNJ14|chr19|+
# NM_170721|MSI2|chr17|+
# NM_033540|MFN1|chr3|+
# NR_033465|NT5C3L|chr17|-
# NM_033544|RCCD1|chr15|+
# NR_033460|PAGE3|chrX|-
# ...
# NM_003666|BLZF1|chr1|+
# NM_003667|LGR5|chr12|+
# NM_003664|AP3B1|chr5|-
# NM_018430|TSNAXIP1|chr16|+
# NM_003662|PIR|chrX|-
# NM_018436|ALLC|chr2|+
# NM_003660|PPFIA3|chr19|+
# NM_018434|RNF130|chr5|-
# NM_018439|IMPACT|chr18|+
# NM_018438|FBXO6|chr1|+
# NM_003668|MAPKAPK5|chr12|+
# NM_001197216|ASGR1|chr17|-
# NM_002398|MEIS1|chr2|+
# NM_002395|ME1|chr6|-
# NM_002391|MDK|chr11|+
# NM_002390|ADAM11|chr17|+
# NM_002392|MDM2|chr12|+
# NM_001190977|YAF2|chr12|-
# NM_001190971|PIWIL1|chr12|+
# NR_039631|MIR4432|chr2|-
# NM_005626|SRSF4|chr1|-
# NM_001014975|CFH|chr1|+
# NR_039635|MIR4436A|chr2|+
# NR_039634|MIR4435-1|chr2|+
# NM_005623|CCL8|chr17|+
# NM_006012|CLPP|chr19|+
# NR_038328|TEKT4P2|chr21|-
# NR_038329|TEKT4P2|chr21|-
# NM_003061|SLIT1|chr10|-
# NR_038324|LOC100505768|chr1|-
# NR_038325|LOC100505776|chr18|-
# NM_001077653|TBX20|chr7|-
# NM_001077654|TNFAIP8|chr5|+
# NR_038321|OR51B5|chr11|-
# NR_038322|MAP3K13|chr3|+
# NR_038323|LOC100507156|chr8|+
# NR_040001|LOC375295|chr2|-
# NM_133487|RAD51|chr15|+
# NR_040005|LOC401074|chr3|+
# NM_015660|GIMAP2|chr7|+
# NM_015662|IFT172|chr2|-
# NM_015665|AAAS|chr12|-
# NM_018299|UBE2W|chr8|-
# NM_015666|GTPBP5|chr20|+
# NM_015669|PCDHB5|chr5|+
# NM_018296|LRRC36|chr16|+
# NM_018295|TMEM140|chr7|+
# NM_018294|CWF19L1|chr10|-
# NM_018293|ZNF654|chr3|+
# NM_018292|QRSL1|chr6|+
# NM_018290|PGM2|chr4|+
# NM_002539|ODC1|chr2|-
# NM_002531|NTSR1|chr20|+
# NM_002530|NTRK3|chr15|-
# NM_002533|NVL|chr1|-
# NM_002532|NUP88|chr17|-
# NM_002535|OAS2|chr12|+
# NM_002534|OAS1|chr12|+
# NM_002537|OAZ2|chr15|-
# NM_002536|TBC1D25|chrX|+
# NR_037859|PIR-FIGF|chrX|-
# NM_001037535|SCML1|chrX|+
# NR_033772|CENPVL1|chrX|+
# NR_033770|ROCK1P1|chr18|+
# NR_037850|PROX1-AS1|chr1|-
# NR_037857|LOC254128|chr2|+
# NR_033777|TEX21P|chr14|-
# NR_033774|BASP1P1|chr13|-
# NM_004627|WRB|chr21|+
# NM_025263|PRR3|chr6|+
# NR_036186|MIR4300|chr11|-
# NR_036184|MIR4299|chr11|-
# NR_036185|MIR4298|chr11|-
# NR_036182|MIR4294|chr10|-
# NR_036180|MIR378C|chr10|-
# NM_033309|B3GNT9|chr16|-
# NM_033302|ADRA1A|chr8|-
# NM_033303|ADRA1A|chr8|-
# NM_033304|ADRA1A|chr8|-
# NM_033305|VPS13A|chr9|+
# NM_145326|ZNF493|chr19|+
# NM_178314|RILPL1|chr12|-
# NM_178313|SPTBN1|chr2|+
# NM_178312|GGTLC1|chr20|-
# NM_178310|SNAI3|chr16|-
# NM_001201362|HMGN3|chr6|-
# NM_001201366|DNAL1|chr14|+
# NM_001013403|CXorf66|chrX|-
# NM_001013407|PRAMEF5|chr1|+
# NM_001013406|KRIT1|chr7|-
# NM_000704|ATP4A|chr19|-
# NM_000705|ATP4B|chr13|-
# NM_000706|AVPR1A|chr12|-
# NM_000707|AVPR1B|chr1|+
# NM_000700|ANXA1|chr9|+
# NM_000701|ATP1A1|chr1|+
# NM_000702|ATP1A2|chr1|+
# NM_006621|AHCYL1|chr1|+
# NM_006620|HBS1L|chr6|-
# NM_006623|PHGDH|chr1|+
# NM_006622|PLK2|chr5|-
# NM_006625|SRSF10|chr1|-
# NM_006626|ZBTB6|chr9|-
# NM_006628|ARPP19|chr15|-
# NM_153770|CABYR|chr18|+
# NM_023917|TAS2R9|chr12|-
# NM_023915|GPR87|chr3|-
# NM_023918|TAS2R8|chr12|-
# NM_023919|TAS2R7|chr12|-
# NR_029595|MIR208A|chr14|-
# NR_029597|MIR148A|chr7|-
# NR_029596|MIR129-1|chr7|+
# NR_029599|MIR30D|chr8|-
# NR_029598|MIR30C2|chr6|-
# NR_026914|MGC16275|chr17|-
# NR_026915|LOC201651|chr3|+
# NR_026916|ANKRD30BP2|chr21|+
# NM_001012758|NUDT17|chr1|-
# NM_001177999|SLC34A2|chr4|+
# NR_026913|LOC100133669|chr8|-
# NM_001012755|SLC25A53|chrX|-
# NR_026919|LOC150197|chr22|+
# NM_001012753|ZNF763|chr19|+
# NR_029629|MIR216A|chr2|-
# NR_029628|MIR215|chr1|-
# NR_029623|MIR210|chr11|-
# NR_029622|MIR205|chr1|+
# NR_029621|MIR204|chr9|-
# NR_029626|MIR181A1|chr1|-
# NR_029625|MIR212|chr17|-
# NR_029624|MIR211|chr15|-
# NM_024649|BBS1|chr11|+
# NM_024646|ZYG11B|chr1|+
# NM_024644|C14orf169|chr14|+
# NM_024642|GALNT12|chr9|+
# NM_024641|MANEA|chr6|+
# NM_024640|YRDC|chr1|-
# NM_001171905|NUDT16|chr3|+
# NR_037441|MIR3668|chr6|+
# NR_037443|MIR3671|chr1|-
# NR_037446|MIR3675|chr1|+
# NR_037447|MIR3676|chr17|+
# NR_037449|MIR3678|chr17|+
# NM_001171909|CXorf40A|chrX|+
# NM_001171908|CXorf40A|chrX|+
# NM_198581|ZC3H6|chr2|+
# NM_001122646|FAM178B|chr2|-
# NM_003062|SLIT3|chr5|-
# NM_014279|OLFM1|chr9|+
# NM_014278|HSPA4L|chr4|+
# NM_014271|IL1RAPL1|chrX|+
# NR_033961|LOC729862|chr5|+
# NM_003063|SLN|chr11|-
# NM_014272|ADAMTS7|chr15|-
# NM_014276|RBPJL|chr20|+
# NR_027795|BTN2A3P|chr6|+
# NR_027790|LINC00478|chr21|+
# NR_027793|LINC00518|chr6|-
# NM_152914|C17orf103|chr17|-
# NM_152911|PAOX|chr10|+
# NM_152910|DGKH|chr13|+
# NM_152913|TMEM130|chr7|-
# NM_001127699|SPINK5|chr5|+
# NM_001127692|PCCA|chr13|+
# NM_001127691|RHD|chr1|+
# NM_001127695|CTSA|chr20|+
# NM_022731|NUCKS1|chr1|-
# NM_022730|COPS7B|chr2|+
# NM_022733|SMAP2|chr1|+
# NM_022735|ACBD3|chr1|-
# NM_022734|METTL17|chr14|+
# NM_022737|LPPR2|chr19|+
# NM_022736|MFSD1|chr3|+
# NM_022739|SMURF2|chr17|-
# NR_027139|SPIN3|chrX|-
# NR_027138|C11orf36|chr11|+
# NR_027131|NKAPP1|chrX|-
# NR_027130|ZNF738|chr19|+
# NR_027133|LOC145820|chr15|+
# NR_027135|ZSCAN18|chr19|-
# NR_027134|DKFZp779M0652|chr11|+
# NR_027136|C1orf126|chr1|-
# NM_032389|ARFGAP2|chr11|-
# NM_020777|SORCS2|chr4|+
# NM_020776|KIAA1328|chr18|+
# NM_020775|KIAA1324|chr1|+
# NM_020774|MIB1|chr18|+
# NM_020773|TBC1D14|chr4|+
# NM_020772|NUFIP2|chr17|-
# NM_020771|HACE1|chr6|-
# NM_020770|CGN|chr1|+
# NM_020778|ALPK3|chr15|+
# NM_001143940|LGSN|chr6|-
# NM_001143944|LEMD2|chr6|-
# NM_001143947|UNC93A|chr6|+
# NM_001170747|PIN4|chrX|+
# NM_001170741|FAM22G|chr9|+
# NM_001198838|RBM12|chr20|-
# NM_001198832|PDE4DIP|chr1|-
# NM_001198834|PDE4DIP|chr1|-
# NM_013409|FST|chr5|+
# NM_013403|STRN4|chr19|-
# NM_001134381|TBC1D5|chr3|-
# NM_001134382|IQSEC1|chr3|-
# NM_001004712|OR4K14|chr14|-
# NM_001134388|ZDHHC4|chr7|+
# NM_013401|RAB3IL1|chr11|-
# NM_001135036|FAM18B2|chr17|-
# NM_001135032|FAM176A|chr2|-
# NM_001083116|PRF1|chr10|-
# NM_001083112|GPD2|chr2|+
# NM_001007189|IGIP|chr5|+
# NM_001145045|ZNF286B|chr17|-
# NM_001145044|SLCO3A1|chr15|+
# NM_001145048|GPN1|chr2|+
# NM_202469|GIPC1|chr19|-
# NM_001100419|C19orf60|chr19|+
# NM_001100411|FAM184A|chr6|-
# NM_005428|VAV1|chr19|+
# NM_005429|VEGFC|chr4|-
# NM_005426|TP53BP2|chr1|-
# NM_005425|TNP2|chr16|-
# NM_005422|TECTA|chr11|+
# NM_005423|TFF2|chr21|-
# NM_005420|SULT1E1|chr4|-
# NM_005421|TAL2|chr9|+
# NM_001243531|LOC100505679|chr15|+
# NM_080816|SIRPG|chr20|-
# NM_080817|GPR82|chrX|+
# NM_001243537|LOC388849|chr22|-
# NM_001243538|LOC283710|chr15|-
# NM_001243539|IL15RA|chr10|-
# NR_040117|LOC392364|chr9|-
# NM_080818|OXGR1|chr13|-
# NR_040111|LOC100505782|chr17|+
# NR_040112|A2MP1|chr12|-
# NR_040113|ANKRD20A5P|chr18|+
# NM_207171|POGZ|chr1|-
# NR_038120|ELMO1|chr7|-
# NM_207173|NPSR1|chr7|+
# NM_001204911|C16orf57|chr16|+
# NM_001012715|C9orf106|chr9|+
# NM_005396|PNLIPRP2|chr10|+
# NM_005397|PODXL|chr7|-
# NM_005390|PDHA2|chr4|+
# NM_005391|PDK3|chrX|+
# NM_005392|PHF2|chr9|+
# NM_032276|RHBDD1|chr2|+
# NM_032271|TRAF7|chr16|+
# NM_032270|LRRC8C|chr1|+
# NM_032273|TMEM126A|chr11|+
# NM_032272|MAF1|chr8|+
# NM_001202425|ZNF559-ZNF177|chr19|+
# NM_001202423|TRMT1L|chr1|-
# NM_001202429|ASB2|chr14|-
# NM_001015038|PAGE2B|chrX|+
# NR_024261|GOLGA2P5|chr12|-
# NM_001023570|IQCB1|chr3|-
# NM_001110354|ZP3|chr7|+
# NM_001110359|RNASE9|chr14|-
# NM_001220500|FCER2|chr19|-
# NR_003014|SNORA47|chr5|-
# NR_003015|SNORA53|chr12|+
# NR_003016|SNORA26|chr4|+
# NR_003017|SNORA71C|chr20|-
# NR_003010|SCARNA12|chr12|-
# NR_003011|SCARNA15|chr15|+
# NR_003012|SCARNA11|chr12|-
# NM_004077|CS|chr12|-
# NR_003018|SNORA71D|chr20|-
# NM_004074|COX8A|chr11|+
# NM_001007|RPS4X|chrX|-
# NM_004073|PLK3|chr1|+
# NM_138573|NRG4|chr15|-
# NM_138572|TAF8|chr6|+
# NM_138571|HINT3|chr6|+
# NM_138570|SLC38A10|chr17|-
# NM_138576|BCL11B|chr14|-
# NM_138575|PGAM5|chr12|+
# NM_138574|HDGFL1|chr6|+
# NM_138578|BCL2L1|chr20|-
# NM_130386|COLEC12|chr18|-
# NM_130387|ASB14|chr3|-
# NM_130388|ASB12|chrX|-
# NR_002941|LOC285359|chr3|+
# NR_002940|LRRC37A4P|chr17|-
# NR_002942|LOC340508|chr9|-
# NR_002944|HNRNPA1P10|chr12|+
# NR_002947|TCAM1P|chr17|+
# NR_002946|MMP23A|chr1|+
# NR_002949|NUDT16P1|chr3|+
# NR_002948|KLKP1|chr19|-
# NM_054104|OR6C3|chr12|+
# NM_017898|MARC2|chr1|+
# NM_017894|ZSCAN2|chr15|+
# NM_017895|DDX27|chr20|+
# NM_017896|C20orf11|chr20|+
# NM_017897|OXSM|chr3|+
# NM_017891|C1orf159|chr1|-
# NM_017892|PRPF40A|chr2|-
# NM_017893|SEMA4G|chr10|+
# NM_001899|CST4|chr20|-
# NM_001898|CST1|chr20|-
# NM_001892|CSNK1A1|chr5|-
# NM_001891|CSN2|chr4|-
# NM_001890|CSN1S1|chr4|+
# NM_001897|CSPG4|chr15|-
# NM_001896|CSNK2A2|chr16|-
# NM_001895|CSNK2A1|chr20|-
# NM_001013649|C2orf68|chr2|-
# NM_001013647|LOC646851|chr22|-
# NM_001013646|FAM209B|chr20|+
# NM_001013641|TMEM82|chr1|+
# NM_030767|AKNA|chr9|-
# NM_001013642|TRNP1|chr1|+
# NM_017798|YTHDF1|chr20|-
# NR_003352|SNORD115-37|chr15|+
# NR_038908|LOC100507392|chr11|-
# NR_038909|LOC100507401|chr11|+
# NR_038904|LOC100506305|chr11|-
# NR_038905|LOC100506368|chr11|+
# NR_038906|LOC643623|chr6|+
# NR_038907|LOC100507300|chr11|-
# NR_038901|LINC00251|chr8|-
# NR_038902|LOC153469|chr5|+
# NR_038903|LOC100506233|chr11|+
# NM_001195536|CHMP5|chr9|+
# NM_001195535|LOC100505841|chr5|+
# NM_001014342|FLG2|chr1|-
# NM_000275|OCA2|chr15|-
# NM_000277|PAH|chr12|-
# NM_000270|PNP|chr14|+
# NM_000271|NPC1|chr18|-
# NM_000273|GPR143|chrX|-
# NR_045529|LOC390660|chr15|+
# NM_001128635|RIMBP3B|chr22|+
# NM_001128636|ELFN1|chr7|+
# NM_001128633|RIMBP3C|chr22|+
# NM_024071|ZFYVE21|chr14|+
# NM_016418|NF2|chr22|+
# NM_016417|GLRX5|chr14|+
# NM_016413|CPB2|chr13|-
# NM_172238|TFAP2D|chr6|+
# NM_172239|REXO1L1|chr8|-
# NM_001098213|HRH1|chr3|+
# NM_172230|SYVN1|chr11|-
# NM_001098210|CTNNB1|chr3|+
# NM_172236|POFUT1|chr20|+
# NM_139155|ADAMTS14|chr10|+
# NM_000851|GSTM5|chr1|+
# NM_000852|GSTP1|chr11|+
# NM_000853|GSTT1|chr22|-
# NM_000854|GSTT2|chr22|-
# NM_012088|PGLS|chr19|+
# NM_000856|GUCY1A3|chr4|+
# NM_000857|GUCY1B3|chr4|+
# NM_000859|HMGCR|chr5|+
# NM_001193269|EML2|chr19|-
# NM_012089|ABCB10|chr1|-
# NM_024076|KCTD15|chr19|+
# NM_001077191|GPBAR1|chr2|+
# NM_001077194|GPBAR1|chr2|+
# NM_001077199|SREK1|chr5|+
# NM_001077198|ATG9A|chr2|-
# NM_001252657|PP2D1|chr3|-
# NM_031205|CABP1|chr12|+
# NM_031209|QTRT1|chr19|+
# NM_031208|FAHD1|chr16|+
# NM_001256795|LOC100129083|chr19|+
# NR_002169|OR1F2P|chr16|+
# NM_001163646|HTR3D|chr3|+
# NR_002166|TRAPPC2P1|chr19|+
# NR_002165|HMGB3P1|chr20|-
# NR_002164|GTF2IRD2P1|chr7|-
# NR_002163|OR7E37P|chr13|+
# NR_002162|ATP5EP2|chr13|+
# NM_178571|TBC1D26|chr17|+
# NM_178570|RTN4RL2|chr11|+
# NM_001042371|PGP|chr16|-
# NM_001099670|C8orf59|chr8|-
# NM_001099676|C12orf56|chr12|-
# NM_001099678|LRRC58|chr3|-
# NM_001099679|TRIM32|chr9|+
# NM_014701|SECISBP2L|chr15|-
# NM_014700|RAB11FIP3|chr16|+
# NM_014705|DOCK4|chr7|-
# NM_014704|CEP104|chr1|-
# NM_014707|HDAC9|chr7|+
# NM_014706|SART3|chr12|-
# NM_005981|TSPAN31|chr12|+
# NM_014708|KNTC1|chr12|+
# NM_005983|SKP2|chr5|+
# NM_005982|SIX1|chr14|-
# NM_005985|SNAI1|chr20|+
# NM_005987|SPRR1A|chr1|+
# NM_005986|SOX1|chr13|+
# NM_001005501|OR4K2|chr14|+
# NM_001005500|OR4M1|chr14|+
# NM_001005503|OR11G2|chr14|+
# NM_001005504|OR4F21|chr8|-
# NM_015254|KIF13B|chr8|-
# NM_001177519|MICA|chr6|+
# NM_015256|ACSL6|chr5|-
# NM_001008901|GTSF1L|chr20|-
# NM_015250|BICD2|chr9|-
# NM_015251|ATMIN|chr16|+
# NM_015253|WSCD1|chr17|+
# NM_001197020|PRSS55|chr8|+
# NM_015258|FKBP15|chr9|-
# NM_001197027|PLEKHA8|chr7|+
# NM_175078|KRT77|chr12|-
# NM_052985|IFT122|chr3|+
# NM_052987|CDK10|chr16|+
# NM_052988|CDK10|chr16|+
# NM_053050|MRPL53|chr2|-
# NM_053051|CNTROB|chr17|+
# NM_053052|SNAP47|chr1|+
# NM_053053|TADA1|chr1|-
# NM_053054|CATSPER1|chr11|-
# NM_053055|THEM4|chr1|-
# NM_053056|CCND1|chr11|+
# NM_001077446|TSEN34|chr19|+
# NM_001171581|ITM2A|chrX|-
# NM_006988|ADAMTS1|chr21|-
# NM_006980|MTERF|chr7|-
# NM_006981|NR4A3|chr9|+
# NM_006982|ALX1|chr12|+
# NM_006983|MMP23B|chr1|+
# NM_006985|NPIP|chr16|+
# NM_006986|MAGED1|chrX|+
# NM_006987|RPH3AL|chr17|-
# NM_004693|KRT75|chr12|-
# NM_001242758|HLA-A|chr6|+
# NM_004168|SDHA|chr5|+
# NM_004160|PYY|chr17|-
# NM_004161|RAB1A|chr2|-
# NM_004162|RAB5A|chr3|+
# NM_004163|RAB27B|chr18|+
# NM_004164|RBP2|chr3|-
# NM_004165|RRAD|chr16|-
# NM_181361|KCNMB2|chr3|+
# NM_152489|UBE2U|chr1|+
# NM_201627|TRIM41|chr5|+
# NM_001669|ARSD|chrX|-
# NM_004299|ABCB7|chrX|-
# NM_004296|RGS6|chr14|+
# NM_001665|RHOG|chr11|-
# NM_001666|ARHGAP4|chrX|-
# NM_004295|TRAF4|chr17|+
# NM_004292|RIN1|chr11|-
# NM_001661|ARL4D|chr17|+
# NM_001662|ARF5|chr7|+
# NM_001663|ARF6|chr14|+
# NM_000139|MS4A2|chr11|+
# NM_000138|FBN1|chr15|-
# NM_000137|FAH|chr15|+
# NM_000135|FANCA|chr16|-
# NM_000134|FABP2|chr4|-
# NM_000133|F9|chrX|+
# NM_000132|F8|chrX|-
# NM_000131|F7|chr13|+
# NM_000130|F5|chr1|-
# NM_001205228|SORT1|chr1|-
# NR_034078|LOC643733|chr11|-
# NM_152487|TMEM56|chr1|+
# NM_152486|SAMD11|chr1|+
# NM_001001975|ATP5D|chr19|+
# NM_001080116|LDB3|chr10|+
# NM_004838|HOMER3|chr19|-
# NM_004839|HOMER2|chr15|-
# NR_028032|HCG9|chr6|+
# NM_004833|AIM2|chr1|-
# NM_004830|MED23|chr6|-
# NM_004831|MED26|chr19|-
# NM_004836|EIF2AK3|chr2|-
# NM_003400|XPO1|chr2|-
# NM_139014|MAPK14|chr6|+
# NM_001251884|VIPR1|chr3|+
# NM_006470|TRIM16|chr17|-
# NM_006471|MYL12A|chr18|+
# NM_006472|TXNIP|chr1|+
# NM_006473|TAF6L|chr11|+
# NM_006474|PDPN|chr1|+
# NM_006477|RASL10A|chr22|-
# NM_180976|PPP2R5D|chr6|+
# NR_030724|XPNPEP1|chr10|-
# NR_030725|RCC1|chr1|+
# NR_030727|TLR8-AS1|chrX|-
# NR_030728|LOC440910|chr2|+
# NM_001171941|FNDC5|chr1|-
# NM_001171942|GLRA2|chrX|+
# NM_001190827|FAM217B|chr20|+
# NM_001171946|SUN1|chr7|+
# NM_001007469|HCST|chr19|+
# NM_001130065|MYO9B|chr19|+
# NM_001130060|ATF7|chr12|-
# NM_001164527|ZNF135|chr19|+
# NM_001252512|SOAT1|chr1|+
# NM_001242830|ELOVL5|chr6|-
# NM_001242831|ELOVL5|chr6|-
# NM_001242834|NDRG4|chr16|+
# NM_001242839|GUK1|chr1|+
# NR_002570|CYP2D7P1|chr22|-
# NM_199004|ARRB2|chr17|+
# NM_199002|ARHGEF1|chr19|+
# NM_199003|THAP1|chr8|-
# NM_199000|LHFPL3|chr7|+
# NM_199001|C9orf169|chr9|+
# NR_002578|GAS5|chr1|-
# NM_017704|ANKRD49|chr11|+
# NM_017705|PAQR5|chr15|+
# NM_017706|WDR55|chr5|+
# NM_017707|ASAP3|chr1|-
# NM_017700|ARHGEF38|chr4|+
# NM_017702|DEF8|chr16|+
# NM_017703|FBXL12|chr19|-
# NM_017708|FAM83E|chr19|-
# NM_017709|FAM46C|chr1|+
# NM_030808|NDEL1|chr17|+
# NM_030809|CSRNP2|chr12|-
# NM_182603|ANKRD42|chr11|+
# NM_182607|VSIG1|chrX|+
# NM_182608|ANKRD33|chr12|+
# NM_182609|ZNF677|chr19|-
# NM_030802|FAM117A|chr17|-
# NM_030806|C1orf21|chr1|+
# NM_030807|SLC2A11|chr22|+
# NM_001134225|INPP4A|chr2|+
# NM_001134223|USP46|chr4|-
# NM_001134222|IRX2|chr5|-
# NR_046198|LOC339622|chr21|+
# NR_046199|LOC339862|chr3|+
# NM_001243879|TRA2B|chr3|-
# NM_001243878|FHL3|chr1|-
# NM_198353|KCTD8|chr4|-
# NM_001199355|RPL17-C18ORF32|chr18|-
# NM_022968|SERF1A|chr5|+
# NM_001243877|TOB1|chr17|-
# NR_046448|LOC374443|chr12|+
# NM_020526|EPHA8|chr1|+
# NM_020524|PBXIP1|chr1|-
# NM_020525|IL22|chr12|-
# NR_040415|LINC00266-1|chr20|+
# NM_020529|NFKBIA|chr14|-
# NM_001242589|TREM1|chr6|-
# NM_181643|C1orf88|chr1|+
# NM_001103154|ARL17B|chr17|-
# NM_181645|CCDC67|chr11|+
# NM_181644|MFSD4|chr1|+
# NM_181646|ZNF804B|chr7|+
# NM_001136575|LANCL1|chr2|-
# NM_001136571|ZAR1L|chr13|-
# NR_024268|PRNT|chr20|-
# NR_024264|LOC145845|chr15|-
# NR_024265|POGLUT1|chr3|+
# NR_024266|CCNT1|chr12|-
# NR_024260|NECAP1|chr12|+
# NM_145701|CDCA4|chr14|-
# NM_145702|TIGD1|chr2|-
# NM_002748|MAPK6|chr15|+
# NM_002746|MAPK3|chr16|-
# NM_002747|MAPK4|chr18|+
# NM_002745|MAPK1|chr22|-
# NM_002742|PRKD1|chr14|-
# NM_002743|PRKCSH|chr19|+
# NM_002740|PRKCI|chr3|+
# NM_002741|PKN1|chr19|+
# NM_031445|AMMECR1L|chr2|-
# NM_031444|C22orf13|chr22|-
# NM_031443|CCM2|chr7|+
# NM_031442|TMEM47|chrX|-
# NM_031440|RTP3|chr3|+
# NM_031448|C19orf12|chr19|-
# NM_001130834|LDB2|chr4|-
# NM_031993|PCDHGA1|chr5|+
# NM_031992|EIF4H|chr7|+
# NM_175075|C8orf42|chr8|-
# NR_040098|LOC100506393|chr12|+
# NM_175077|SLA2|chr20|-
# NM_001105659|LRRIQ3|chr1|-
# NR_040091|LOC100506990|chr8|+
# NR_040090|CYP21A1P|chr6|+
# NR_040093|LOC100505678|chr5|+
# NR_040092|LOC100506990|chr8|+
# NR_040095|LOC284801|chr20|-
# NR_040094|LOC348120|chr15|+
# NR_040097|LOC100506123|chr2|+
# NM_207033|EDN3|chr20|+
# NM_207034|EDN3|chr20|+
# NM_001039876|C19orf46|chr19|-
# NM_005211|CSF1R|chr5|-
# NM_005210|CRYGB|chr2|-
# NM_005213|CSTA|chr3|+
# NM_005212|CSN3|chr4|+
# NM_005215|DCC|chr18|+
# NM_005214|CTLA4|chr2|+
# NM_005217|DEFA3|chr8|-
# NM_005216|DDOST|chr1|-
# NM_005219|DIAPH1|chr5|-
# NM_005218|DEFB1|chr8|-
# NR_033124|ALG13|chrX|+
# NR_036573|LOC155060|chr7|+
# NR_036571|ALG11|chr13|+
# NR_036575|LOC729966|chr19|-
# NR_002574|SNORD102|chr13|+
# NR_002575|SNORA27|chr13|+
# NR_002576|SNORA21|chr17|-
# NM_178167|ZNF598|chr16|-
# NM_178160|OTOP2|chr17|+
# NM_178161|PTF1A|chr10|+
# NM_178168|OR10A5|chr11|+
# NR_002579|SNORD74|chr1|-
# NM_001159531|BEGAIN|chr14|-
# NM_001097613|GPR89A|chr1|-
# NM_001097610|LOC653486|chr11|+
# NM_001097611|KNCN|chr1|-
# NM_001097616|GPR89C|chr1|+
# NM_001097615|POLR2J3|chr7|-
# NM_018936|PCDHB2|chr5|+
# NM_018937|PCDHB3|chr5|+
# NM_018934|PCDHB14|chr5|+
# NM_018935|PCDHB15|chr5|+
# NM_018932|PCDHB12|chr5|+
# NM_018933|PCDHB13|chr5|+
# NM_018930|PCDHB10|chr5|+
# NM_018931|PCDHB11|chr5|+
# NM_018938|PCDHB4|chr5|+
# NM_018939|PCDHB6|chr5|+
# NM_019048|ASNSD1|chr2|+
# NM_019044|CCDC93|chr2|-
# NM_019046|ANKRD16|chr10|-
# NM_019041|MTRF1L|chr6|-
# NM_019040|ELP4|chr11|+
# NM_019043|APBB1IP|chr10|+
# NM_019042|PUS7|chr7|-

# %%
All_sample_coverage_weights = All_samples_sequencing_depths/np.mean(All_samples_sequencing_depths)
All_sample_coverage_weights
# Out:
# array([1.02384623, 0.97615377])

# %%
num_samples = len(All_Sample_files)

##Prepare output directory
d = os.path.dirname(output_directory)
if not os.path.exists(d):
    os.makedirs(d)
temp_dir = d+'/tmp/'
if not os.path.exists(temp_dir):
    os.makedirs(temp_dir)
Output_all_prediction_file = output_directory+Output_result_file+'_result_temp.txt'
Output_result = open(Output_all_prediction_file, 'w')
##Write the first line
first_line = ['Gene','fit_value','Predicted_Proximal_APA','Loci']
for i in range(num_group_1):
    curr_long_exp = 'A_%s_long_exp' % str(i+1)
    curr_short_exp = 'A_%s_short_exp' % str(i+1)
    curr_ratio ='A_%s_PDUI' % str(i+1)
    first_line.extend([curr_long_exp,curr_short_exp,curr_ratio])
for i in range(num_samples - num_group_1):
    curr_long_exp = 'B_%s_long_exp' % str(i+1)
    curr_short_exp = 'B_%s_short_exp' % str(i+1)
    curr_ratio ='B_%s_PDUI' % str(i+1)
    first_line.extend([curr_long_exp,curr_short_exp,curr_ratio])
first_line.append('PDUI_Group_diff')

Output_result.writelines('\t'.join(first_line) + '\n')

# %%
    
for i,curr_3UTR_id in enumerate(UTR_events_dict):
    curr_3UTR_structure = UTR_events_dict[curr_3UTR_id]
    region_start = curr_3UTR_structure[1]
    region_end   = curr_3UTR_structure[2]
    curr_strand  = curr_3UTR_structure[-2]
    UTR_pos = curr_3UTR_structure[-1]
    if i==2:
        break

# %%
curr_3UTR_id
# Out:
# 'NM_001008781|FAT3|chr11|+'

# %%
curr_3UTR_structure
# Out:
# ['chr11', 92623658, 92628438, '+', 'chr11:92623657-92629635']

# %%
UTR_pos = curr_3UTR_structure[-1]
UTR_pos
# Out:
# 'chr11:92623657-92629635'

# %%
if curr_3UTR_id in All_samples_Target_3UTR_coverages:
    print(1)
    # curr_3UTR_coverage_wig = All_samples_Target_3UTR_coverages[curr_3UTR_id]
# curr_3UTR_coverage_wig
